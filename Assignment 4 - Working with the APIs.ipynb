# %% [markdown]
# # Lab Assignment 4: How to Use APIs in Python
# ## DS 6001

# %% [markdown]
# ### Instructions
# Please answer the following questions as completely as possible using text, code, and the results of code as needed. Format your answers in a Jupyter notebook. To receive full credit, make sure you address every part of the problem, and make sure your document is formatted in a clean and professional way.
#
# ## Problem 0
# Import the following packages:

# %%
import numpy as np
import pandas as pd
import requests
import json
import os
import dotenv
import lyricsgenius

r = requests.get('https://httpbin.org/user-agent')
useragent = json.loads(r.text)['user-agent'] #This saves your user-agent string for use later

# %% [markdown]
# ## Problem 1
# The hardest part of working with an API is finding and understanding the API's documentation. While the documentation (if it exists!) is essential for helping you to navigate to the data you need, they are also dense and technical.
#
# One big reason why API documentation is difficult is that it has to speak to all use-cases. Very often, when software engineers interact with an API like genius.com's, they are building apps. Imagine that you are hired to build an events and ticketing app for a local music venue. You might want to embed a list of albums, songs, and background information in your app by connecting to the Genius API (for song lyrics and artist information) and pulling that data into your app. You might run a record label and you want to interact with this API by posting information about the musicians you've signed. Or you might want to collect data on the users of genius.com for marketing research. The documentation must provide enough information to support all of these uses. As a result, documentation tends to be very long, and most of the information you will see is neither relevant nor easy to understand. That is okay, and should be the expectation.
#
# To effectively use API documentation, take a deep breath. Then narrow your search through the documentation to only these four things:
#
# 1. **The root**: We make requests from an API by, in part, writing out a complicated URL. In Python, we will compile the segments of this URL and let the `requests` package build the right URL. The first segment is the root, or the shared beginning of every URL associated with this API. Roots sometimes also include a version number such as /v2 or /v3. Your first task is to find the root and save it as a string in Python. One complaint I have about API documentation is that sometimes the root is a bit difficult to find, whereas I think it should be written in bold letters on the homepage. Sometimes I have to look for *example calls* to the API to see the root being used.
#
# 2. **The endpoints**: The next part of an API call's URL (generally after the first slash / but before the question mark) is called the endpoint. Very commonly, APIs have many endpoints for many different types of data. Genius for example has separate endpoints for songs, artists, user accounts, its search engine, and other types of functions. Sometimes endpoints are called "resources" or something similar, but you can generally tell an endpoint because it is denoted with a slash first, such as Genius's /songs, /artists, /accounts, and /search sections under resources. Your task here is to find the endpoint or endpoints that can give you the data you need by reading their descriptions in the documentation.
#
# 3. **The endpoint parameters**: Some endpoints will also have a list of parameters that control the selection of data a request will return. There are two ways that these parameters can appear in an API call's URL. First, they can appear as "query parameters" after a question mark, using equal signs to specify parameter values, and separating parameters with & signs. If you write these parameters in a dictionary and use the `params` argument in the `requests.get()` method to supply these parameters to the API, then `requests` will format the URL properly for you. The other way parameters might appear is as "path parameters" which are part of the endpoint, sometimes surrounded by {curly braces}: this format implies that the parameter value should be part of the endpoint you supply to `requests.get()` instead of an entry in the `params` argument. Either way, your task here is to find the parameters that enable you to get the data you need and to use the correct names and values of these parameters in your Python code.
#
# 4. **How to acquire API authentication or access keys, and how to supply these credentials when interacting with the API**: It's important to remember that APIs are designed to give the data owners control over how their data is shared with users like you. There is a political dimension to that: a data owner can choose what to divulge or keep private. There's also a financial dimension: websites can charge you at varying rates for using the API, can restrict the speed and volume of your requests to prevent you from overloading systems or profiting too much off of their work, or can use a "freemium" model where only a small amount of data is free but more data carries charges. Many APIs require you to register in advance and acquire secret codes (called keys or tokens) that must be supplied back to the API to enable your use. You have two tasks here. First you need to find instructions in the documentation for acquiring API access keys, paying particular attention to whether they are asking for a credit card (Genius does not) and if so what they might charge you, and what limits exist on the amount of data you can grab. Second, you need to find the instructions for supplying your key to the API. Sometimes that will be one of the endpoint parameters, and sometimes it will be in the headers along with your user-agent string. (When providing an API key via the headers, there's a common format that requires you to write the word "Bearer" and a space before your key. You are likely to see this format pop up sometimes.)
#
# For the following problems, describe in words how you can get the data in question. Use the API documentation linked in each question. Be specific about
#
# * the root,
# * endpoint,
# * parameters,
# * method of acquiring keys,
# * method for supplying these keys during an API call,
# * and whether and how using the API costs money, or is limited to only certain quantities of data.
#
# If there is more than one way to accomplish a task, describing just one of the valid approaches is fine.
#
# Do not write Python code to accomplish these steps. Focus on reading the documentation and understanding what you would need to do if you did attempt to get the data. Also, do NOT give any of these websites a credit card or other payment information, and please do not copy and paste your API keys into this document.

# %% [markdown]
# ### Part a
# How would you get data on the top 50 headlines from Germany today on the topic of sports? Use the News API, with documentation here: https://newsapi.org/docs (Hint: here's a list of country codes: https://en.wikipedia.org/wiki/ISO_3166-1_alpha-2) [12 points]

# %%
# define the API endpoints

root = 'http://newsapi.org'
endpoint = '/v2/top-headlines'

# %%
useragent='feyBot/0.0 (qhh3bv@virginia.edu) generic-library/2.32.5'
headers = {'User-Agent': useragent,
           'From': 'xdy6sg@virginia.edu'}

# %%
dotenv.load_dotenv()
newskey = os.getenv('newskey')

newskey
# congresskey = os.getenv('congresskey')
# Out:
# '57bf225ec0f64d62a6da2615f8b3a67b'

# %%
newskey = '57bf225ec0f64d62a6da2615f8b3a67b'

# %%
# define the parameters for the API request

params = {
    "country": "de",           # Germany's country code
    "category": "sports",      # Topic of interest
    "pageSize": 50,            # Maximum number of headlines allowed per request
    "apiKey": "57bf225ec0f64d62a6da2615f8b3a67b"   # Replace with your actual News API key
}

# %%
# Make the GET request
r = requests.get(root + endpoint, headers=headers, params = params)
r
# Out:
# <Response [200]>

# %%
r.url
# Out:
# 'http://newsapi.org/v2/top-headlines?country=de&category=sports&pageSize=50&apiKey=57bf225ec0f64d62a6da2615f8b3a67b'

# %%
# output the JSON content

r.json()
# Out:
# {'status': 'ok', 'totalResults': 0, 'articles': []}

# %% [markdown]
# ### Part b
# How would you get JSON formatted data on the 100 most recent house resolutions (bills that passed a vote in the House of Representatives) in the 119th congress (elected in 2024) from the API of the U.S Congress? The documentation for this API is here: https://api.congress.gov/ [12 points]

# %%
# define the API endpoints

root = 'https://api.congress.gov'
endpoint = '/v3/bill'

# %%
congresskey = '4nfARHzILhC1BAA5RdxYZ99udkLFKaFfZDK0B7dP'

# %%
# define the parameters for the API request

params = {
    "congress": 119,           # 119th Congress (elected in 2024)
    "type": "hr",              # House Resolutions
    "chamber": "house",        # House of Representatives
    "status": "passed",        # Only resolutions that passed a vote
    "pageSize": 100,           # Maximum number of results
    "format": "json",          # JSON response format
    "api_key": "4nfARHzILhC1BAA5RdxYZ99udkLFKaFfZDK0B7dP"  # Replace with your actual API key
}

# %%
# Make the GET request
r = requests.get(root + endpoint, headers=headers, params = params)
r
# Out:
# <Response [200]>

# %%
r.url
# Out:
# 'https://api.congress.gov/v3/bill?congress=119&type=hr&chamber=house&status=passed&pageSize=100&format=json&api_key=4nfARHzILhC1BAA5RdxYZ99udkLFKaFfZDK0B7dP'

# %%
# output the JSON content

r.json()
# Out:
# {'bills': [{'congress': 119,
#    'latestAction': {'actionDate': '2025-09-19',
#     'text': 'Ordered placed on Senate Legislative Calendar under General Orders. Calendar No. 168.'},
#    'number': '5371',
#    'originChamber': 'House',
#    'originChamberCode': 'H',
#    'title': 'Continuing Appropriations and Extensions Act, 2026',
#    'type': 'HR',
#    'updateDate': '2025-09-20',
#    'updateDateIncludingText': '2025-09-20',
#    'url': 'https://api.congress.gov/v3/bill/119/hr/5371?format=json'},
#   {'congress': 119,
#    'latestAction': {'actionDate': '2025-09-19',
#     'text': 'Ordered placed on Senate Legislative Calendar under General Orders. Calendar No. 167.'},
#    'number': '2882',
#    'originChamber': 'Senate',
#    'originChamberCode': 'S',
#    'title': 'Continuing Appropriations and Extensions and Other Matters Act, 2026',
#    'type': 'S',
#    'updateDate': '2025-09-21',
#    'updateDateIncludingText': '2025-09-21',
#    'url': 'https://api.congress.gov/v3/bill/119/s/2882?format=json'},
#   {'congress': 119,
#    'latestAction': {'actionDate': '2025-09-19',
#     'text': 'Cloture motion on the motion to proceed to the measure presented in Senate.'},
#    'number': '2806',
#    'originChamber': 'Senate',
#    'originChamberCode': 'S',
#    'title': 'Eliminate Shutdowns Act',
#    'type': 'S',
#    'updateDate': '2025-09-20',
#    'updateDateIncludingText': '2025-09-20',
#    'url': 'https://api.congress.gov/v3/bill/119/s/2806?format=json'},
#   {'congress': 119,
#    'latestAction': {'actionDate': '2025-09-19',
#     'text': 'Referred to the Committee on Environment and Public Works.'},
#    'number': '418',
#    'originChamber': 'Senate',
#    'originChamberCode': 'S',
#    'title': 'A resolution expressing support for the designation of the week of September 20 through September 27, 2025, as "National Estuaries Week".',
#    'type': 'SRES',
#    'updateDate': '2025-09-20',
#    'updateDateIncludingText': '2025-09-20',
#    'url': 'https://api.congress.gov/v3/bill/119/sres/418?format=json'},
#   {'congress': 119,
#    'latestAction': {'actionDate': '2025-09-19',
#     'text': 'Resolution agreed to in Senate without amendment and with a preamble by Unanimous Consent.'},
#    'number': '225',
#    'originChamber': 'Senate',
#    'originChamberCode': 'S',
#    'title': 'A resolution designating the week of September 14 through September 20, 2025, as "National Truck Driver Appreciation Week".',
#    'type': 'SRES',
#    'updateDate': '2025-09-20',
#    'updateDateIncludingText': '2025-09-20',
#    'url': 'https://api.congress.gov/v3/bill/119/sres/225?format=json'},
#   {'congress': 119,
#    'latestAction': {'actionDate': '2025-09-19',
#     'text': 'Submitted in the Senate, considered, and agreed to without amendment and with a preamble by Voice Vote.'},
#    'number': '417',
#    'originChamber': 'Senate',
#    'originChamberCode': 'S',
#    'title': 'A resolution supporting the designation of the week of September 14 through September 20, 2025, as "Telehealth Awareness Week".',
#    'type': 'SRES',
#    'updateDate': '2025-09-20',
#    'updateDateIncludingText': '2025-09-20',
#    'url': 'https://api.congress.gov/v3/bill/119/sres/417?format=json'},
#   {'congress': 119,
#    'latestAction': {'actionDate': '2025-09-19',
#     'text': 'Submitted in the Senate, considered, and agreed to without amendment and with a preamble by Unanimous Consent.'},
#    'number': '416',
#    'originChamber': 'Senate',
#    'originChamberCode': 'S',
#    'title': 'A resolution expressing support for the designation of September 2025 as "Sickle Cell Disease Awareness Month" in order to educate communities across the United States about sickle cell disease and the need for research, early detection methods, effective treatments, and preventative care programs with respect to complications from sickle cell disease and conditions related to sickle cell disease.',
#    'type': 'SRES',
#    'updateDate': '2025-09-20',
#    'updateDateIncludingText': '2025-09-20',
#    'url': 'https://api.congress.gov/v3/bill/119/sres/416?format=json'},
#   {'congress': 119,
#    'latestAction': {'actionDate': '2025-09-19',
#     'text': 'Submitted in the Senate, considered, and agreed to without amendment and with a preamble by Unanimous Consent.'},
#    'number': '415',
#    'originChamber': 'Senate',
#    'originChamberCode': 'S',
#    'title': 'A resolution designating the week of September 21 through September 27, 2025, as "Gold Star Families Remembrance Week".',
#    'type': 'SRES',
#    'updateDate': '2025-09-20',
#    'updateDateIncludingText': '2025-09-20',
#    'url': 'https://api.congress.gov/v3/bill/119/sres/415?format=json'},
#   {'congress': 119,
#    'latestAction': {'actionDate': '2025-09-19',
#     'text': 'Submitted in the Senate, considered, and agreed to without amendment and with a preamble by Unanimous Consent.'},
#    'number': '414',
#    'originChamber': 'Senate',
#    'originChamberCode': 'S',
#    'title': 'A resolution designating September 2025 as "National Child Awareness Month" to promote awareness of charities that benefit children as well as youth-serving organizations throughout the United States and recognizing the efforts made by those charities and organizations on behalf of children and youth as critical contributions to the future of the United States.',
#    'type': 'SRES',
#    'updateDate': '2025-09-20',
#    'updateDateIncludingText': '2025-09-20',
#    'url': 'https://api.congress.gov/v3/bill/119/sres/414?format=json'},
#   {'congress': 119,
#    'latestAction': {'actionDate': '2025-09-19',
#     'text': 'Passed Senate with an amendment by Unanimous Consent.'},
#    'number': '269',
#    'originChamber': 'Senate',
#    'originChamberCode': 'S',
#    'title': 'Ending Improper Payments to Deceased People Act',
#    'type': 'S',
#    'updateDate': '2025-09-21',
#    'updateDateIncludingText': '2025-09-21',
#    'url': 'https://api.congress.gov/v3/bill/119/s/269?format=json'},
#   {'congress': 119,
#    'latestAction': {'actionDate': '2025-09-19',
#     'text': 'Received in the Senate and Read twice and referred to the Committee on Energy and Natural Resources.'},
#    'number': '3062',
#    'originChamber': 'House',
#    'originChamberCode': 'H',
#    'title': 'Promoting Cross-border Energy Infrastructure Act',
#    'type': 'HR',
#    'updateDate': '2025-09-20',
#    'updateDateIncludingText': '2025-09-20',
#    'url': 'https://api.congress.gov/v3/bill/119/hr/3062?format=json'},
#   {'congress': 119,
#    'latestAction': {'actionDate': '2025-09-19',
#     'text': 'Received in the Senate and Read twice and referred to the Committee on Energy and Natural Resources.'},
#    'number': '3015',
#    'originChamber': 'House',
#    'originChamberCode': 'H',
#    'title': 'National Coal Council Reestablishment Act',
#    'type': 'HR',
#    'updateDate': '2025-09-20',
#    'updateDateIncludingText': '2025-09-20',
#    'url': 'https://api.congress.gov/v3/bill/119/hr/3015?format=json'},
#   {'congress': 119,
#    'latestAction': {'actionDate': '2025-09-19',
#     'text': 'Received in the Senate and Read twice and referred to the Committee on Energy and Natural Resources.'},
#    'number': '1047',
#    'originChamber': 'House',
#    'originChamberCode': 'H',
#    'title': 'GRID Power Act',
#    'type': 'HR',
#    'updateDate': '2025-09-21',
#    'updateDateIncludingText': '2025-09-21',
#    'url': 'https://api.congress.gov/v3/bill/119/hr/1047?format=json'},
#   {'congress': 119,
#    'latestAction': {'actionDate': '2025-09-19',
#     'text': 'Read twice and referred to the Committee on the Judiciary.'},
#    'number': '2923',
#    'originChamber': 'Senate',
#    'originChamberCode': 'S',
#    'title': 'A bill to provide for the automatic acquisition of United States citizenship for certain internationally adopted individuals, and for other purposes.',
#    'type': 'S',
#    'updateDate': '2025-09-20',
#    'updateDateIncludingText': '2025-09-20',
#    'url': 'https://api.congress.gov/v3/bill/119/s/2923?format=json'},
#   {'congress': 119,
#    'latestAction': {'actionDate': '2025-09-19',
#     'text': 'Placed on Senate Legislative Calendar under General Orders. Calendar No. 166.'},
#    'number': '1092',
#    'originChamber': 'Senate',
#    'originChamberCode': 'S',
#    'title': 'WIPPES Act',
#    'type': 'S',
#    'updateDate': '2025-09-20',
#    'updateDateIncludingText': '2025-09-20',
#    'url': 'https://api.congress.gov/v3/bill/119/s/1092?format=json'},
#   {'congress': 119,
#    'latestAction': {'actionDate': '2025-09-19',
#     'text': 'Read twice and referred to the Committee on Environment and Public Works.'},
#    'number': '2922',
#    'originChamber': 'Senate',
#    'originChamberCode': 'S',
#    'title': 'A bill to amend title 23, United States Code, to extend the authorization for certain alternative fuel and clean vehicles to use HOV facilities, and for other purposes.',
#    'type': 'S',
#    'updateDate': '2025-09-20',
#    'updateDateIncludingText': '2025-09-20',
#    'url': 'https://api.congress.gov/v3/bill/119/s/2922?format=json'},
#   {'congress': 119,
#    'latestAction': {'actionDate': '2025-09-19',
#     'text': 'Read twice and referred to the Committee on Health, Education, Labor, and Pensions.'},
#    'number': '2921',
#    'originChamber': 'Senate',
#    'originChamberCode': 'S',
#    'title': 'A bill to amend section 7014 of the Elementary and Secondary Education Act of 1965 to advance toward full Federal funding for impact aid, and for other purposes.',
#    'type': 'S',
#    'updateDate': '2025-09-20',
#    'updateDateIncludingText': '2025-09-20',
#    'url': 'https://api.congress.gov/v3/bill/119/s/2921?format=json'},
#   {'congress': 119,
#    'latestAction': {'actionDate': '2025-09-19',
#     'text': 'Read twice and referred to the Committee on Banking, Housing, and Urban Affairs.'},
#    'number': '2920',
#    'originChamber': 'Senate',
#    'originChamberCode': 'S',
#    'title': 'A bill to enhance civil penalties under the Federal securities laws, and for other purposes.',
#    'type': 'S',
#    'updateDate': '2025-09-20',
#    'updateDateIncludingText': '2025-09-20',
#    'url': 'https://api.congress.gov/v3/bill/119/s/2920?format=json'},
#   {'congress': 119,
#    'latestAction': {'actionDate': '2025-09-19',
#     'text': 'Read twice and referred to the Committee on Banking, Housing, and Urban Affairs.'},
#    'number': '2919',
#    'originChamber': 'Senate',
#    'originChamberCode': 'S',
#    'title': 'A bill to amend the Sarbanes-Oxley Act of 2002 to promote transparency by permitting the Public Company Accounting Oversight Board to allow its disciplinary proceedings to be open to the public, and for other purposes.',
#    'type': 'S',
#    'updateDate': '2025-09-20',
#    'updateDateIncludingText': '2025-09-20',
#    'url': 'https://api.congress.gov/v3/bill/119/s/2919?format=json'},
#   {'congress': 119,
#    'latestAction': {'actionDate': '2025-09-19',
#     'text': 'Read twice and referred to the Committee on Foreign Relations.'},
#    'number': '2918',
#    'originChamber': 'Senate',
#    'originChamberCode': 'S',
#    'title': 'A bill to amend the Rebuilding Economic Prosperity and Opportunity for Ukrainians Act to improve the implementation of the seizure of Russian sovereign assets for the benefit of Ukraine, and for other purposes.',
#    'type': 'S',
#    'updateDate': '2025-09-20',
#    'updateDateIncludingText': '2025-09-20',
#    'url': 'https://api.congress.gov/v3/bill/119/s/2918?format=json'}],
#  'pagination': {'count': 420984,
#   'next': 'https://api.congress.gov/v3/bill?chamber=house&congress=119&pageSize=100&status=passed&type=hr&offset=20&limit=20&format=json'},
#  'request': {'contentType': 'application/json', 'format': 'json'}}

# %% [markdown]
# ### Part c
# How would you get a real-time property value estimate for a specific address, say [1 Lewis Mountain Parkway, Charlottesville, VA 22904](https://wineandcountrylife.com/featured_item/lewis-mountain/) for example, using the RentCast API? The API documentation is here: https://developers.rentcast.io/reference/introduction When calculating costs, suppose I want to repeat this for each of 25,000 Charlottesville area addresses. [12 points]

# %%
# define the API endpoints

root = "https://api.rentcast.io"
endpoint = "/v1/avm/value"

# %%
# set your API key in the headers

headers = {
    "X-Api-Key": "41a983fcd7bc49fc948931f4cd0e0c6e"  # Replace with your actual RentCast API key
}

# %%
print(headers)
# Out:
# {'X-Api-Key': '41a983fcd7bc49fc948931f4cd0e0c6e'}

# %%
# define the parameters for the API request

params = {
    "address": "1 Lewis Mountain Parkway, Charlottesville, VA 22904"
}

# %%
# Make the GET request
r = requests.get(root + endpoint, headers=headers, params = params)
r
# Out:
# <Response [200]>

# %%
r.url
# Out:
# 'https://api.rentcast.io/v1/avm/value?address=1+Lewis+Mountain+Parkway%2C+Charlottesville%2C+VA+22904'

# %%
r.json()
# Out:
# {'price': 787000,
#  'priceRangeLow': 377000,
#  'priceRangeHigh': 1198000,
#  'latitude': 38.0409156,
#  'longitude': -78.52147099999999,
#  'subjectProperty': {'id': '1-Lewis-Mountain-Pkwy,-Charlottesville,-VA-22904',
#   'formattedAddress': '1 Lewis Mountain Pkwy, Charlottesville, VA 22904',
#   'addressLine1': '1 Lewis Mountain Pkwy',
#   'addressLine2': None,
#   'city': 'Charlottesville',
#   'state': 'VA',
#   'stateFips': '51',
#   'zipCode': '22904',
#   'latitude': 38.0409156,
#   'longitude': -78.52147099999999},
#  'comparables': [{'id': '312-Foothill-Ct,-Charlottesville,-VA-22903',
#    'formattedAddress': '312 Foothill Ct, Charlottesville, VA 22903',
#    'addressLine1': '312 Foothill Ct',
#    'addressLine2': None,
#    'city': 'Charlottesville',
#    'state': 'VA',
#    'stateFips': '51',
#    'zipCode': '22903',
#    'county': 'Charlottesville',
#    'countyFips': '540',
#    'latitude': 38.043411,
#    'longitude': -78.521091,
#    'propertyType': 'Townhouse',
#    'bedrooms': 3,
#    'bathrooms': 2.5,
#    'squareFootage': 2366,
#    'lotSize': 1742,
#    'yearBuilt': 2006,
#    'status': 'Inactive',
#    'price': 699000,
#    'listingType': 'Standard',
#    'listedDate': '2025-04-01T00:00:00.000Z',
#    'removedDate': '2025-05-10T00:00:00.000Z',
#    'lastSeenDate': '2025-05-09T08:43:47.776Z',
#    'daysOnMarket': 39,
#    'distance': 0.1738,
#    'daysOld': 136,
#    'correlation': 0.99},
#   {'id': '729-Cairn-Heights-Ct,-Charlottesville,-VA-22903',
#    'formattedAddress': '729 Cairn Heights Ct, Charlottesville, VA 22903',
#    'addressLine1': '729 Cairn Heights Ct',
#    'addressLine2': None,
#    'city': 'Charlottesville',
#    'state': 'VA',
#    'stateFips': '51',
#    'zipCode': '22903',
#    'county': 'Albemarle',
#    'countyFips': '003',
#    'latitude': 38.043751,
#    'longitude': -78.521382,
#    'propertyType': 'Townhouse',
#    'bedrooms': 2,
#    'bathrooms': 2,
#    'squareFootage': 1548,
#    'lotSize': 1307,
#    'yearBuilt': 2007,
#    'status': 'Inactive',
#    'price': 479000,
#    'listingType': 'Standard',
#    'listedDate': '2025-08-29T00:00:00.000Z',
#    'removedDate': '2025-09-02T00:00:00.000Z',
#    'lastSeenDate': '2025-09-01T07:21:07.118Z',
#    'daysOnMarket': 4,
#    'distance': 0.1962,
#    'daysOld': 21,
#    'correlation': 0.99},
#   {'id': '727-Cairn-Heights-Ct,-Charlottesville,-VA-22903',
#    'formattedAddress': '727 Cairn Heights Ct, Charlottesville, VA 22903',
#    'addressLine1': '727 Cairn Heights Ct',
#    'addressLine2': None,
#    'city': 'Charlottesville',
#    'state': 'VA',
#    'stateFips': '51',
#    'zipCode': '22903',
#    'county': 'Albemarle',
#    'countyFips': '003',
#    'latitude': 38.043781,
#    'longitude': -78.521318,
#    'propertyType': 'Townhouse',
#    'bedrooms': 4,
#    'bathrooms': 3.5,
#    'squareFootage': 2843,
#    'lotSize': 1742,
#    'yearBuilt': 2007,
#    'status': 'Inactive',
#    'price': 795000,
#    'listingType': 'Standard',
#    'listedDate': '2025-08-29T00:00:00.000Z',
#    'removedDate': '2025-09-03T00:00:00.000Z',
#    'lastSeenDate': '2025-09-02T06:28:19.893Z',
#    'daysOnMarket': 5,
#    'distance': 0.1984,
#    'daysOld': 20,
#    'correlation': 0.9899},
#   {'id': '408-Samara-Ct,-Charlottesville,-VA-22903',
#    'formattedAddress': '408 Samara Ct, Charlottesville, VA 22903',
#    'addressLine1': '408 Samara Ct',
#    'addressLine2': None,
#    'city': 'Charlottesville',
#    'state': 'VA',
#    'stateFips': '51',
#    'zipCode': '22903',
#    'county': 'Albemarle',
#    'countyFips': '003',
#    'latitude': 38.043575,
#    'longitude': -78.519491,
#    'propertyType': 'Townhouse',
#    'bedrooms': 3,
#    'bathrooms': 3.5,
#    'squareFootage': 2204,
#    'lotSize': 1742,
#    'yearBuilt': 2011,
#    'status': 'Inactive',
#    'price': 630000,
#    'listingType': 'Standard',
#    'listedDate': '2025-02-28T00:00:00.000Z',
#    'removedDate': '2025-03-27T00:00:00.000Z',
#    'lastSeenDate': '2025-03-26T08:49:44.830Z',
#    'daysOnMarket': 27,
#    'distance': 0.2132,
#    'daysOld': 180,
#    'correlation': 0.9876},
#   {'id': '114-Harvest-Dr,-Charlottesville,-VA-22903',
#    'formattedAddress': '114 Harvest Dr, Charlottesville, VA 22903',
#    'addressLine1': '114 Harvest Dr',
#    'addressLine2': None,
#    'city': 'Charlottesville',
#    'state': 'VA',
#    'stateFips': '51',
#    'zipCode': '22903',
#    'county': 'Charlottesville City',
#    'countyFips': '540',
#    'latitude': 38.047341,
#    'longitude': -78.519019,
#    'propertyType': 'Condo',
#    'bedrooms': 3,
#    'bathrooms': 3.5,
#    'squareFootage': 2392,
#    'lotSize': 436,
#    'yearBuilt': 1984,
#    'status': 'Active',
#    'price': 399900,
#    'listingType': 'Standard',
#    'listedDate': '2025-08-12T00:00:00.000Z',
#    'removedDate': None,
#    'lastSeenDate': '2025-09-21T06:42:17.550Z',
#    'daysOnMarket': 41,
#    'distance': 0.4641,
#    'daysOld': 1,
#    'correlation': 0.9768},
#   {'id': '143-Harvest-Dr,-Charlottesville,-VA-22903',
#    'formattedAddress': '143 Harvest Dr, Charlottesville, VA 22903',
#    'addressLine1': '143 Harvest Dr',
#    'addressLine2': None,
#    'city': 'Charlottesville',
#    'state': 'VA',
#    'stateFips': '51',
#    'zipCode': '22903',
#    'county': 'Albemarle',
#    'countyFips': '003',
#    'latitude': 38.048321,
#    'longitude': -78.518923,
#    'propertyType': 'Condo',
#    'bedrooms': 2,
#    'bathrooms': 2.5,
#    'squareFootage': 1626,
#    'yearBuilt': 1984,
#    'status': 'Inactive',
#    'price': 400000,
#    'listingType': 'Standard',
#    'listedDate': '2025-05-01T00:00:00.000Z',
#    'removedDate': '2025-06-01T00:00:00.000Z',
#    'lastSeenDate': '2025-05-31T08:54:35.988Z',
#    'daysOnMarket': 31,
#    'distance': 0.5307,
#    'daysOld': 114,
#    'correlation': 0.9723},
#   {'id': '326-Harvest-Dr,-Charlottesville,-VA-22903',
#    'formattedAddress': '326 Harvest Dr, Charlottesville, VA 22903',
#    'addressLine1': '326 Harvest Dr',
#    'addressLine2': None,
#    'city': 'Charlottesville',
#    'state': 'VA',
#    'stateFips': '51',
#    'zipCode': '22903',
#    'county': 'Charlottesville',
#    'countyFips': '540',
#    'latitude': 38.048727,
#    'longitude': -78.520398,
#    'propertyType': 'Condo',
#    'bedrooms': 2,
#    'bathrooms': 2,
#    'squareFootage': 1320,
#    'yearBuilt': 1979,
#    'status': 'Inactive',
#    'price': 419900,
#    'listingType': 'Standard',
#    'listedDate': '2025-03-28T00:00:00.000Z',
#    'removedDate': '2025-05-30T00:00:00.000Z',
#    'lastSeenDate': '2025-05-29T08:28:28.562Z',
#    'daysOnMarket': 63,
#    'distance': 0.5435,
#    'daysOld': 116,
#    'correlation': 0.9717},
#   {'id': '108-Bollingwood-Rd,-Charlottesville,-VA-22903',
#    'formattedAddress': '108 Bollingwood Rd, Charlottesville, VA 22903',
#    'addressLine1': '108 Bollingwood Rd',
#    'addressLine2': None,
#    'city': 'Charlottesville',
#    'state': 'VA',
#    'stateFips': '51',
#    'zipCode': '22903',
#    'county': 'Charlottesville City',
#    'countyFips': '540',
#    'latitude': 38.041082,
#    'longitude': -78.510554,
#    'propertyType': 'Single Family',
#    'bedrooms': 4,
#    'bathrooms': 5,
#    'squareFootage': 3203,
#    'lotSize': 18731,
#    'yearBuilt': 1930,
#    'status': 'Inactive',
#    'price': 1100000,
#    'listingType': 'Standard',
#    'listedDate': '2025-08-28T00:00:00.000Z',
#    'removedDate': '2025-09-04T00:00:00.000Z',
#    'lastSeenDate': '2025-09-03T05:53:54.308Z',
#    'daysOnMarket': 7,
#    'distance': 0.5948,
#    'daysOld': 19,
#    'correlation': 0.9701},
#   {'id': '500-Crestwood-Dr,-Unit-1405,-Charlottesville,-VA-22903',
#    'formattedAddress': '500 Crestwood Dr, Unit 1405, Charlottesville, VA 22903',
#    'addressLine1': '500 Crestwood Dr',
#    'addressLine2': 'Unit 1405',
#    'city': 'Charlottesville',
#    'state': 'VA',
#    'stateFips': '51',
#    'zipCode': '22903',
#    'county': 'Charlottesville City',
#    'countyFips': '540',
#    'latitude': 38.049429,
#    'longitude': -78.516711,
#    'propertyType': 'Condo',
#    'bedrooms': 1,
#    'bathrooms': 1,
#    'squareFootage': 923,
#    'yearBuilt': 1991,
#    'status': 'Inactive',
#    'price': 435000,
#    'listingType': 'Standard',
#    'listedDate': '2025-08-29T00:00:00.000Z',
#    'removedDate': '2025-09-13T00:00:00.000Z',
#    'lastSeenDate': '2025-09-12T07:23:43.864Z',
#    'daysOnMarket': 15,
#    'distance': 0.6434,
#    'daysOld': 10,
#    'correlation': 0.9677},
#   {'id': '500-Crestwood-Dr,-Unit-2306,-Charlottesville,-VA-22903',
#    'formattedAddress': '500 Crestwood Dr, Unit 2306, Charlottesville, VA 22903',
#    'addressLine1': '500 Crestwood Dr',
#    'addressLine2': 'Unit 2306',
#    'city': 'Charlottesville',
#    'state': 'VA',
#    'stateFips': '51',
#    'zipCode': '22903',
#    'county': 'Charlottesville City',
#    'countyFips': '540',
#    'latitude': 38.051234,
#    'longitude': -78.518596,
#    'propertyType': 'Condo',
#    'bedrooms': 2,
#    'bathrooms': 2,
#    'squareFootage': 1347,
#    'yearBuilt': 1994,
#    'status': 'Active',
#    'price': 565000,
#    'listingType': 'Standard',
#    'listedDate': '2025-09-04T00:00:00.000Z',
#    'removedDate': None,
#    'lastSeenDate': '2025-09-21T06:36:51.973Z',
#    'daysOnMarket': 18,
#    'distance': 0.7307,
#    'daysOld': 1,
#    'correlation': 0.9635},
#   {'id': '1917-Thomson-Rd,-Charlottesville,-VA-22903',
#    'formattedAddress': '1917 Thomson Rd, Charlottesville, VA 22903',
#    'addressLine1': '1917 Thomson Rd',
#    'addressLine2': None,
#    'city': 'Charlottesville',
#    'state': 'VA',
#    'stateFips': '51',
#    'zipCode': '22903',
#    'county': 'Charlottesville',
#    'countyFips': '540',
#    'latitude': 38.037179,
#    'longitude': -78.509382,
#    'propertyType': 'Single Family',
#    'bedrooms': 3,
#    'bathrooms': 3,
#    'squareFootage': 2506,
#    'lotSize': 13068,
#    'yearBuilt': 1941,
#    'status': 'Inactive',
#    'price': 1495000,
#    'listingType': 'Standard',
#    'listedDate': '2025-04-16T00:00:00.000Z',
#    'removedDate': '2025-04-28T00:00:00.000Z',
#    'lastSeenDate': '2025-04-27T06:41:39.048Z',
#    'daysOnMarket': 12,
#    'distance': 0.7075,
#    'daysOld': 148,
#    'correlation': 0.9632},
#   {'id': '500-Crestwood-Dr,-Unit-2203,-Charlottesville,-VA-22903',
#    'formattedAddress': '500 Crestwood Dr, Unit 2203, Charlottesville, VA 22903',
#    'addressLine1': '500 Crestwood Dr',
#    'addressLine2': 'Unit 2203',
#    'city': 'Charlottesville',
#    'state': 'VA',
#    'stateFips': '51',
#    'zipCode': '22903',
#    'county': 'Charlottesville',
#    'countyFips': '540',
#    'latitude': 38.051234,
#    'longitude': -78.518596,
#    'propertyType': 'Condo',
#    'bedrooms': 2,
#    'bathrooms': 2,
#    'squareFootage': 1347,
#    'yearBuilt': 1994,
#    'status': 'Inactive',
#    'price': 569000,
#    'listingType': 'Standard',
#    'listedDate': '2025-06-12T00:00:00.000Z',
#    'removedDate': '2025-07-04T00:00:00.000Z',
#    'lastSeenDate': '2025-07-03T08:43:32.111Z',
#    'daysOnMarket': 22,
#    'distance': 0.7307,
#    'daysOld': 81,
#    'correlation': 0.9627},
#   {'id': '15-Orchard-Rd,-Charlottesville,-VA-22903',
#    'formattedAddress': '15 Orchard Rd, Charlottesville, VA 22903',
#    'addressLine1': '15 Orchard Rd',
#    'addressLine2': None,
#    'city': 'Charlottesville',
#    'state': 'VA',
#    'stateFips': '51',
#    'zipCode': '22903',
#    'county': 'Charlottesville',
#    'countyFips': '540',
#    'latitude': 38.033502,
#    'longitude': -78.532302,
#    'propertyType': 'Single Family',
#    'bedrooms': 3,
#    'bathrooms': 2,
#    'squareFootage': 2006,
#    'lotSize': 54450,
#    'yearBuilt': 1954,
#    'status': 'Inactive',
#    'price': 1050000,
#    'listingType': 'Standard',
#    'listedDate': '2025-04-02T00:00:00.000Z',
#    'removedDate': '2025-04-04T00:00:00.000Z',
#    'lastSeenDate': '2025-04-03T07:52:04.885Z',
#    'daysOnMarket': 2,
#    'distance': 0.7818,
#    'daysOld': 172,
#    'correlation': 0.9592},
#   {'id': '2307-Price-Ave,-Charlottesville,-VA-22903',
#    'formattedAddress': '2307 Price Ave, Charlottesville, VA 22903',
#    'addressLine1': '2307 Price Ave',
#    'addressLine2': None,
#    'city': 'Charlottesville',
#    'state': 'VA',
#    'stateFips': '51',
#    'zipCode': '22903',
#    'county': 'Charlottesville City',
#    'countyFips': '540',
#    'latitude': 38.027497,
#    'longitude': -78.517165,
#    'propertyType': 'Single Family',
#    'bedrooms': 4,
#    'bathrooms': 3.5,
#    'squareFootage': 2826,
#    'lotSize': 10454,
#    'yearBuilt': 2014,
#    'status': 'Inactive',
#    'price': 925000,
#    'listingType': 'Standard',
#    'listedDate': '2025-08-14T00:00:00.000Z',
#    'removedDate': '2025-08-30T00:00:00.000Z',
#    'lastSeenDate': '2025-08-29T06:03:57.843Z',
#    'daysOnMarket': 16,
#    'distance': 0.9574,
#    'daysOld': 24,
#    'correlation': 0.9519},
#   {'id': '15-Ednam-Village-St,-Charlottesville,-VA-22903',
#    'formattedAddress': '15 Ednam Village St, Charlottesville, VA 22903',
#    'addressLine1': '15 Ednam Village St',
#    'addressLine2': None,
#    'city': 'Charlottesville',
#    'state': 'VA',
#    'stateFips': '51',
#    'zipCode': '22903',
#    'county': 'Charlottesville City',
#    'countyFips': '540',
#    'latitude': 38.04856,
#    'longitude': -78.537074,
#    'propertyType': 'Townhouse',
#    'bedrooms': 3,
#    'bathrooms': 3,
#    'squareFootage': 2916,
#    'lotSize': 4356,
#    'yearBuilt': 1969,
#    'status': 'Active',
#    'price': 1895000,
#    'listingType': 'Standard',
#    'listedDate': '2025-09-08T00:00:00.000Z',
#    'removedDate': None,
#    'lastSeenDate': '2025-09-21T06:36:51.931Z',
#    'daysOnMarket': 14,
#    'distance': 1.001,
#    'daysOld': 1,
#    'correlation': 0.9499}]}

# %%
data = r.json()
# Out:
# Estimated Value: None

# %% [markdown]
# #### Factor in the cost of scaling your API usage.
#
# Each /avm/value request costs 1 token
#
# > To query 25,000 addresses, you need 25,000 tokens
#
# > RentCast’s largest standard plan offers 15,000 tokens/month for $199
#
# Therefore, you would need a custom enterprise plan to handle 25,000 requests
#
# > Estimated cost: $300–$500/month or more, depending on negotiated pricing

# %% [markdown]
# ## Problem 2
#
# Next we'll work through the steps to access the Genius API and bring data from this API into Python.
#
# ### Part a
# Genius.com's API is documented here: https://docs.genius.com/#/getting-started-h1.
#
# Follow the same process you used in problem 1 to find the information you need to use this API. Start with learning about how to use the search endpoint to do a search for "Bob Dylan". Write briefly your findings regarding the root, endpoint, parameters, method of acquiring keys, and the method for supplying these keys during an API call. In this case, you are specifically looking for a credential called an Access Token. This API is free and has minimal restrictions, so no need to look for that information this time.
#
# (Hint: because you are just trying to pull data, and not set up access for additional registered users, look for "Access for Apps Without Users" in the Authentication section of the API documentation. You can find the "API Client management page" by clicking "Manage Clients" on the left.) [12 points]

# %%
# define the API endpoints

root = "https://api.genius.com"
endpoint = "/search"

# %%
headers = {"Authorization": "Bearer njOAgKVnDpYgAwmuR0FBIHXp1GH00sY-rH7MB78OH6hdmpiBrjo4jtzjWT9wc3Tr"}

# %%
params = {"q": "Bob Dylan"}

# %%
# Make the GET request
r = requests.get(root + endpoint, headers=headers, params = params)
r
# Out:
# <Response [200]>

# %%
r.url
# Out:
# 'https://api.genius.com/search?q=Bob+Dylan'

# %%
r.json()
# Out:
# {'meta': {'status': 200},
#  'response': {'hits': [{'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 12,
#      'api_path': '/songs/79424',
#      'artist_names': 'Bob Dylan',
#      'full_title': "Blowin' in the Wind by\xa0Bob\xa0Dylan",
#      'header_image_thumbnail_url': 'https://images.genius.com/8ad4575fda9fd49e964c4b4ac541b4a4.300x300x1.png',
#      'header_image_url': 'https://images.genius.com/8ad4575fda9fd49e964c4b4ac541b4a4.1000x1000x1.png',
#      'id': 79424,
#      'lyrics_owner_id': 73267,
#      'lyrics_state': 'complete',
#      'path': '/Bob-dylan-blowin-in-the-wind-lyrics',
#      'primary_artist_names': 'Bob Dylan',
#      'pyongs_count': 49,
#      'relationships_index_url': 'https://genius.com/Bob-dylan-blowin-in-the-wind-sample',
#      'release_date_components': {'year': 1963, 'month': 5, 'day': 27},
#      'release_date_for_display': 'May 27, 1963',
#      'release_date_with_abbreviated_month_for_display': 'May 27, 1963',
#      'song_art_image_thumbnail_url': 'https://images.genius.com/8ad4575fda9fd49e964c4b4ac541b4a4.300x300x1.png',
#      'song_art_image_url': 'https://images.genius.com/8ad4575fda9fd49e964c4b4ac541b4a4.1000x1000x1.png',
#      'stats': {'unreviewed_annotations': 0, 'hot': False, 'pageviews': 706088},
#      'title': 'Blowin’ in the Wind',
#      'title_with_featured': "Blowin' in the Wind",
#      'url': 'https://genius.com/Bob-dylan-blowin-in-the-wind-lyrics',
#      'featured_artists': [],
#      'primary_artist': {'api_path': '/artists/181',
#       'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#       'id': 181,
#       'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Bob Dylan',
#       'url': 'https://genius.com/artists/Bob-dylan'},
#      'primary_artists': [{'api_path': '/artists/181',
#        'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#        'id': 181,
#        'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#        'is_meme_verified': False,
#        'is_verified': False,
#        'name': 'Bob Dylan',
#        'url': 'https://genius.com/artists/Bob-dylan'}]}},
#    {'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 19,
#      'api_path': '/songs/62605',
#      'artist_names': 'Bob Dylan',
#      'full_title': "The Times They Are A-Changin' by\xa0Bob\xa0Dylan",
#      'header_image_thumbnail_url': 'https://images.genius.com/3f8af2a0b75202890de67fbfe572fe94.300x300x1.jpg',
#      'header_image_url': 'https://images.genius.com/3f8af2a0b75202890de67fbfe572fe94.571x571x1.jpg',
#      'id': 62605,
#      'lyrics_owner_id': 49202,
#      'lyrics_state': 'complete',
#      'path': '/Bob-dylan-the-times-they-are-a-changin-lyrics',
#      'primary_artist_names': 'Bob Dylan',
#      'pyongs_count': 44,
#      'relationships_index_url': 'https://genius.com/Bob-dylan-the-times-they-are-a-changin-sample',
#      'release_date_components': {'year': 1964, 'month': 1, 'day': 13},
#      'release_date_for_display': 'January 13, 1964',
#      'release_date_with_abbreviated_month_for_display': 'Jan. 13, 1964',
#      'song_art_image_thumbnail_url': 'https://images.genius.com/3f8af2a0b75202890de67fbfe572fe94.300x300x1.jpg',
#      'song_art_image_url': 'https://images.genius.com/3f8af2a0b75202890de67fbfe572fe94.571x571x1.jpg',
#      'stats': {'unreviewed_annotations': 4, 'hot': False, 'pageviews': 600866},
#      'title': 'The Times They Are A-Changin’',
#      'title_with_featured': "The Times They Are A-Changin'",
#      'url': 'https://genius.com/Bob-dylan-the-times-they-are-a-changin-lyrics',
#      'featured_artists': [],
#      'primary_artist': {'api_path': '/artists/181',
#       'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#       'id': 181,
#       'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Bob Dylan',
#       'url': 'https://genius.com/artists/Bob-dylan'},
#      'primary_artists': [{'api_path': '/artists/181',
#        'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#        'id': 181,
#        'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#        'is_meme_verified': False,
#        'is_verified': False,
#        'name': 'Bob Dylan',
#        'url': 'https://genius.com/artists/Bob-dylan'}]}},
#    {'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 31,
#      'api_path': '/songs/54784',
#      'artist_names': 'Bob Dylan',
#      'full_title': 'Like a Rolling Stone by\xa0Bob\xa0Dylan',
#      'header_image_thumbnail_url': 'https://images.genius.com/51cae7d22b817fa25c88b8618ad91b40.300x300x1.jpg',
#      'header_image_url': 'https://images.genius.com/51cae7d22b817fa25c88b8618ad91b40.550x550x1.jpg',
#      'id': 54784,
#      'lyrics_owner_id': 7,
#      'lyrics_state': 'complete',
#      'path': '/Bob-dylan-like-a-rolling-stone-lyrics',
#      'primary_artist_names': 'Bob Dylan',
#      'pyongs_count': 66,
#      'relationships_index_url': 'https://genius.com/Bob-dylan-like-a-rolling-stone-sample',
#      'release_date_components': {'year': 1965, 'month': 7, 'day': 20},
#      'release_date_for_display': 'July 20, 1965',
#      'release_date_with_abbreviated_month_for_display': 'Jul. 20, 1965',
#      'song_art_image_thumbnail_url': 'https://images.genius.com/51cae7d22b817fa25c88b8618ad91b40.300x300x1.jpg',
#      'song_art_image_url': 'https://images.genius.com/51cae7d22b817fa25c88b8618ad91b40.550x550x1.jpg',
#      'stats': {'unreviewed_annotations': 15,
#       'hot': False,
#       'pageviews': 586233},
#      'title': 'Like a Rolling Stone',
#      'title_with_featured': 'Like a Rolling Stone',
#      'url': 'https://genius.com/Bob-dylan-like-a-rolling-stone-lyrics',
#      'featured_artists': [],
#      'primary_artist': {'api_path': '/artists/181',
#       'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#       'id': 181,
#       'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Bob Dylan',
#       'url': 'https://genius.com/artists/Bob-dylan'},
#      'primary_artists': [{'api_path': '/artists/181',
#        'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#        'id': 181,
#        'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#        'is_meme_verified': False,
#        'is_verified': False,
#        'name': 'Bob Dylan',
#        'url': 'https://genius.com/artists/Bob-dylan'}]}},
#    {'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 15,
#      'api_path': '/songs/98664',
#      'artist_names': 'Bob Dylan',
#      'full_title': 'All Along the Watchtower by\xa0Bob\xa0Dylan',
#      'header_image_thumbnail_url': 'https://images.genius.com/40169c4a86e479f32e7a44e3ae4d85d4.300x300x1.jpg',
#      'header_image_url': 'https://images.genius.com/40169c4a86e479f32e7a44e3ae4d85d4.320x320x1.jpg',
#      'id': 98664,
#      'lyrics_owner_id': 779,
#      'lyrics_state': 'complete',
#      'path': '/Bob-dylan-all-along-the-watchtower-lyrics',
#      'primary_artist_names': 'Bob Dylan',
#      'pyongs_count': 44,
#      'relationships_index_url': 'https://genius.com/Bob-dylan-all-along-the-watchtower-sample',
#      'release_date_components': {'year': 1967, 'month': 12, 'day': 27},
#      'release_date_for_display': 'December 27, 1967',
#      'release_date_with_abbreviated_month_for_display': 'Dec. 27, 1967',
#      'song_art_image_thumbnail_url': 'https://images.genius.com/40169c4a86e479f32e7a44e3ae4d85d4.300x300x1.jpg',
#      'song_art_image_url': 'https://images.genius.com/40169c4a86e479f32e7a44e3ae4d85d4.320x320x1.jpg',
#      'stats': {'unreviewed_annotations': 0, 'hot': False, 'pageviews': 550952},
#      'title': 'All Along the Watchtower',
#      'title_with_featured': 'All Along the Watchtower',
#      'url': 'https://genius.com/Bob-dylan-all-along-the-watchtower-lyrics',
#      'featured_artists': [],
#      'primary_artist': {'api_path': '/artists/181',
#       'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#       'id': 181,
#       'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Bob Dylan',
#       'url': 'https://genius.com/artists/Bob-dylan'},
#      'primary_artists': [{'api_path': '/artists/181',
#        'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#        'id': 181,
#        'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#        'is_meme_verified': False,
#        'is_verified': False,
#        'name': 'Bob Dylan',
#        'url': 'https://genius.com/artists/Bob-dylan'}]}},
#    {'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 128,
#      'api_path': '/songs/5393247',
#      'artist_names': 'Bob Dylan',
#      'full_title': 'Murder Most Foul by\xa0Bob\xa0Dylan',
#      'header_image_thumbnail_url': 'https://images.genius.com/7fbaf838ffdf99315408faa29cb566ac.300x300x1.jpg',
#      'header_image_url': 'https://images.genius.com/7fbaf838ffdf99315408faa29cb566ac.1000x1000x1.jpg',
#      'id': 5393247,
#      'lyrics_owner_id': 3360167,
#      'lyrics_state': 'complete',
#      'path': '/Bob-dylan-murder-most-foul-lyrics',
#      'primary_artist_names': 'Bob Dylan',
#      'pyongs_count': 37,
#      'relationships_index_url': 'https://genius.com/Bob-dylan-murder-most-foul-sample',
#      'release_date_components': {'year': 2020, 'month': 3, 'day': 27},
#      'release_date_for_display': 'March 27, 2020',
#      'release_date_with_abbreviated_month_for_display': 'Mar. 27, 2020',
#      'song_art_image_thumbnail_url': 'https://images.genius.com/7fbaf838ffdf99315408faa29cb566ac.300x300x1.jpg',
#      'song_art_image_url': 'https://images.genius.com/7fbaf838ffdf99315408faa29cb566ac.1000x1000x1.jpg',
#      'stats': {'unreviewed_annotations': 40,
#       'hot': False,
#       'pageviews': 519604},
#      'title': 'Murder Most Foul',
#      'title_with_featured': 'Murder Most Foul',
#      'url': 'https://genius.com/Bob-dylan-murder-most-foul-lyrics',
#      'featured_artists': [],
#      'primary_artist': {'api_path': '/artists/181',
#       'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#       'id': 181,
#       'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Bob Dylan',
#       'url': 'https://genius.com/artists/Bob-dylan'},
#      'primary_artists': [{'api_path': '/artists/181',
#        'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#        'id': 181,
#        'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#        'is_meme_verified': False,
#        'is_verified': False,
#        'name': 'Bob Dylan',
#        'url': 'https://genius.com/artists/Bob-dylan'}]}},
#    {'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 10,
#      'api_path': '/songs/84846',
#      'artist_names': 'Bob Dylan',
#      'full_title': "Don't Think Twice, It's All Right by\xa0Bob\xa0Dylan",
#      'header_image_thumbnail_url': 'https://images.genius.com/8ad4575fda9fd49e964c4b4ac541b4a4.300x300x1.png',
#      'header_image_url': 'https://images.genius.com/8ad4575fda9fd49e964c4b4ac541b4a4.1000x1000x1.png',
#      'id': 84846,
#      'lyrics_owner_id': 125524,
#      'lyrics_state': 'complete',
#      'path': '/Bob-dylan-dont-think-twice-its-all-right-lyrics',
#      'primary_artist_names': 'Bob Dylan',
#      'pyongs_count': 31,
#      'relationships_index_url': 'https://genius.com/Bob-dylan-dont-think-twice-its-all-right-sample',
#      'release_date_components': {'year': 1963, 'month': 5, 'day': 27},
#      'release_date_for_display': 'May 27, 1963',
#      'release_date_with_abbreviated_month_for_display': 'May 27, 1963',
#      'song_art_image_thumbnail_url': 'https://images.genius.com/8ad4575fda9fd49e964c4b4ac541b4a4.300x300x1.png',
#      'song_art_image_url': 'https://images.genius.com/8ad4575fda9fd49e964c4b4ac541b4a4.1000x1000x1.png',
#      'stats': {'unreviewed_annotations': 5, 'hot': False, 'pageviews': 488074},
#      'title': 'Don’t Think Twice, It’s All Right',
#      'title_with_featured': "Don't Think Twice, It's All Right",
#      'url': 'https://genius.com/Bob-dylan-dont-think-twice-its-all-right-lyrics',
#      'featured_artists': [],
#      'primary_artist': {'api_path': '/artists/181',
#       'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#       'id': 181,
#       'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Bob Dylan',
#       'url': 'https://genius.com/artists/Bob-dylan'},
#      'primary_artists': [{'api_path': '/artists/181',
#        'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#        'id': 181,
#        'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#        'is_meme_verified': False,
#        'is_verified': False,
#        'name': 'Bob Dylan',
#        'url': 'https://genius.com/artists/Bob-dylan'}]}},
#    {'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 32,
#      'api_path': '/songs/87402',
#      'artist_names': 'Bob Dylan',
#      'full_title': 'Hurricane by\xa0Bob\xa0Dylan',
#      'header_image_thumbnail_url': 'https://images.genius.com/2df91ca57456e44cf67e1d30d25bb701.300x299x1.jpg',
#      'header_image_url': 'https://images.genius.com/2df91ca57456e44cf67e1d30d25bb701.567x566x1.jpg',
#      'id': 87402,
#      'lyrics_owner_id': 132320,
#      'lyrics_state': 'complete',
#      'path': '/Bob-dylan-hurricane-lyrics',
#      'primary_artist_names': 'Bob Dylan',
#      'pyongs_count': 27,
#      'relationships_index_url': 'https://genius.com/Bob-dylan-hurricane-sample',
#      'release_date_components': {'year': 1976, 'month': 1, 'day': 5},
#      'release_date_for_display': 'January 5, 1976',
#      'release_date_with_abbreviated_month_for_display': 'Jan. 5, 1976',
#      'song_art_image_thumbnail_url': 'https://images.genius.com/2df91ca57456e44cf67e1d30d25bb701.300x299x1.jpg',
#      'song_art_image_url': 'https://images.genius.com/2df91ca57456e44cf67e1d30d25bb701.567x566x1.jpg',
#      'stats': {'unreviewed_annotations': 7,
#       'concurrents': 2,
#       'hot': False,
#       'pageviews': 441451},
#      'title': 'Hurricane',
#      'title_with_featured': 'Hurricane',
#      'url': 'https://genius.com/Bob-dylan-hurricane-lyrics',
#      'featured_artists': [],
#      'primary_artist': {'api_path': '/artists/181',
#       'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#       'id': 181,
#       'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Bob Dylan',
#       'url': 'https://genius.com/artists/Bob-dylan'},
#      'primary_artists': [{'api_path': '/artists/181',
#        'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#        'id': 181,
#        'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#        'is_meme_verified': False,
#        'is_verified': False,
#        'name': 'Bob Dylan',
#        'url': 'https://genius.com/artists/Bob-dylan'}]}},
#    {'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 21,
#      'api_path': '/songs/224',
#      'artist_names': 'Bob Dylan',
#      'full_title': 'Subterranean Homesick Blues by\xa0Bob\xa0Dylan',
#      'header_image_thumbnail_url': 'https://images.genius.com/fccb3cb2608c837461ddab5ddd8cd31e.300x300x1.jpg',
#      'header_image_url': 'https://images.genius.com/fccb3cb2608c837461ddab5ddd8cd31e.1000x1000x1.jpg',
#      'id': 224,
#      'lyrics_owner_id': 4,
#      'lyrics_state': 'complete',
#      'path': '/Bob-dylan-subterranean-homesick-blues-lyrics',
#      'primary_artist_names': 'Bob Dylan',
#      'pyongs_count': 37,
#      'relationships_index_url': 'https://genius.com/Bob-dylan-subterranean-homesick-blues-sample',
#      'release_date_components': {'year': 1965, 'month': 3, 'day': 8},
#      'release_date_for_display': 'March 8, 1965',
#      'release_date_with_abbreviated_month_for_display': 'Mar. 8, 1965',
#      'song_art_image_thumbnail_url': 'https://images.genius.com/fccb3cb2608c837461ddab5ddd8cd31e.300x300x1.jpg',
#      'song_art_image_url': 'https://images.genius.com/fccb3cb2608c837461ddab5ddd8cd31e.1000x1000x1.jpg',
#      'stats': {'unreviewed_annotations': 2,
#       'concurrents': 2,
#       'hot': False,
#       'pageviews': 404741},
#      'title': 'Subterranean Homesick Blues',
#      'title_with_featured': 'Subterranean Homesick Blues',
#      'url': 'https://genius.com/Bob-dylan-subterranean-homesick-blues-lyrics',
#      'featured_artists': [],
#      'primary_artist': {'api_path': '/artists/181',
#       'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#       'id': 181,
#       'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Bob Dylan',
#       'url': 'https://genius.com/artists/Bob-dylan'},
#      'primary_artists': [{'api_path': '/artists/181',
#        'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#        'id': 181,
#        'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#        'is_meme_verified': False,
#        'is_verified': False,
#        'name': 'Bob Dylan',
#        'url': 'https://genius.com/artists/Bob-dylan'}]}},
#    {'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 10,
#      'api_path': '/songs/79749',
#      'artist_names': 'Bob Dylan',
#      'full_title': 'Make You Feel My Love by\xa0Bob\xa0Dylan',
#      'header_image_thumbnail_url': 'https://images.genius.com/cd0a26733cc459710d0986b7b64de8f0.300x300x1.jpg',
#      'header_image_url': 'https://images.genius.com/cd0a26733cc459710d0986b7b64de8f0.1000x1000x1.jpg',
#      'id': 79749,
#      'lyrics_owner_id': 5307,
#      'lyrics_state': 'complete',
#      'path': '/Bob-dylan-make-you-feel-my-love-lyrics',
#      'primary_artist_names': 'Bob Dylan',
#      'pyongs_count': 10,
#      'relationships_index_url': 'https://genius.com/Bob-dylan-make-you-feel-my-love-sample',
#      'release_date_components': {'year': 1997, 'month': 9, 'day': 30},
#      'release_date_for_display': 'September 30, 1997',
#      'release_date_with_abbreviated_month_for_display': 'Sep. 30, 1997',
#      'song_art_image_thumbnail_url': 'https://images.genius.com/cd0a26733cc459710d0986b7b64de8f0.300x300x1.jpg',
#      'song_art_image_url': 'https://images.genius.com/cd0a26733cc459710d0986b7b64de8f0.1000x1000x1.jpg',
#      'stats': {'unreviewed_annotations': 3, 'hot': False, 'pageviews': 391597},
#      'title': 'Make You Feel My Love',
#      'title_with_featured': 'Make You Feel My Love',
#      'url': 'https://genius.com/Bob-dylan-make-you-feel-my-love-lyrics',
#      'featured_artists': [],
#      'primary_artist': {'api_path': '/artists/181',
#       'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#       'id': 181,
#       'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Bob Dylan',
#       'url': 'https://genius.com/artists/Bob-dylan'},
#      'primary_artists': [{'api_path': '/artists/181',
#        'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#        'id': 181,
#        'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#        'is_meme_verified': False,
#        'is_verified': False,
#        'name': 'Bob Dylan',
#        'url': 'https://genius.com/artists/Bob-dylan'}]}},
#    {'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 41,
#      'api_path': '/songs/105186',
#      'artist_names': 'Bob Dylan',
#      'full_title': "A Hard Rain's A-Gonna Fall by\xa0Bob\xa0Dylan",
#      'header_image_thumbnail_url': 'https://images.genius.com/8ad4575fda9fd49e964c4b4ac541b4a4.300x300x1.png',
#      'header_image_url': 'https://images.genius.com/8ad4575fda9fd49e964c4b4ac541b4a4.1000x1000x1.png',
#      'id': 105186,
#      'lyrics_owner_id': 16,
#      'lyrics_state': 'complete',
#      'path': '/Bob-dylan-a-hard-rains-a-gonna-fall-lyrics',
#      'primary_artist_names': 'Bob Dylan',
#      'pyongs_count': 24,
#      'relationships_index_url': 'https://genius.com/Bob-dylan-a-hard-rains-a-gonna-fall-sample',
#      'release_date_components': {'year': 1963, 'month': 5, 'day': 27},
#      'release_date_for_display': 'May 27, 1963',
#      'release_date_with_abbreviated_month_for_display': 'May 27, 1963',
#      'song_art_image_thumbnail_url': 'https://images.genius.com/8ad4575fda9fd49e964c4b4ac541b4a4.300x300x1.png',
#      'song_art_image_url': 'https://images.genius.com/8ad4575fda9fd49e964c4b4ac541b4a4.1000x1000x1.png',
#      'stats': {'unreviewed_annotations': 5, 'hot': False, 'pageviews': 390349},
#      'title': 'A Hard Rain’s A-Gonna Fall',
#      'title_with_featured': "A Hard Rain's A-Gonna Fall",
#      'url': 'https://genius.com/Bob-dylan-a-hard-rains-a-gonna-fall-lyrics',
#      'featured_artists': [],
#      'primary_artist': {'api_path': '/artists/181',
#       'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#       'id': 181,
#       'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Bob Dylan',
#       'url': 'https://genius.com/artists/Bob-dylan'},
#      'primary_artists': [{'api_path': '/artists/181',
#        'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#        'id': 181,
#        'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#        'is_meme_verified': False,
#        'is_verified': False,
#        'name': 'Bob Dylan',
#        'url': 'https://genius.com/artists/Bob-dylan'}]}}]}}

# %% [markdown]
# Explanation :
#
# - The Genius API root URL is https://api.genius.com/.
#
# - To search for content like “Bob Dylan” you use the GET /search endpoint with the parameter q specifying the search term (e.g., q=Bob Dylan).
#
# - You obtain credentials by signing in to Genius, going to Manage Clients, creating an API client, and clicking “Generate Access Token” to get a Client Access Token.
#
# - This token is supplied with each request—preferably in the HTTP header as Authorization: Bearer YOUR_ACCESS_TOKEN (or alternatively as an access_token query parameter).
#
# - All responses are returned in JSON format with a top-level meta (status) and response (data).

# %% [markdown]
# ### Part b
# Create a `.env` file for this project. The easiest way to do this in VS Code is to click on File -> New File, then name the file ".env" exactly, with no additional characters.
#
# Open the .env file, copy your Genius access token into it with a name, and save it. Then use Python code to load this environmental variable and save it as a Python variable. (You can print the access token to make sure it worked, but do not allow your access token to display in your final notebook). [12 points]

# %%
pip install python-dotenv
# Out:
# Requirement already satisfied: python-dotenv in /Users/khansaamaa/miniconda3/envs/ds6001/lib/python3.13/site-packages (1.1.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
from dotenv import load_dotenv
import os

# %%
load_dotenv()
# Out:
# True

# %%
genius_token = os.getenv("GENIUS_ACCESS_TOKEN")
genius_token
# Out:
# 'njOAgKVnDpYgAwmuR0FBIHXp1GH00sY-rH7MB78OH6hdmpiBrjo4jtzjWT9wc3Tr'

# %%
# Build headers with the token
headers = {"Authorization": f"Bearer {genius_token}"}

# %%
# Set up search parameters (from Part a)
params = {"q": "Bob Dylan"}

# Make the API request
response = requests.get("https://api.genius.com/search",
                        headers=headers,
                        params=params)

# %%
# Convert to JSON
data = response.json()
data
# Out:
# {'meta': {'status': 200},
#  'response': {'hits': [{'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 12,
#      'api_path': '/songs/79424',
#      'artist_names': 'Bob Dylan',
#      'full_title': "Blowin' in the Wind by\xa0Bob\xa0Dylan",
#      'header_image_thumbnail_url': 'https://images.genius.com/8ad4575fda9fd49e964c4b4ac541b4a4.300x300x1.png',
#      'header_image_url': 'https://images.genius.com/8ad4575fda9fd49e964c4b4ac541b4a4.1000x1000x1.png',
#      'id': 79424,
#      'lyrics_owner_id': 73267,
#      'lyrics_state': 'complete',
#      'path': '/Bob-dylan-blowin-in-the-wind-lyrics',
#      'primary_artist_names': 'Bob Dylan',
#      'pyongs_count': 49,
#      'relationships_index_url': 'https://genius.com/Bob-dylan-blowin-in-the-wind-sample',
#      'release_date_components': {'year': 1963, 'month': 5, 'day': 27},
#      'release_date_for_display': 'May 27, 1963',
#      'release_date_with_abbreviated_month_for_display': 'May 27, 1963',
#      'song_art_image_thumbnail_url': 'https://images.genius.com/8ad4575fda9fd49e964c4b4ac541b4a4.300x300x1.png',
#      'song_art_image_url': 'https://images.genius.com/8ad4575fda9fd49e964c4b4ac541b4a4.1000x1000x1.png',
#      'stats': {'unreviewed_annotations': 0, 'hot': False, 'pageviews': 706089},
#      'title': 'Blowin’ in the Wind',
#      'title_with_featured': "Blowin' in the Wind",
#      'url': 'https://genius.com/Bob-dylan-blowin-in-the-wind-lyrics',
#      'featured_artists': [],
#      'primary_artist': {'api_path': '/artists/181',
#       'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#       'id': 181,
#       'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Bob Dylan',
#       'url': 'https://genius.com/artists/Bob-dylan'},
#      'primary_artists': [{'api_path': '/artists/181',
#        'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#        'id': 181,
#        'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#        'is_meme_verified': False,
#        'is_verified': False,
#        'name': 'Bob Dylan',
#        'url': 'https://genius.com/artists/Bob-dylan'}]}},
#    {'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 19,
#      'api_path': '/songs/62605',
#      'artist_names': 'Bob Dylan',
#      'full_title': "The Times They Are A-Changin' by\xa0Bob\xa0Dylan",
#      'header_image_thumbnail_url': 'https://images.genius.com/3f8af2a0b75202890de67fbfe572fe94.300x300x1.jpg',
#      'header_image_url': 'https://images.genius.com/3f8af2a0b75202890de67fbfe572fe94.571x571x1.jpg',
#      'id': 62605,
#      'lyrics_owner_id': 49202,
#      'lyrics_state': 'complete',
#      'path': '/Bob-dylan-the-times-they-are-a-changin-lyrics',
#      'primary_artist_names': 'Bob Dylan',
#      'pyongs_count': 44,
#      'relationships_index_url': 'https://genius.com/Bob-dylan-the-times-they-are-a-changin-sample',
#      'release_date_components': {'year': 1964, 'month': 1, 'day': 13},
#      'release_date_for_display': 'January 13, 1964',
#      'release_date_with_abbreviated_month_for_display': 'Jan. 13, 1964',
#      'song_art_image_thumbnail_url': 'https://images.genius.com/3f8af2a0b75202890de67fbfe572fe94.300x300x1.jpg',
#      'song_art_image_url': 'https://images.genius.com/3f8af2a0b75202890de67fbfe572fe94.571x571x1.jpg',
#      'stats': {'unreviewed_annotations': 4,
#       'concurrents': 2,
#       'hot': False,
#       'pageviews': 600868},
#      'title': 'The Times They Are A-Changin’',
#      'title_with_featured': "The Times They Are A-Changin'",
#      'url': 'https://genius.com/Bob-dylan-the-times-they-are-a-changin-lyrics',
#      'featured_artists': [],
#      'primary_artist': {'api_path': '/artists/181',
#       'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#       'id': 181,
#       'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Bob Dylan',
#       'url': 'https://genius.com/artists/Bob-dylan'},
#      'primary_artists': [{'api_path': '/artists/181',
#        'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#        'id': 181,
#        'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#        'is_meme_verified': False,
#        'is_verified': False,
#        'name': 'Bob Dylan',
#        'url': 'https://genius.com/artists/Bob-dylan'}]}},
#    {'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 31,
#      'api_path': '/songs/54784',
#      'artist_names': 'Bob Dylan',
#      'full_title': 'Like a Rolling Stone by\xa0Bob\xa0Dylan',
#      'header_image_thumbnail_url': 'https://images.genius.com/51cae7d22b817fa25c88b8618ad91b40.300x300x1.jpg',
#      'header_image_url': 'https://images.genius.com/51cae7d22b817fa25c88b8618ad91b40.550x550x1.jpg',
#      'id': 54784,
#      'lyrics_owner_id': 7,
#      'lyrics_state': 'complete',
#      'path': '/Bob-dylan-like-a-rolling-stone-lyrics',
#      'primary_artist_names': 'Bob Dylan',
#      'pyongs_count': 66,
#      'relationships_index_url': 'https://genius.com/Bob-dylan-like-a-rolling-stone-sample',
#      'release_date_components': {'year': 1965, 'month': 7, 'day': 20},
#      'release_date_for_display': 'July 20, 1965',
#      'release_date_with_abbreviated_month_for_display': 'Jul. 20, 1965',
#      'song_art_image_thumbnail_url': 'https://images.genius.com/51cae7d22b817fa25c88b8618ad91b40.300x300x1.jpg',
#      'song_art_image_url': 'https://images.genius.com/51cae7d22b817fa25c88b8618ad91b40.550x550x1.jpg',
#      'stats': {'unreviewed_annotations': 15,
#       'hot': False,
#       'pageviews': 586233},
#      'title': 'Like a Rolling Stone',
#      'title_with_featured': 'Like a Rolling Stone',
#      'url': 'https://genius.com/Bob-dylan-like-a-rolling-stone-lyrics',
#      'featured_artists': [],
#      'primary_artist': {'api_path': '/artists/181',
#       'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#       'id': 181,
#       'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Bob Dylan',
#       'url': 'https://genius.com/artists/Bob-dylan'},
#      'primary_artists': [{'api_path': '/artists/181',
#        'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#        'id': 181,
#        'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#        'is_meme_verified': False,
#        'is_verified': False,
#        'name': 'Bob Dylan',
#        'url': 'https://genius.com/artists/Bob-dylan'}]}},
#    {'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 15,
#      'api_path': '/songs/98664',
#      'artist_names': 'Bob Dylan',
#      'full_title': 'All Along the Watchtower by\xa0Bob\xa0Dylan',
#      'header_image_thumbnail_url': 'https://images.genius.com/40169c4a86e479f32e7a44e3ae4d85d4.300x300x1.jpg',
#      'header_image_url': 'https://images.genius.com/40169c4a86e479f32e7a44e3ae4d85d4.320x320x1.jpg',
#      'id': 98664,
#      'lyrics_owner_id': 779,
#      'lyrics_state': 'complete',
#      'path': '/Bob-dylan-all-along-the-watchtower-lyrics',
#      'primary_artist_names': 'Bob Dylan',
#      'pyongs_count': 44,
#      'relationships_index_url': 'https://genius.com/Bob-dylan-all-along-the-watchtower-sample',
#      'release_date_components': {'year': 1967, 'month': 12, 'day': 27},
#      'release_date_for_display': 'December 27, 1967',
#      'release_date_with_abbreviated_month_for_display': 'Dec. 27, 1967',
#      'song_art_image_thumbnail_url': 'https://images.genius.com/40169c4a86e479f32e7a44e3ae4d85d4.300x300x1.jpg',
#      'song_art_image_url': 'https://images.genius.com/40169c4a86e479f32e7a44e3ae4d85d4.320x320x1.jpg',
#      'stats': {'unreviewed_annotations': 0, 'hot': False, 'pageviews': 550952},
#      'title': 'All Along the Watchtower',
#      'title_with_featured': 'All Along the Watchtower',
#      'url': 'https://genius.com/Bob-dylan-all-along-the-watchtower-lyrics',
#      'featured_artists': [],
#      'primary_artist': {'api_path': '/artists/181',
#       'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#       'id': 181,
#       'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Bob Dylan',
#       'url': 'https://genius.com/artists/Bob-dylan'},
#      'primary_artists': [{'api_path': '/artists/181',
#        'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#        'id': 181,
#        'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#        'is_meme_verified': False,
#        'is_verified': False,
#        'name': 'Bob Dylan',
#        'url': 'https://genius.com/artists/Bob-dylan'}]}},
#    {'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 128,
#      'api_path': '/songs/5393247',
#      'artist_names': 'Bob Dylan',
#      'full_title': 'Murder Most Foul by\xa0Bob\xa0Dylan',
#      'header_image_thumbnail_url': 'https://images.genius.com/7fbaf838ffdf99315408faa29cb566ac.300x300x1.jpg',
#      'header_image_url': 'https://images.genius.com/7fbaf838ffdf99315408faa29cb566ac.1000x1000x1.jpg',
#      'id': 5393247,
#      'lyrics_owner_id': 3360167,
#      'lyrics_state': 'complete',
#      'path': '/Bob-dylan-murder-most-foul-lyrics',
#      'primary_artist_names': 'Bob Dylan',
#      'pyongs_count': 37,
#      'relationships_index_url': 'https://genius.com/Bob-dylan-murder-most-foul-sample',
#      'release_date_components': {'year': 2020, 'month': 3, 'day': 27},
#      'release_date_for_display': 'March 27, 2020',
#      'release_date_with_abbreviated_month_for_display': 'Mar. 27, 2020',
#      'song_art_image_thumbnail_url': 'https://images.genius.com/7fbaf838ffdf99315408faa29cb566ac.300x300x1.jpg',
#      'song_art_image_url': 'https://images.genius.com/7fbaf838ffdf99315408faa29cb566ac.1000x1000x1.jpg',
#      'stats': {'unreviewed_annotations': 40,
#       'hot': False,
#       'pageviews': 519604},
#      'title': 'Murder Most Foul',
#      'title_with_featured': 'Murder Most Foul',
#      'url': 'https://genius.com/Bob-dylan-murder-most-foul-lyrics',
#      'featured_artists': [],
#      'primary_artist': {'api_path': '/artists/181',
#       'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#       'id': 181,
#       'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Bob Dylan',
#       'url': 'https://genius.com/artists/Bob-dylan'},
#      'primary_artists': [{'api_path': '/artists/181',
#        'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#        'id': 181,
#        'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#        'is_meme_verified': False,
#        'is_verified': False,
#        'name': 'Bob Dylan',
#        'url': 'https://genius.com/artists/Bob-dylan'}]}},
#    {'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 10,
#      'api_path': '/songs/84846',
#      'artist_names': 'Bob Dylan',
#      'full_title': "Don't Think Twice, It's All Right by\xa0Bob\xa0Dylan",
#      'header_image_thumbnail_url': 'https://images.genius.com/8ad4575fda9fd49e964c4b4ac541b4a4.300x300x1.png',
#      'header_image_url': 'https://images.genius.com/8ad4575fda9fd49e964c4b4ac541b4a4.1000x1000x1.png',
#      'id': 84846,
#      'lyrics_owner_id': 125524,
#      'lyrics_state': 'complete',
#      'path': '/Bob-dylan-dont-think-twice-its-all-right-lyrics',
#      'primary_artist_names': 'Bob Dylan',
#      'pyongs_count': 31,
#      'relationships_index_url': 'https://genius.com/Bob-dylan-dont-think-twice-its-all-right-sample',
#      'release_date_components': {'year': 1963, 'month': 5, 'day': 27},
#      'release_date_for_display': 'May 27, 1963',
#      'release_date_with_abbreviated_month_for_display': 'May 27, 1963',
#      'song_art_image_thumbnail_url': 'https://images.genius.com/8ad4575fda9fd49e964c4b4ac541b4a4.300x300x1.png',
#      'song_art_image_url': 'https://images.genius.com/8ad4575fda9fd49e964c4b4ac541b4a4.1000x1000x1.png',
#      'stats': {'unreviewed_annotations': 5, 'hot': False, 'pageviews': 488074},
#      'title': 'Don’t Think Twice, It’s All Right',
#      'title_with_featured': "Don't Think Twice, It's All Right",
#      'url': 'https://genius.com/Bob-dylan-dont-think-twice-its-all-right-lyrics',
#      'featured_artists': [],
#      'primary_artist': {'api_path': '/artists/181',
#       'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#       'id': 181,
#       'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Bob Dylan',
#       'url': 'https://genius.com/artists/Bob-dylan'},
#      'primary_artists': [{'api_path': '/artists/181',
#        'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#        'id': 181,
#        'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#        'is_meme_verified': False,
#        'is_verified': False,
#        'name': 'Bob Dylan',
#        'url': 'https://genius.com/artists/Bob-dylan'}]}},
#    {'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 32,
#      'api_path': '/songs/87402',
#      'artist_names': 'Bob Dylan',
#      'full_title': 'Hurricane by\xa0Bob\xa0Dylan',
#      'header_image_thumbnail_url': 'https://images.genius.com/2df91ca57456e44cf67e1d30d25bb701.300x299x1.jpg',
#      'header_image_url': 'https://images.genius.com/2df91ca57456e44cf67e1d30d25bb701.567x566x1.jpg',
#      'id': 87402,
#      'lyrics_owner_id': 132320,
#      'lyrics_state': 'complete',
#      'path': '/Bob-dylan-hurricane-lyrics',
#      'primary_artist_names': 'Bob Dylan',
#      'pyongs_count': 27,
#      'relationships_index_url': 'https://genius.com/Bob-dylan-hurricane-sample',
#      'release_date_components': {'year': 1976, 'month': 1, 'day': 5},
#      'release_date_for_display': 'January 5, 1976',
#      'release_date_with_abbreviated_month_for_display': 'Jan. 5, 1976',
#      'song_art_image_thumbnail_url': 'https://images.genius.com/2df91ca57456e44cf67e1d30d25bb701.300x299x1.jpg',
#      'song_art_image_url': 'https://images.genius.com/2df91ca57456e44cf67e1d30d25bb701.567x566x1.jpg',
#      'stats': {'unreviewed_annotations': 7, 'hot': False, 'pageviews': 441453},
#      'title': 'Hurricane',
#      'title_with_featured': 'Hurricane',
#      'url': 'https://genius.com/Bob-dylan-hurricane-lyrics',
#      'featured_artists': [],
#      'primary_artist': {'api_path': '/artists/181',
#       'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#       'id': 181,
#       'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Bob Dylan',
#       'url': 'https://genius.com/artists/Bob-dylan'},
#      'primary_artists': [{'api_path': '/artists/181',
#        'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#        'id': 181,
#        'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#        'is_meme_verified': False,
#        'is_verified': False,
#        'name': 'Bob Dylan',
#        'url': 'https://genius.com/artists/Bob-dylan'}]}},
#    {'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 21,
#      'api_path': '/songs/224',
#      'artist_names': 'Bob Dylan',
#      'full_title': 'Subterranean Homesick Blues by\xa0Bob\xa0Dylan',
#      'header_image_thumbnail_url': 'https://images.genius.com/fccb3cb2608c837461ddab5ddd8cd31e.300x300x1.jpg',
#      'header_image_url': 'https://images.genius.com/fccb3cb2608c837461ddab5ddd8cd31e.1000x1000x1.jpg',
#      'id': 224,
#      'lyrics_owner_id': 4,
#      'lyrics_state': 'complete',
#      'path': '/Bob-dylan-subterranean-homesick-blues-lyrics',
#      'primary_artist_names': 'Bob Dylan',
#      'pyongs_count': 37,
#      'relationships_index_url': 'https://genius.com/Bob-dylan-subterranean-homesick-blues-sample',
#      'release_date_components': {'year': 1965, 'month': 3, 'day': 8},
#      'release_date_for_display': 'March 8, 1965',
#      'release_date_with_abbreviated_month_for_display': 'Mar. 8, 1965',
#      'song_art_image_thumbnail_url': 'https://images.genius.com/fccb3cb2608c837461ddab5ddd8cd31e.300x300x1.jpg',
#      'song_art_image_url': 'https://images.genius.com/fccb3cb2608c837461ddab5ddd8cd31e.1000x1000x1.jpg',
#      'stats': {'unreviewed_annotations': 2, 'hot': False, 'pageviews': 404742},
#      'title': 'Subterranean Homesick Blues',
#      'title_with_featured': 'Subterranean Homesick Blues',
#      'url': 'https://genius.com/Bob-dylan-subterranean-homesick-blues-lyrics',
#      'featured_artists': [],
#      'primary_artist': {'api_path': '/artists/181',
#       'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#       'id': 181,
#       'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Bob Dylan',
#       'url': 'https://genius.com/artists/Bob-dylan'},
#      'primary_artists': [{'api_path': '/artists/181',
#        'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#        'id': 181,
#        'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#        'is_meme_verified': False,
#        'is_verified': False,
#        'name': 'Bob Dylan',
#        'url': 'https://genius.com/artists/Bob-dylan'}]}},
#    {'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 10,
#      'api_path': '/songs/79749',
#      'artist_names': 'Bob Dylan',
#      'full_title': 'Make You Feel My Love by\xa0Bob\xa0Dylan',
#      'header_image_thumbnail_url': 'https://images.genius.com/cd0a26733cc459710d0986b7b64de8f0.300x300x1.jpg',
#      'header_image_url': 'https://images.genius.com/cd0a26733cc459710d0986b7b64de8f0.1000x1000x1.jpg',
#      'id': 79749,
#      'lyrics_owner_id': 5307,
#      'lyrics_state': 'complete',
#      'path': '/Bob-dylan-make-you-feel-my-love-lyrics',
#      'primary_artist_names': 'Bob Dylan',
#      'pyongs_count': 10,
#      'relationships_index_url': 'https://genius.com/Bob-dylan-make-you-feel-my-love-sample',
#      'release_date_components': {'year': 1997, 'month': 9, 'day': 30},
#      'release_date_for_display': 'September 30, 1997',
#      'release_date_with_abbreviated_month_for_display': 'Sep. 30, 1997',
#      'song_art_image_thumbnail_url': 'https://images.genius.com/cd0a26733cc459710d0986b7b64de8f0.300x300x1.jpg',
#      'song_art_image_url': 'https://images.genius.com/cd0a26733cc459710d0986b7b64de8f0.1000x1000x1.jpg',
#      'stats': {'unreviewed_annotations': 3, 'hot': False, 'pageviews': 391597},
#      'title': 'Make You Feel My Love',
#      'title_with_featured': 'Make You Feel My Love',
#      'url': 'https://genius.com/Bob-dylan-make-you-feel-my-love-lyrics',
#      'featured_artists': [],
#      'primary_artist': {'api_path': '/artists/181',
#       'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#       'id': 181,
#       'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Bob Dylan',
#       'url': 'https://genius.com/artists/Bob-dylan'},
#      'primary_artists': [{'api_path': '/artists/181',
#        'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#        'id': 181,
#        'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#        'is_meme_verified': False,
#        'is_verified': False,
#        'name': 'Bob Dylan',
#        'url': 'https://genius.com/artists/Bob-dylan'}]}},
#    {'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 41,
#      'api_path': '/songs/105186',
#      'artist_names': 'Bob Dylan',
#      'full_title': "A Hard Rain's A-Gonna Fall by\xa0Bob\xa0Dylan",
#      'header_image_thumbnail_url': 'https://images.genius.com/8ad4575fda9fd49e964c4b4ac541b4a4.300x300x1.png',
#      'header_image_url': 'https://images.genius.com/8ad4575fda9fd49e964c4b4ac541b4a4.1000x1000x1.png',
#      'id': 105186,
#      'lyrics_owner_id': 16,
#      'lyrics_state': 'complete',
#      'path': '/Bob-dylan-a-hard-rains-a-gonna-fall-lyrics',
#      'primary_artist_names': 'Bob Dylan',
#      'pyongs_count': 24,
#      'relationships_index_url': 'https://genius.com/Bob-dylan-a-hard-rains-a-gonna-fall-sample',
#      'release_date_components': {'year': 1963, 'month': 5, 'day': 27},
#      'release_date_for_display': 'May 27, 1963',
#      'release_date_with_abbreviated_month_for_display': 'May 27, 1963',
#      'song_art_image_thumbnail_url': 'https://images.genius.com/8ad4575fda9fd49e964c4b4ac541b4a4.300x300x1.png',
#      'song_art_image_url': 'https://images.genius.com/8ad4575fda9fd49e964c4b4ac541b4a4.1000x1000x1.png',
#      'stats': {'unreviewed_annotations': 5, 'hot': False, 'pageviews': 390351},
#      'title': 'A Hard Rain’s A-Gonna Fall',
#      'title_with_featured': "A Hard Rain's A-Gonna Fall",
#      'url': 'https://genius.com/Bob-dylan-a-hard-rains-a-gonna-fall-lyrics',
#      'featured_artists': [],
#      'primary_artist': {'api_path': '/artists/181',
#       'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#       'id': 181,
#       'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Bob Dylan',
#       'url': 'https://genius.com/artists/Bob-dylan'},
#      'primary_artists': [{'api_path': '/artists/181',
#        'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#        'id': 181,
#        'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#        'is_meme_verified': False,
#        'is_verified': False,
#        'name': 'Bob Dylan',
#        'url': 'https://genius.com/artists/Bob-dylan'}]}}]}}

# %% [markdown]
# ### Part c
# Using the `requests` package in Python, connect to the Genius API's /search endpoint and search for "Bob Dylan". Remember to include a dictionary under `headers` that includes your user-agent string.
#
# The output will be in JSON format. Genius's API is organized in a way that every individual artist has his or her own API endpoint with more detailed information about the artist. Display the portion of the JSON output that displays the API endpoint path for the data on Bob Dylan. (Hint: it is listed under `primary_artist` several branches down the JSON tree.) [14 points]

# %%
# 1. Load your token
load_dotenv()
genius_token = os.getenv("GENIUS_ACCESS_TOKEN")

# %%
# 2. Build headers (include user-agent string)
headers = {
    "Authorization": f"Bearer {genius_token}",
    "User-Agent": "MyPythonApp/1.0"  # you can give any descriptive UA
}

# %%
# 3. Set parameters and call the API
params = {"q": "Bob Dylan"}
url = "https://api.genius.com/search"
response = requests.get(url, headers=headers, params=params)
data = response.json()
data
# Out:
# {'meta': {'status': 200},
#  'response': {'hits': [{'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 12,
#      'api_path': '/songs/79424',
#      'artist_names': 'Bob Dylan',
#      'full_title': "Blowin' in the Wind by\xa0Bob\xa0Dylan",
#      'header_image_thumbnail_url': 'https://images.genius.com/8ad4575fda9fd49e964c4b4ac541b4a4.300x300x1.png',
#      'header_image_url': 'https://images.genius.com/8ad4575fda9fd49e964c4b4ac541b4a4.1000x1000x1.png',
#      'id': 79424,
#      'lyrics_owner_id': 73267,
#      'lyrics_state': 'complete',
#      'path': '/Bob-dylan-blowin-in-the-wind-lyrics',
#      'primary_artist_names': 'Bob Dylan',
#      'pyongs_count': 49,
#      'relationships_index_url': 'https://genius.com/Bob-dylan-blowin-in-the-wind-sample',
#      'release_date_components': {'year': 1963, 'month': 5, 'day': 27},
#      'release_date_for_display': 'May 27, 1963',
#      'release_date_with_abbreviated_month_for_display': 'May 27, 1963',
#      'song_art_image_thumbnail_url': 'https://images.genius.com/8ad4575fda9fd49e964c4b4ac541b4a4.300x300x1.png',
#      'song_art_image_url': 'https://images.genius.com/8ad4575fda9fd49e964c4b4ac541b4a4.1000x1000x1.png',
#      'stats': {'unreviewed_annotations': 0, 'hot': False, 'pageviews': 706089},
#      'title': 'Blowin’ in the Wind',
#      'title_with_featured': "Blowin' in the Wind",
#      'url': 'https://genius.com/Bob-dylan-blowin-in-the-wind-lyrics',
#      'featured_artists': [],
#      'primary_artist': {'api_path': '/artists/181',
#       'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#       'id': 181,
#       'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Bob Dylan',
#       'url': 'https://genius.com/artists/Bob-dylan'},
#      'primary_artists': [{'api_path': '/artists/181',
#        'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#        'id': 181,
#        'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#        'is_meme_verified': False,
#        'is_verified': False,
#        'name': 'Bob Dylan',
#        'url': 'https://genius.com/artists/Bob-dylan'}]}},
#    {'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 19,
#      'api_path': '/songs/62605',
#      'artist_names': 'Bob Dylan',
#      'full_title': "The Times They Are A-Changin' by\xa0Bob\xa0Dylan",
#      'header_image_thumbnail_url': 'https://images.genius.com/3f8af2a0b75202890de67fbfe572fe94.300x300x1.jpg',
#      'header_image_url': 'https://images.genius.com/3f8af2a0b75202890de67fbfe572fe94.571x571x1.jpg',
#      'id': 62605,
#      'lyrics_owner_id': 49202,
#      'lyrics_state': 'complete',
#      'path': '/Bob-dylan-the-times-they-are-a-changin-lyrics',
#      'primary_artist_names': 'Bob Dylan',
#      'pyongs_count': 44,
#      'relationships_index_url': 'https://genius.com/Bob-dylan-the-times-they-are-a-changin-sample',
#      'release_date_components': {'year': 1964, 'month': 1, 'day': 13},
#      'release_date_for_display': 'January 13, 1964',
#      'release_date_with_abbreviated_month_for_display': 'Jan. 13, 1964',
#      'song_art_image_thumbnail_url': 'https://images.genius.com/3f8af2a0b75202890de67fbfe572fe94.300x300x1.jpg',
#      'song_art_image_url': 'https://images.genius.com/3f8af2a0b75202890de67fbfe572fe94.571x571x1.jpg',
#      'stats': {'unreviewed_annotations': 4,
#       'concurrents': 2,
#       'hot': False,
#       'pageviews': 600868},
#      'title': 'The Times They Are A-Changin’',
#      'title_with_featured': "The Times They Are A-Changin'",
#      'url': 'https://genius.com/Bob-dylan-the-times-they-are-a-changin-lyrics',
#      'featured_artists': [],
#      'primary_artist': {'api_path': '/artists/181',
#       'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#       'id': 181,
#       'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Bob Dylan',
#       'url': 'https://genius.com/artists/Bob-dylan'},
#      'primary_artists': [{'api_path': '/artists/181',
#        'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#        'id': 181,
#        'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#        'is_meme_verified': False,
#        'is_verified': False,
#        'name': 'Bob Dylan',
#        'url': 'https://genius.com/artists/Bob-dylan'}]}},
#    {'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 31,
#      'api_path': '/songs/54784',
#      'artist_names': 'Bob Dylan',
#      'full_title': 'Like a Rolling Stone by\xa0Bob\xa0Dylan',
#      'header_image_thumbnail_url': 'https://images.genius.com/51cae7d22b817fa25c88b8618ad91b40.300x300x1.jpg',
#      'header_image_url': 'https://images.genius.com/51cae7d22b817fa25c88b8618ad91b40.550x550x1.jpg',
#      'id': 54784,
#      'lyrics_owner_id': 7,
#      'lyrics_state': 'complete',
#      'path': '/Bob-dylan-like-a-rolling-stone-lyrics',
#      'primary_artist_names': 'Bob Dylan',
#      'pyongs_count': 66,
#      'relationships_index_url': 'https://genius.com/Bob-dylan-like-a-rolling-stone-sample',
#      'release_date_components': {'year': 1965, 'month': 7, 'day': 20},
#      'release_date_for_display': 'July 20, 1965',
#      'release_date_with_abbreviated_month_for_display': 'Jul. 20, 1965',
#      'song_art_image_thumbnail_url': 'https://images.genius.com/51cae7d22b817fa25c88b8618ad91b40.300x300x1.jpg',
#      'song_art_image_url': 'https://images.genius.com/51cae7d22b817fa25c88b8618ad91b40.550x550x1.jpg',
#      'stats': {'unreviewed_annotations': 15,
#       'hot': False,
#       'pageviews': 586233},
#      'title': 'Like a Rolling Stone',
#      'title_with_featured': 'Like a Rolling Stone',
#      'url': 'https://genius.com/Bob-dylan-like-a-rolling-stone-lyrics',
#      'featured_artists': [],
#      'primary_artist': {'api_path': '/artists/181',
#       'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#       'id': 181,
#       'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Bob Dylan',
#       'url': 'https://genius.com/artists/Bob-dylan'},
#      'primary_artists': [{'api_path': '/artists/181',
#        'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#        'id': 181,
#        'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#        'is_meme_verified': False,
#        'is_verified': False,
#        'name': 'Bob Dylan',
#        'url': 'https://genius.com/artists/Bob-dylan'}]}},
#    {'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 15,
#      'api_path': '/songs/98664',
#      'artist_names': 'Bob Dylan',
#      'full_title': 'All Along the Watchtower by\xa0Bob\xa0Dylan',
#      'header_image_thumbnail_url': 'https://images.genius.com/40169c4a86e479f32e7a44e3ae4d85d4.300x300x1.jpg',
#      'header_image_url': 'https://images.genius.com/40169c4a86e479f32e7a44e3ae4d85d4.320x320x1.jpg',
#      'id': 98664,
#      'lyrics_owner_id': 779,
#      'lyrics_state': 'complete',
#      'path': '/Bob-dylan-all-along-the-watchtower-lyrics',
#      'primary_artist_names': 'Bob Dylan',
#      'pyongs_count': 44,
#      'relationships_index_url': 'https://genius.com/Bob-dylan-all-along-the-watchtower-sample',
#      'release_date_components': {'year': 1967, 'month': 12, 'day': 27},
#      'release_date_for_display': 'December 27, 1967',
#      'release_date_with_abbreviated_month_for_display': 'Dec. 27, 1967',
#      'song_art_image_thumbnail_url': 'https://images.genius.com/40169c4a86e479f32e7a44e3ae4d85d4.300x300x1.jpg',
#      'song_art_image_url': 'https://images.genius.com/40169c4a86e479f32e7a44e3ae4d85d4.320x320x1.jpg',
#      'stats': {'unreviewed_annotations': 0, 'hot': False, 'pageviews': 550952},
#      'title': 'All Along the Watchtower',
#      'title_with_featured': 'All Along the Watchtower',
#      'url': 'https://genius.com/Bob-dylan-all-along-the-watchtower-lyrics',
#      'featured_artists': [],
#      'primary_artist': {'api_path': '/artists/181',
#       'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#       'id': 181,
#       'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Bob Dylan',
#       'url': 'https://genius.com/artists/Bob-dylan'},
#      'primary_artists': [{'api_path': '/artists/181',
#        'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#        'id': 181,
#        'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#        'is_meme_verified': False,
#        'is_verified': False,
#        'name': 'Bob Dylan',
#        'url': 'https://genius.com/artists/Bob-dylan'}]}},
#    {'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 128,
#      'api_path': '/songs/5393247',
#      'artist_names': 'Bob Dylan',
#      'full_title': 'Murder Most Foul by\xa0Bob\xa0Dylan',
#      'header_image_thumbnail_url': 'https://images.genius.com/7fbaf838ffdf99315408faa29cb566ac.300x300x1.jpg',
#      'header_image_url': 'https://images.genius.com/7fbaf838ffdf99315408faa29cb566ac.1000x1000x1.jpg',
#      'id': 5393247,
#      'lyrics_owner_id': 3360167,
#      'lyrics_state': 'complete',
#      'path': '/Bob-dylan-murder-most-foul-lyrics',
#      'primary_artist_names': 'Bob Dylan',
#      'pyongs_count': 37,
#      'relationships_index_url': 'https://genius.com/Bob-dylan-murder-most-foul-sample',
#      'release_date_components': {'year': 2020, 'month': 3, 'day': 27},
#      'release_date_for_display': 'March 27, 2020',
#      'release_date_with_abbreviated_month_for_display': 'Mar. 27, 2020',
#      'song_art_image_thumbnail_url': 'https://images.genius.com/7fbaf838ffdf99315408faa29cb566ac.300x300x1.jpg',
#      'song_art_image_url': 'https://images.genius.com/7fbaf838ffdf99315408faa29cb566ac.1000x1000x1.jpg',
#      'stats': {'unreviewed_annotations': 40,
#       'hot': False,
#       'pageviews': 519604},
#      'title': 'Murder Most Foul',
#      'title_with_featured': 'Murder Most Foul',
#      'url': 'https://genius.com/Bob-dylan-murder-most-foul-lyrics',
#      'featured_artists': [],
#      'primary_artist': {'api_path': '/artists/181',
#       'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#       'id': 181,
#       'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Bob Dylan',
#       'url': 'https://genius.com/artists/Bob-dylan'},
#      'primary_artists': [{'api_path': '/artists/181',
#        'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#        'id': 181,
#        'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#        'is_meme_verified': False,
#        'is_verified': False,
#        'name': 'Bob Dylan',
#        'url': 'https://genius.com/artists/Bob-dylan'}]}},
#    {'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 10,
#      'api_path': '/songs/84846',
#      'artist_names': 'Bob Dylan',
#      'full_title': "Don't Think Twice, It's All Right by\xa0Bob\xa0Dylan",
#      'header_image_thumbnail_url': 'https://images.genius.com/8ad4575fda9fd49e964c4b4ac541b4a4.300x300x1.png',
#      'header_image_url': 'https://images.genius.com/8ad4575fda9fd49e964c4b4ac541b4a4.1000x1000x1.png',
#      'id': 84846,
#      'lyrics_owner_id': 125524,
#      'lyrics_state': 'complete',
#      'path': '/Bob-dylan-dont-think-twice-its-all-right-lyrics',
#      'primary_artist_names': 'Bob Dylan',
#      'pyongs_count': 31,
#      'relationships_index_url': 'https://genius.com/Bob-dylan-dont-think-twice-its-all-right-sample',
#      'release_date_components': {'year': 1963, 'month': 5, 'day': 27},
#      'release_date_for_display': 'May 27, 1963',
#      'release_date_with_abbreviated_month_for_display': 'May 27, 1963',
#      'song_art_image_thumbnail_url': 'https://images.genius.com/8ad4575fda9fd49e964c4b4ac541b4a4.300x300x1.png',
#      'song_art_image_url': 'https://images.genius.com/8ad4575fda9fd49e964c4b4ac541b4a4.1000x1000x1.png',
#      'stats': {'unreviewed_annotations': 5, 'hot': False, 'pageviews': 488074},
#      'title': 'Don’t Think Twice, It’s All Right',
#      'title_with_featured': "Don't Think Twice, It's All Right",
#      'url': 'https://genius.com/Bob-dylan-dont-think-twice-its-all-right-lyrics',
#      'featured_artists': [],
#      'primary_artist': {'api_path': '/artists/181',
#       'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#       'id': 181,
#       'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Bob Dylan',
#       'url': 'https://genius.com/artists/Bob-dylan'},
#      'primary_artists': [{'api_path': '/artists/181',
#        'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#        'id': 181,
#        'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#        'is_meme_verified': False,
#        'is_verified': False,
#        'name': 'Bob Dylan',
#        'url': 'https://genius.com/artists/Bob-dylan'}]}},
#    {'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 32,
#      'api_path': '/songs/87402',
#      'artist_names': 'Bob Dylan',
#      'full_title': 'Hurricane by\xa0Bob\xa0Dylan',
#      'header_image_thumbnail_url': 'https://images.genius.com/2df91ca57456e44cf67e1d30d25bb701.300x299x1.jpg',
#      'header_image_url': 'https://images.genius.com/2df91ca57456e44cf67e1d30d25bb701.567x566x1.jpg',
#      'id': 87402,
#      'lyrics_owner_id': 132320,
#      'lyrics_state': 'complete',
#      'path': '/Bob-dylan-hurricane-lyrics',
#      'primary_artist_names': 'Bob Dylan',
#      'pyongs_count': 27,
#      'relationships_index_url': 'https://genius.com/Bob-dylan-hurricane-sample',
#      'release_date_components': {'year': 1976, 'month': 1, 'day': 5},
#      'release_date_for_display': 'January 5, 1976',
#      'release_date_with_abbreviated_month_for_display': 'Jan. 5, 1976',
#      'song_art_image_thumbnail_url': 'https://images.genius.com/2df91ca57456e44cf67e1d30d25bb701.300x299x1.jpg',
#      'song_art_image_url': 'https://images.genius.com/2df91ca57456e44cf67e1d30d25bb701.567x566x1.jpg',
#      'stats': {'unreviewed_annotations': 7, 'hot': False, 'pageviews': 441453},
#      'title': 'Hurricane',
#      'title_with_featured': 'Hurricane',
#      'url': 'https://genius.com/Bob-dylan-hurricane-lyrics',
#      'featured_artists': [],
#      'primary_artist': {'api_path': '/artists/181',
#       'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#       'id': 181,
#       'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Bob Dylan',
#       'url': 'https://genius.com/artists/Bob-dylan'},
#      'primary_artists': [{'api_path': '/artists/181',
#        'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#        'id': 181,
#        'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#        'is_meme_verified': False,
#        'is_verified': False,
#        'name': 'Bob Dylan',
#        'url': 'https://genius.com/artists/Bob-dylan'}]}},
#    {'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 21,
#      'api_path': '/songs/224',
#      'artist_names': 'Bob Dylan',
#      'full_title': 'Subterranean Homesick Blues by\xa0Bob\xa0Dylan',
#      'header_image_thumbnail_url': 'https://images.genius.com/fccb3cb2608c837461ddab5ddd8cd31e.300x300x1.jpg',
#      'header_image_url': 'https://images.genius.com/fccb3cb2608c837461ddab5ddd8cd31e.1000x1000x1.jpg',
#      'id': 224,
#      'lyrics_owner_id': 4,
#      'lyrics_state': 'complete',
#      'path': '/Bob-dylan-subterranean-homesick-blues-lyrics',
#      'primary_artist_names': 'Bob Dylan',
#      'pyongs_count': 37,
#      'relationships_index_url': 'https://genius.com/Bob-dylan-subterranean-homesick-blues-sample',
#      'release_date_components': {'year': 1965, 'month': 3, 'day': 8},
#      'release_date_for_display': 'March 8, 1965',
#      'release_date_with_abbreviated_month_for_display': 'Mar. 8, 1965',
#      'song_art_image_thumbnail_url': 'https://images.genius.com/fccb3cb2608c837461ddab5ddd8cd31e.300x300x1.jpg',
#      'song_art_image_url': 'https://images.genius.com/fccb3cb2608c837461ddab5ddd8cd31e.1000x1000x1.jpg',
#      'stats': {'unreviewed_annotations': 2, 'hot': False, 'pageviews': 404742},
#      'title': 'Subterranean Homesick Blues',
#      'title_with_featured': 'Subterranean Homesick Blues',
#      'url': 'https://genius.com/Bob-dylan-subterranean-homesick-blues-lyrics',
#      'featured_artists': [],
#      'primary_artist': {'api_path': '/artists/181',
#       'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#       'id': 181,
#       'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Bob Dylan',
#       'url': 'https://genius.com/artists/Bob-dylan'},
#      'primary_artists': [{'api_path': '/artists/181',
#        'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#        'id': 181,
#        'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#        'is_meme_verified': False,
#        'is_verified': False,
#        'name': 'Bob Dylan',
#        'url': 'https://genius.com/artists/Bob-dylan'}]}},
#    {'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 10,
#      'api_path': '/songs/79749',
#      'artist_names': 'Bob Dylan',
#      'full_title': 'Make You Feel My Love by\xa0Bob\xa0Dylan',
#      'header_image_thumbnail_url': 'https://images.genius.com/cd0a26733cc459710d0986b7b64de8f0.300x300x1.jpg',
#      'header_image_url': 'https://images.genius.com/cd0a26733cc459710d0986b7b64de8f0.1000x1000x1.jpg',
#      'id': 79749,
#      'lyrics_owner_id': 5307,
#      'lyrics_state': 'complete',
#      'path': '/Bob-dylan-make-you-feel-my-love-lyrics',
#      'primary_artist_names': 'Bob Dylan',
#      'pyongs_count': 10,
#      'relationships_index_url': 'https://genius.com/Bob-dylan-make-you-feel-my-love-sample',
#      'release_date_components': {'year': 1997, 'month': 9, 'day': 30},
#      'release_date_for_display': 'September 30, 1997',
#      'release_date_with_abbreviated_month_for_display': 'Sep. 30, 1997',
#      'song_art_image_thumbnail_url': 'https://images.genius.com/cd0a26733cc459710d0986b7b64de8f0.300x300x1.jpg',
#      'song_art_image_url': 'https://images.genius.com/cd0a26733cc459710d0986b7b64de8f0.1000x1000x1.jpg',
#      'stats': {'unreviewed_annotations': 3, 'hot': False, 'pageviews': 391597},
#      'title': 'Make You Feel My Love',
#      'title_with_featured': 'Make You Feel My Love',
#      'url': 'https://genius.com/Bob-dylan-make-you-feel-my-love-lyrics',
#      'featured_artists': [],
#      'primary_artist': {'api_path': '/artists/181',
#       'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#       'id': 181,
#       'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Bob Dylan',
#       'url': 'https://genius.com/artists/Bob-dylan'},
#      'primary_artists': [{'api_path': '/artists/181',
#        'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#        'id': 181,
#        'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#        'is_meme_verified': False,
#        'is_verified': False,
#        'name': 'Bob Dylan',
#        'url': 'https://genius.com/artists/Bob-dylan'}]}},
#    {'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 41,
#      'api_path': '/songs/105186',
#      'artist_names': 'Bob Dylan',
#      'full_title': "A Hard Rain's A-Gonna Fall by\xa0Bob\xa0Dylan",
#      'header_image_thumbnail_url': 'https://images.genius.com/8ad4575fda9fd49e964c4b4ac541b4a4.300x300x1.png',
#      'header_image_url': 'https://images.genius.com/8ad4575fda9fd49e964c4b4ac541b4a4.1000x1000x1.png',
#      'id': 105186,
#      'lyrics_owner_id': 16,
#      'lyrics_state': 'complete',
#      'path': '/Bob-dylan-a-hard-rains-a-gonna-fall-lyrics',
#      'primary_artist_names': 'Bob Dylan',
#      'pyongs_count': 24,
#      'relationships_index_url': 'https://genius.com/Bob-dylan-a-hard-rains-a-gonna-fall-sample',
#      'release_date_components': {'year': 1963, 'month': 5, 'day': 27},
#      'release_date_for_display': 'May 27, 1963',
#      'release_date_with_abbreviated_month_for_display': 'May 27, 1963',
#      'song_art_image_thumbnail_url': 'https://images.genius.com/8ad4575fda9fd49e964c4b4ac541b4a4.300x300x1.png',
#      'song_art_image_url': 'https://images.genius.com/8ad4575fda9fd49e964c4b4ac541b4a4.1000x1000x1.png',
#      'stats': {'unreviewed_annotations': 5, 'hot': False, 'pageviews': 390351},
#      'title': 'A Hard Rain’s A-Gonna Fall',
#      'title_with_featured': "A Hard Rain's A-Gonna Fall",
#      'url': 'https://genius.com/Bob-dylan-a-hard-rains-a-gonna-fall-lyrics',
#      'featured_artists': [],
#      'primary_artist': {'api_path': '/artists/181',
#       'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#       'id': 181,
#       'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Bob Dylan',
#       'url': 'https://genius.com/artists/Bob-dylan'},
#      'primary_artists': [{'api_path': '/artists/181',
#        'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#        'id': 181,
#        'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#        'is_meme_verified': False,
#        'is_verified': False,
#        'name': 'Bob Dylan',
#        'url': 'https://genius.com/artists/Bob-dylan'}]}}]}}

# %%
# 4. Inspect the JSON structure for Bob Dylan’s primary_artist api_path
# Typically the first hit is Bob Dylan:
hits = data['response']['hits']

for hit in hits:
    artist = hit['result']['primary_artist']
    name = artist['name']
    if name.lower() == 'bob dylan':
        print("Bob Dylan API path:", artist['api_path'])
        break
# Out:
# Bob Dylan API path: /artists/181

# %% [markdown]
# ### Part d
# Add `/songs` to the end of the the endpoint path you found in problem 3 and use this path to request the 20 most popular songs written by Bob Dylan (some of these may be performed by other artists because Dylan is one of the most frequently covered musicians of all time). Organize these data in a `pandas` data frame. [14 points]

# %%
root = "https://api.genius.com"
endpoint = "/artists/181/songs"

# %%
params = {
    "sort": "popularity",
    "per_page": 20
}

# %%
response = requests.get(root + endpoint, headers=headers, params = params)
response
# Out:
# <Response [200]>

# %%
r.url
# Out:
# 'https://api.genius.com/artists/181/songs?sort=popularity&per_page=20'

# %%
data =response.json()
data
# Out:
# {'meta': {'status': 200},
#  'response': {'songs': [{'annotation_count': 15,
#     'api_path': '/songs/96286',
#     'artist_names': 'USA For Africa',
#     'full_title': 'We Are the World by\xa0USA\xa0For Africa',
#     'header_image_thumbnail_url': 'https://images.genius.com/d328397b28953bd84465cd582e71271d.300x300x1.jpg',
#     'header_image_url': 'https://images.genius.com/d328397b28953bd84465cd582e71271d.1000x1000x1.jpg',
#     'id': 96286,
#     'lyrics_owner_id': 4733728,
#     'lyrics_state': 'complete',
#     'path': '/Usa-for-africa-we-are-the-world-lyrics',
#     'primary_artist_names': 'USA For Africa',
#     'pyongs_count': 35,
#     'relationships_index_url': 'https://genius.com/Usa-for-africa-we-are-the-world-sample',
#     'release_date_components': {'year': 1985, 'month': 3, 'day': 7},
#     'release_date_for_display': 'March 7, 1985',
#     'release_date_with_abbreviated_month_for_display': 'Mar. 7, 1985',
#     'song_art_image_thumbnail_url': 'https://images.genius.com/d328397b28953bd84465cd582e71271d.300x300x1.jpg',
#     'song_art_image_url': 'https://images.genius.com/d328397b28953bd84465cd582e71271d.1000x1000x1.jpg',
#     'stats': {'unreviewed_annotations': 0,
#      'concurrents': 2,
#      'hot': False,
#      'pageviews': 837056},
#     'title': 'We Are the World',
#     'title_with_featured': 'We Are the World',
#     'url': 'https://genius.com/Usa-for-africa-we-are-the-world-lyrics',
#     'featured_artists': [],
#     'primary_artist': {'api_path': '/artists/370890',
#      'header_image_url': 'https://images.genius.com/3fb2d9f68c911b5473399b97ef9427e6.768x768x1.jpg',
#      'id': 370890,
#      'image_url': 'https://images.genius.com/3fb2d9f68c911b5473399b97ef9427e6.768x768x1.jpg',
#      'is_meme_verified': False,
#      'is_verified': False,
#      'name': 'USA For Africa',
#      'url': 'https://genius.com/artists/Usa-for-africa'},
#     'primary_artists': [{'api_path': '/artists/370890',
#       'header_image_url': 'https://images.genius.com/3fb2d9f68c911b5473399b97ef9427e6.768x768x1.jpg',
#       'id': 370890,
#       'image_url': 'https://images.genius.com/3fb2d9f68c911b5473399b97ef9427e6.768x768x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'USA For Africa',
#       'url': 'https://genius.com/artists/Usa-for-africa'}]},
#    {'annotation_count': 12,
#     'api_path': '/songs/79424',
#     'artist_names': 'Bob Dylan',
#     'full_title': "Blowin' in the Wind by\xa0Bob\xa0Dylan",
#     'header_image_thumbnail_url': 'https://images.genius.com/8ad4575fda9fd49e964c4b4ac541b4a4.300x300x1.png',
#     'header_image_url': 'https://images.genius.com/8ad4575fda9fd49e964c4b4ac541b4a4.1000x1000x1.png',
#     'id': 79424,
#     'lyrics_owner_id': 73267,
#     'lyrics_state': 'complete',
#     'path': '/Bob-dylan-blowin-in-the-wind-lyrics',
#     'primary_artist_names': 'Bob Dylan',
#     'pyongs_count': 49,
#     'relationships_index_url': 'https://genius.com/Bob-dylan-blowin-in-the-wind-sample',
#     'release_date_components': {'year': 1963, 'month': 5, 'day': 27},
#     'release_date_for_display': 'May 27, 1963',
#     'release_date_with_abbreviated_month_for_display': 'May 27, 1963',
#     'song_art_image_thumbnail_url': 'https://images.genius.com/8ad4575fda9fd49e964c4b4ac541b4a4.300x300x1.png',
#     'song_art_image_url': 'https://images.genius.com/8ad4575fda9fd49e964c4b4ac541b4a4.1000x1000x1.png',
#     'stats': {'unreviewed_annotations': 0,
#      'concurrents': 2,
#      'hot': False,
#      'pageviews': 706090},
#     'title': 'Blowin’ in the Wind',
#     'title_with_featured': "Blowin' in the Wind",
#     'url': 'https://genius.com/Bob-dylan-blowin-in-the-wind-lyrics',
#     'featured_artists': [],
#     'primary_artist': {'api_path': '/artists/181',
#      'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#      'id': 181,
#      'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#      'is_meme_verified': False,
#      'is_verified': False,
#      'name': 'Bob Dylan',
#      'url': 'https://genius.com/artists/Bob-dylan'},
#     'primary_artists': [{'api_path': '/artists/181',
#       'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#       'id': 181,
#       'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Bob Dylan',
#       'url': 'https://genius.com/artists/Bob-dylan'}]},
#    {'annotation_count': 3,
#     'api_path': '/songs/68146',
#     'artist_names': 'Adele',
#     'full_title': 'Make You Feel My Love by\xa0Adele',
#     'header_image_thumbnail_url': 'https://images.genius.com/f248cc85ccaab603ce88832109b21bb8.300x300x1.png',
#     'header_image_url': 'https://images.genius.com/f248cc85ccaab603ce88832109b21bb8.1000x1000x1.png',
#     'id': 68146,
#     'lyrics_owner_id': 82481,
#     'lyrics_state': 'complete',
#     'path': '/Adele-make-you-feel-my-love-lyrics',
#     'primary_artist_names': 'Adele',
#     'pyongs_count': 53,
#     'relationships_index_url': 'https://genius.com/Adele-make-you-feel-my-love-sample',
#     'release_date_components': {'year': 2008, 'month': 10, 'day': 27},
#     'release_date_for_display': 'October 27, 2008',
#     'release_date_with_abbreviated_month_for_display': 'Oct. 27, 2008',
#     'song_art_image_thumbnail_url': 'https://images.genius.com/f248cc85ccaab603ce88832109b21bb8.300x300x1.png',
#     'song_art_image_url': 'https://images.genius.com/f248cc85ccaab603ce88832109b21bb8.1000x1000x1.png',
#     'stats': {'unreviewed_annotations': 2,
#      'concurrents': 2,
#      'hot': False,
#      'pageviews': 689276},
#     'title': 'Make You Feel My Love',
#     'title_with_featured': 'Make You Feel My Love',
#     'url': 'https://genius.com/Adele-make-you-feel-my-love-lyrics',
#     'featured_artists': [],
#     'primary_artist': {'api_path': '/artists/2300',
#      'header_image_url': 'https://images.genius.com/87aa5d8c32965a10e0e7ad1acb54ba40.1000x287x6.gif',
#      'id': 2300,
#      'image_url': 'https://images.genius.com/8a23ab928ccfce13accfde72f1290702.1000x1000x1.jpg',
#      'is_meme_verified': False,
#      'is_verified': False,
#      'name': 'Adele',
#      'url': 'https://genius.com/artists/Adele'},
#     'primary_artists': [{'api_path': '/artists/2300',
#       'header_image_url': 'https://images.genius.com/87aa5d8c32965a10e0e7ad1acb54ba40.1000x287x6.gif',
#       'id': 2300,
#       'image_url': 'https://images.genius.com/8a23ab928ccfce13accfde72f1290702.1000x1000x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Adele',
#       'url': 'https://genius.com/artists/Adele'}]},
#    {'annotation_count': 19,
#     'api_path': '/songs/62605',
#     'artist_names': 'Bob Dylan',
#     'full_title': "The Times They Are A-Changin' by\xa0Bob\xa0Dylan",
#     'header_image_thumbnail_url': 'https://images.genius.com/3f8af2a0b75202890de67fbfe572fe94.300x300x1.jpg',
#     'header_image_url': 'https://images.genius.com/3f8af2a0b75202890de67fbfe572fe94.571x571x1.jpg',
#     'id': 62605,
#     'lyrics_owner_id': 49202,
#     'lyrics_state': 'complete',
#     'path': '/Bob-dylan-the-times-they-are-a-changin-lyrics',
#     'primary_artist_names': 'Bob Dylan',
#     'pyongs_count': 44,
#     'relationships_index_url': 'https://genius.com/Bob-dylan-the-times-they-are-a-changin-sample',
#     'release_date_components': {'year': 1964, 'month': 1, 'day': 13},
#     'release_date_for_display': 'January 13, 1964',
#     'release_date_with_abbreviated_month_for_display': 'Jan. 13, 1964',
#     'song_art_image_thumbnail_url': 'https://images.genius.com/3f8af2a0b75202890de67fbfe572fe94.300x300x1.jpg',
#     'song_art_image_url': 'https://images.genius.com/3f8af2a0b75202890de67fbfe572fe94.571x571x1.jpg',
#     'stats': {'unreviewed_annotations': 4, 'hot': False, 'pageviews': 600869},
#     'title': 'The Times They Are A-Changin’',
#     'title_with_featured': "The Times They Are A-Changin'",
#     'url': 'https://genius.com/Bob-dylan-the-times-they-are-a-changin-lyrics',
#     'featured_artists': [],
#     'primary_artist': {'api_path': '/artists/181',
#      'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#      'id': 181,
#      'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#      'is_meme_verified': False,
#      'is_verified': False,
#      'name': 'Bob Dylan',
#      'url': 'https://genius.com/artists/Bob-dylan'},
#     'primary_artists': [{'api_path': '/artists/181',
#       'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#       'id': 181,
#       'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Bob Dylan',
#       'url': 'https://genius.com/artists/Bob-dylan'}]},
#    {'annotation_count': 31,
#     'api_path': '/songs/54784',
#     'artist_names': 'Bob Dylan',
#     'full_title': 'Like a Rolling Stone by\xa0Bob\xa0Dylan',
#     'header_image_thumbnail_url': 'https://images.genius.com/51cae7d22b817fa25c88b8618ad91b40.300x300x1.jpg',
#     'header_image_url': 'https://images.genius.com/51cae7d22b817fa25c88b8618ad91b40.550x550x1.jpg',
#     'id': 54784,
#     'lyrics_owner_id': 7,
#     'lyrics_state': 'complete',
#     'path': '/Bob-dylan-like-a-rolling-stone-lyrics',
#     'primary_artist_names': 'Bob Dylan',
#     'pyongs_count': 66,
#     'relationships_index_url': 'https://genius.com/Bob-dylan-like-a-rolling-stone-sample',
#     'release_date_components': {'year': 1965, 'month': 7, 'day': 20},
#     'release_date_for_display': 'July 20, 1965',
#     'release_date_with_abbreviated_month_for_display': 'Jul. 20, 1965',
#     'song_art_image_thumbnail_url': 'https://images.genius.com/51cae7d22b817fa25c88b8618ad91b40.300x300x1.jpg',
#     'song_art_image_url': 'https://images.genius.com/51cae7d22b817fa25c88b8618ad91b40.550x550x1.jpg',
#     'stats': {'unreviewed_annotations': 15, 'hot': False, 'pageviews': 586233},
#     'title': 'Like a Rolling Stone',
#     'title_with_featured': 'Like a Rolling Stone',
#     'url': 'https://genius.com/Bob-dylan-like-a-rolling-stone-lyrics',
#     'featured_artists': [],
#     'primary_artist': {'api_path': '/artists/181',
#      'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#      'id': 181,
#      'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#      'is_meme_verified': False,
#      'is_verified': False,
#      'name': 'Bob Dylan',
#      'url': 'https://genius.com/artists/Bob-dylan'},
#     'primary_artists': [{'api_path': '/artists/181',
#       'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#       'id': 181,
#       'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Bob Dylan',
#       'url': 'https://genius.com/artists/Bob-dylan'}]},
#    {'annotation_count': 15,
#     'api_path': '/songs/98664',
#     'artist_names': 'Bob Dylan',
#     'full_title': 'All Along the Watchtower by\xa0Bob\xa0Dylan',
#     'header_image_thumbnail_url': 'https://images.genius.com/40169c4a86e479f32e7a44e3ae4d85d4.300x300x1.jpg',
#     'header_image_url': 'https://images.genius.com/40169c4a86e479f32e7a44e3ae4d85d4.320x320x1.jpg',
#     'id': 98664,
#     'lyrics_owner_id': 779,
#     'lyrics_state': 'complete',
#     'path': '/Bob-dylan-all-along-the-watchtower-lyrics',
#     'primary_artist_names': 'Bob Dylan',
#     'pyongs_count': 44,
#     'relationships_index_url': 'https://genius.com/Bob-dylan-all-along-the-watchtower-sample',
#     'release_date_components': {'year': 1967, 'month': 12, 'day': 27},
#     'release_date_for_display': 'December 27, 1967',
#     'release_date_with_abbreviated_month_for_display': 'Dec. 27, 1967',
#     'song_art_image_thumbnail_url': 'https://images.genius.com/40169c4a86e479f32e7a44e3ae4d85d4.300x300x1.jpg',
#     'song_art_image_url': 'https://images.genius.com/40169c4a86e479f32e7a44e3ae4d85d4.320x320x1.jpg',
#     'stats': {'unreviewed_annotations': 0,
#      'concurrents': 2,
#      'hot': False,
#      'pageviews': 550954},
#     'title': 'All Along the Watchtower',
#     'title_with_featured': 'All Along the Watchtower',
#     'url': 'https://genius.com/Bob-dylan-all-along-the-watchtower-lyrics',
#     'featured_artists': [],
#     'primary_artist': {'api_path': '/artists/181',
#      'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#      'id': 181,
#      'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#      'is_meme_verified': False,
#      'is_verified': False,
#      'name': 'Bob Dylan',
#      'url': 'https://genius.com/artists/Bob-dylan'},
#     'primary_artists': [{'api_path': '/artists/181',
#       'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#       'id': 181,
#       'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Bob Dylan',
#       'url': 'https://genius.com/artists/Bob-dylan'}]},
#    {'annotation_count': 7,
#     'api_path': '/songs/103982',
#     'artist_names': "Guns N' Roses",
#     'full_title': "Knockin’ on Heaven’s Door by\xa0Guns\xa0N' Roses",
#     'header_image_thumbnail_url': 'https://images.genius.com/cb2614550098bf753ab31c1f4a758686.300x300x1.jpg',
#     'header_image_url': 'https://images.genius.com/cb2614550098bf753ab31c1f4a758686.770x770x1.jpg',
#     'id': 103982,
#     'lyrics_owner_id': 168784,
#     'lyrics_state': 'complete',
#     'path': '/Guns-n-roses-knockin-on-heavens-door-lyrics',
#     'primary_artist_names': "Guns N' Roses",
#     'pyongs_count': 34,
#     'relationships_index_url': 'https://genius.com/Guns-n-roses-knockin-on-heavens-door-sample',
#     'release_date_components': {'year': 1991, 'month': 9, 'day': 17},
#     'release_date_for_display': 'September 17, 1991',
#     'release_date_with_abbreviated_month_for_display': 'Sep. 17, 1991',
#     'song_art_image_thumbnail_url': 'https://images.genius.com/cb2614550098bf753ab31c1f4a758686.300x300x1.jpg',
#     'song_art_image_url': 'https://images.genius.com/cb2614550098bf753ab31c1f4a758686.770x770x1.jpg',
#     'stats': {'unreviewed_annotations': 1, 'hot': False, 'pageviews': 549060},
#     'title': 'Knockin’ on Heaven’s Door',
#     'title_with_featured': 'Knockin’ on Heaven’s Door',
#     'url': 'https://genius.com/Guns-n-roses-knockin-on-heavens-door-lyrics',
#     'featured_artists': [],
#     'primary_artist': {'api_path': '/artists/637',
#      'header_image_url': 'https://images.genius.com/61cac9c5419a6d77387bb46ecda665fe.1000x488x1.jpg',
#      'id': 637,
#      'image_url': 'https://images.genius.com/f849831e1c03d02aa523459287b7ca51.1000x1000x1.png',
#      'is_meme_verified': False,
#      'is_verified': False,
#      'name': 'Guns N’ Roses',
#      'url': 'https://genius.com/artists/Guns-n-roses'},
#     'primary_artists': [{'api_path': '/artists/637',
#       'header_image_url': 'https://images.genius.com/61cac9c5419a6d77387bb46ecda665fe.1000x488x1.jpg',
#       'id': 637,
#       'image_url': 'https://images.genius.com/f849831e1c03d02aa523459287b7ca51.1000x1000x1.png',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Guns N’ Roses',
#       'url': 'https://genius.com/artists/Guns-n-roses'}]},
#    {'annotation_count': 128,
#     'api_path': '/songs/5393247',
#     'artist_names': 'Bob Dylan',
#     'full_title': 'Murder Most Foul by\xa0Bob\xa0Dylan',
#     'header_image_thumbnail_url': 'https://images.genius.com/7fbaf838ffdf99315408faa29cb566ac.300x300x1.jpg',
#     'header_image_url': 'https://images.genius.com/7fbaf838ffdf99315408faa29cb566ac.1000x1000x1.jpg',
#     'id': 5393247,
#     'lyrics_owner_id': 3360167,
#     'lyrics_state': 'complete',
#     'path': '/Bob-dylan-murder-most-foul-lyrics',
#     'primary_artist_names': 'Bob Dylan',
#     'pyongs_count': 37,
#     'relationships_index_url': 'https://genius.com/Bob-dylan-murder-most-foul-sample',
#     'release_date_components': {'year': 2020, 'month': 3, 'day': 27},
#     'release_date_for_display': 'March 27, 2020',
#     'release_date_with_abbreviated_month_for_display': 'Mar. 27, 2020',
#     'song_art_image_thumbnail_url': 'https://images.genius.com/7fbaf838ffdf99315408faa29cb566ac.300x300x1.jpg',
#     'song_art_image_url': 'https://images.genius.com/7fbaf838ffdf99315408faa29cb566ac.1000x1000x1.jpg',
#     'stats': {'unreviewed_annotations': 40, 'hot': False, 'pageviews': 519604},
#     'title': 'Murder Most Foul',
#     'title_with_featured': 'Murder Most Foul',
#     'url': 'https://genius.com/Bob-dylan-murder-most-foul-lyrics',
#     'featured_artists': [],
#     'primary_artist': {'api_path': '/artists/181',
#      'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#      'id': 181,
#      'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#      'is_meme_verified': False,
#      'is_verified': False,
#      'name': 'Bob Dylan',
#      'url': 'https://genius.com/artists/Bob-dylan'},
#     'primary_artists': [{'api_path': '/artists/181',
#       'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#       'id': 181,
#       'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Bob Dylan',
#       'url': 'https://genius.com/artists/Bob-dylan'}]},
#    {'annotation_count': 10,
#     'api_path': '/songs/84846',
#     'artist_names': 'Bob Dylan',
#     'full_title': "Don't Think Twice, It's All Right by\xa0Bob\xa0Dylan",
#     'header_image_thumbnail_url': 'https://images.genius.com/8ad4575fda9fd49e964c4b4ac541b4a4.300x300x1.png',
#     'header_image_url': 'https://images.genius.com/8ad4575fda9fd49e964c4b4ac541b4a4.1000x1000x1.png',
#     'id': 84846,
#     'lyrics_owner_id': 125524,
#     'lyrics_state': 'complete',
#     'path': '/Bob-dylan-dont-think-twice-its-all-right-lyrics',
#     'primary_artist_names': 'Bob Dylan',
#     'pyongs_count': 31,
#     'relationships_index_url': 'https://genius.com/Bob-dylan-dont-think-twice-its-all-right-sample',
#     'release_date_components': {'year': 1963, 'month': 5, 'day': 27},
#     'release_date_for_display': 'May 27, 1963',
#     'release_date_with_abbreviated_month_for_display': 'May 27, 1963',
#     'song_art_image_thumbnail_url': 'https://images.genius.com/8ad4575fda9fd49e964c4b4ac541b4a4.300x300x1.png',
#     'song_art_image_url': 'https://images.genius.com/8ad4575fda9fd49e964c4b4ac541b4a4.1000x1000x1.png',
#     'stats': {'unreviewed_annotations': 5, 'hot': False, 'pageviews': 488074},
#     'title': 'Don’t Think Twice, It’s All Right',
#     'title_with_featured': "Don't Think Twice, It's All Right",
#     'url': 'https://genius.com/Bob-dylan-dont-think-twice-its-all-right-lyrics',
#     'featured_artists': [],
#     'primary_artist': {'api_path': '/artists/181',
#      'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#      'id': 181,
#      'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#      'is_meme_verified': False,
#      'is_verified': False,
#      'name': 'Bob Dylan',
#      'url': 'https://genius.com/artists/Bob-dylan'},
#     'primary_artists': [{'api_path': '/artists/181',
#       'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#       'id': 181,
#       'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Bob Dylan',
#       'url': 'https://genius.com/artists/Bob-dylan'}]},
#    {'annotation_count': 32,
#     'api_path': '/songs/87402',
#     'artist_names': 'Bob Dylan',
#     'full_title': 'Hurricane by\xa0Bob\xa0Dylan',
#     'header_image_thumbnail_url': 'https://images.genius.com/2df91ca57456e44cf67e1d30d25bb701.300x299x1.jpg',
#     'header_image_url': 'https://images.genius.com/2df91ca57456e44cf67e1d30d25bb701.567x566x1.jpg',
#     'id': 87402,
#     'lyrics_owner_id': 132320,
#     'lyrics_state': 'complete',
#     'path': '/Bob-dylan-hurricane-lyrics',
#     'primary_artist_names': 'Bob Dylan',
#     'pyongs_count': 27,
#     'relationships_index_url': 'https://genius.com/Bob-dylan-hurricane-sample',
#     'release_date_components': {'year': 1976, 'month': 1, 'day': 5},
#     'release_date_for_display': 'January 5, 1976',
#     'release_date_with_abbreviated_month_for_display': 'Jan. 5, 1976',
#     'song_art_image_thumbnail_url': 'https://images.genius.com/2df91ca57456e44cf67e1d30d25bb701.300x299x1.jpg',
#     'song_art_image_url': 'https://images.genius.com/2df91ca57456e44cf67e1d30d25bb701.567x566x1.jpg',
#     'stats': {'unreviewed_annotations': 7, 'hot': False, 'pageviews': 441456},
#     'title': 'Hurricane',
#     'title_with_featured': 'Hurricane',
#     'url': 'https://genius.com/Bob-dylan-hurricane-lyrics',
#     'featured_artists': [],
#     'primary_artist': {'api_path': '/artists/181',
#      'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#      'id': 181,
#      'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#      'is_meme_verified': False,
#      'is_verified': False,
#      'name': 'Bob Dylan',
#      'url': 'https://genius.com/artists/Bob-dylan'},
#     'primary_artists': [{'api_path': '/artists/181',
#       'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#       'id': 181,
#       'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Bob Dylan',
#       'url': 'https://genius.com/artists/Bob-dylan'}]},
#    {'annotation_count': 10,
#     'api_path': '/songs/63341',
#     'artist_names': 'The Jimi Hendrix Experience',
#     'full_title': 'All Along the Watchtower by\xa0The\xa0Jimi Hendrix Experience',
#     'header_image_thumbnail_url': 'https://images.genius.com/ff55dd642026ce236b2488bb316bd98a.300x300x1.jpg',
#     'header_image_url': 'https://images.genius.com/ff55dd642026ce236b2488bb316bd98a.1000x1000x1.jpg',
#     'id': 63341,
#     'lyrics_owner_id': 31298,
#     'lyrics_state': 'complete',
#     'path': '/The-jimi-hendrix-experience-all-along-the-watchtower-lyrics',
#     'primary_artist_names': 'The Jimi Hendrix Experience',
#     'pyongs_count': 73,
#     'relationships_index_url': 'https://genius.com/The-jimi-hendrix-experience-all-along-the-watchtower-sample',
#     'release_date_components': {'year': 1968, 'month': 9, 'day': 21},
#     'release_date_for_display': 'September 21, 1968',
#     'release_date_with_abbreviated_month_for_display': 'Sep. 21, 1968',
#     'song_art_image_thumbnail_url': 'https://images.genius.com/ff55dd642026ce236b2488bb316bd98a.300x300x1.jpg',
#     'song_art_image_url': 'https://images.genius.com/ff55dd642026ce236b2488bb316bd98a.1000x1000x1.jpg',
#     'stats': {'unreviewed_annotations': 0, 'hot': False, 'pageviews': 413430},
#     'title': 'All Along the Watchtower',
#     'title_with_featured': 'All Along the Watchtower',
#     'url': 'https://genius.com/The-jimi-hendrix-experience-all-along-the-watchtower-lyrics',
#     'featured_artists': [],
#     'primary_artist': {'api_path': '/artists/634985',
#      'header_image_url': 'https://images.genius.com/2631895179875ea7541bbb43d0a83481.1000x250x1.png',
#      'id': 634985,
#      'image_url': 'https://images.genius.com/ca64447350d06d6dc144070174575951.840x840x1.jpg',
#      'is_meme_verified': False,
#      'is_verified': False,
#      'name': 'The Jimi Hendrix Experience',
#      'url': 'https://genius.com/artists/The-jimi-hendrix-experience'},
#     'primary_artists': [{'api_path': '/artists/634985',
#       'header_image_url': 'https://images.genius.com/2631895179875ea7541bbb43d0a83481.1000x250x1.png',
#       'id': 634985,
#       'image_url': 'https://images.genius.com/ca64447350d06d6dc144070174575951.840x840x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'The Jimi Hendrix Experience',
#       'url': 'https://genius.com/artists/The-jimi-hendrix-experience'}]},
#    {'annotation_count': 21,
#     'api_path': '/songs/224',
#     'artist_names': 'Bob Dylan',
#     'full_title': 'Subterranean Homesick Blues by\xa0Bob\xa0Dylan',
#     'header_image_thumbnail_url': 'https://images.genius.com/fccb3cb2608c837461ddab5ddd8cd31e.300x300x1.jpg',
#     'header_image_url': 'https://images.genius.com/fccb3cb2608c837461ddab5ddd8cd31e.1000x1000x1.jpg',
#     'id': 224,
#     'lyrics_owner_id': 4,
#     'lyrics_state': 'complete',
#     'path': '/Bob-dylan-subterranean-homesick-blues-lyrics',
#     'primary_artist_names': 'Bob Dylan',
#     'pyongs_count': 37,
#     'relationships_index_url': 'https://genius.com/Bob-dylan-subterranean-homesick-blues-sample',
#     'release_date_components': {'year': 1965, 'month': 3, 'day': 8},
#     'release_date_for_display': 'March 8, 1965',
#     'release_date_with_abbreviated_month_for_display': 'Mar. 8, 1965',
#     'song_art_image_thumbnail_url': 'https://images.genius.com/fccb3cb2608c837461ddab5ddd8cd31e.300x300x1.jpg',
#     'song_art_image_url': 'https://images.genius.com/fccb3cb2608c837461ddab5ddd8cd31e.1000x1000x1.jpg',
#     'stats': {'unreviewed_annotations': 2, 'hot': False, 'pageviews': 404743},
#     'title': 'Subterranean Homesick Blues',
#     'title_with_featured': 'Subterranean Homesick Blues',
#     'url': 'https://genius.com/Bob-dylan-subterranean-homesick-blues-lyrics',
#     'featured_artists': [],
#     'primary_artist': {'api_path': '/artists/181',
#      'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#      'id': 181,
#      'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#      'is_meme_verified': False,
#      'is_verified': False,
#      'name': 'Bob Dylan',
#      'url': 'https://genius.com/artists/Bob-dylan'},
#     'primary_artists': [{'api_path': '/artists/181',
#       'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#       'id': 181,
#       'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Bob Dylan',
#       'url': 'https://genius.com/artists/Bob-dylan'}]},
#    {'annotation_count': 10,
#     'api_path': '/songs/79749',
#     'artist_names': 'Bob Dylan',
#     'full_title': 'Make You Feel My Love by\xa0Bob\xa0Dylan',
#     'header_image_thumbnail_url': 'https://images.genius.com/cd0a26733cc459710d0986b7b64de8f0.300x300x1.jpg',
#     'header_image_url': 'https://images.genius.com/cd0a26733cc459710d0986b7b64de8f0.1000x1000x1.jpg',
#     'id': 79749,
#     'lyrics_owner_id': 5307,
#     'lyrics_state': 'complete',
#     'path': '/Bob-dylan-make-you-feel-my-love-lyrics',
#     'primary_artist_names': 'Bob Dylan',
#     'pyongs_count': 10,
#     'relationships_index_url': 'https://genius.com/Bob-dylan-make-you-feel-my-love-sample',
#     'release_date_components': {'year': 1997, 'month': 9, 'day': 30},
#     'release_date_for_display': 'September 30, 1997',
#     'release_date_with_abbreviated_month_for_display': 'Sep. 30, 1997',
#     'song_art_image_thumbnail_url': 'https://images.genius.com/cd0a26733cc459710d0986b7b64de8f0.300x300x1.jpg',
#     'song_art_image_url': 'https://images.genius.com/cd0a26733cc459710d0986b7b64de8f0.1000x1000x1.jpg',
#     'stats': {'unreviewed_annotations': 3, 'hot': False, 'pageviews': 391598},
#     'title': 'Make You Feel My Love',
#     'title_with_featured': 'Make You Feel My Love',
#     'url': 'https://genius.com/Bob-dylan-make-you-feel-my-love-lyrics',
#     'featured_artists': [],
#     'primary_artist': {'api_path': '/artists/181',
#      'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#      'id': 181,
#      'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#      'is_meme_verified': False,
#      'is_verified': False,
#      'name': 'Bob Dylan',
#      'url': 'https://genius.com/artists/Bob-dylan'},
#     'primary_artists': [{'api_path': '/artists/181',
#       'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#       'id': 181,
#       'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Bob Dylan',
#       'url': 'https://genius.com/artists/Bob-dylan'}]},
#    {'annotation_count': 41,
#     'api_path': '/songs/105186',
#     'artist_names': 'Bob Dylan',
#     'full_title': "A Hard Rain's A-Gonna Fall by\xa0Bob\xa0Dylan",
#     'header_image_thumbnail_url': 'https://images.genius.com/8ad4575fda9fd49e964c4b4ac541b4a4.300x300x1.png',
#     'header_image_url': 'https://images.genius.com/8ad4575fda9fd49e964c4b4ac541b4a4.1000x1000x1.png',
#     'id': 105186,
#     'lyrics_owner_id': 16,
#     'lyrics_state': 'complete',
#     'path': '/Bob-dylan-a-hard-rains-a-gonna-fall-lyrics',
#     'primary_artist_names': 'Bob Dylan',
#     'pyongs_count': 24,
#     'relationships_index_url': 'https://genius.com/Bob-dylan-a-hard-rains-a-gonna-fall-sample',
#     'release_date_components': {'year': 1963, 'month': 5, 'day': 27},
#     'release_date_for_display': 'May 27, 1963',
#     'release_date_with_abbreviated_month_for_display': 'May 27, 1963',
#     'song_art_image_thumbnail_url': 'https://images.genius.com/8ad4575fda9fd49e964c4b4ac541b4a4.300x300x1.png',
#     'song_art_image_url': 'https://images.genius.com/8ad4575fda9fd49e964c4b4ac541b4a4.1000x1000x1.png',
#     'stats': {'unreviewed_annotations': 5, 'hot': False, 'pageviews': 390351},
#     'title': 'A Hard Rain’s A-Gonna Fall',
#     'title_with_featured': "A Hard Rain's A-Gonna Fall",
#     'url': 'https://genius.com/Bob-dylan-a-hard-rains-a-gonna-fall-lyrics',
#     'featured_artists': [],
#     'primary_artist': {'api_path': '/artists/181',
#      'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#      'id': 181,
#      'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#      'is_meme_verified': False,
#      'is_verified': False,
#      'name': 'Bob Dylan',
#      'url': 'https://genius.com/artists/Bob-dylan'},
#     'primary_artists': [{'api_path': '/artists/181',
#       'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#       'id': 181,
#       'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Bob Dylan',
#       'url': 'https://genius.com/artists/Bob-dylan'}]},
#    {'annotation_count': 23,
#     'api_path': '/songs/75446',
#     'artist_names': 'Bob Dylan',
#     'full_title': 'Mr. Tambourine Man by\xa0Bob\xa0Dylan',
#     'header_image_thumbnail_url': 'https://images.genius.com/051afc779ad250f5a1f770d5a5baaa72.300x303x1.jpg',
#     'header_image_url': 'https://images.genius.com/051afc779ad250f5a1f770d5a5baaa72.593x599x1.jpg',
#     'id': 75446,
#     'lyrics_owner_id': 74226,
#     'lyrics_state': 'complete',
#     'path': '/Bob-dylan-mr-tambourine-man-lyrics',
#     'primary_artist_names': 'Bob Dylan',
#     'pyongs_count': 25,
#     'relationships_index_url': 'https://genius.com/Bob-dylan-mr-tambourine-man-sample',
#     'release_date_components': {'year': 1965, 'month': 3, 'day': 22},
#     'release_date_for_display': 'March 22, 1965',
#     'release_date_with_abbreviated_month_for_display': 'Mar. 22, 1965',
#     'song_art_image_thumbnail_url': 'https://images.genius.com/051afc779ad250f5a1f770d5a5baaa72.300x303x1.jpg',
#     'song_art_image_url': 'https://images.genius.com/051afc779ad250f5a1f770d5a5baaa72.593x599x1.jpg',
#     'stats': {'unreviewed_annotations': 5, 'hot': False, 'pageviews': 340001},
#     'title': 'Mr. Tambourine Man',
#     'title_with_featured': 'Mr. Tambourine Man',
#     'url': 'https://genius.com/Bob-dylan-mr-tambourine-man-lyrics',
#     'featured_artists': [],
#     'primary_artist': {'api_path': '/artists/181',
#      'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#      'id': 181,
#      'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#      'is_meme_verified': False,
#      'is_verified': False,
#      'name': 'Bob Dylan',
#      'url': 'https://genius.com/artists/Bob-dylan'},
#     'primary_artists': [{'api_path': '/artists/181',
#       'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#       'id': 181,
#       'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Bob Dylan',
#       'url': 'https://genius.com/artists/Bob-dylan'}]},
#    {'annotation_count': 35,
#     'api_path': '/songs/118799',
#     'artist_names': 'Bob Dylan',
#     'full_title': 'Tangled Up in Blue by\xa0Bob\xa0Dylan',
#     'header_image_thumbnail_url': 'https://images.genius.com/9146ba54ed06288f10b296cd5d888781.300x300x1.jpg',
#     'header_image_url': 'https://images.genius.com/9146ba54ed06288f10b296cd5d888781.500x500x1.jpg',
#     'id': 118799,
#     'lyrics_owner_id': 1850,
#     'lyrics_state': 'complete',
#     'path': '/Bob-dylan-tangled-up-in-blue-lyrics',
#     'primary_artist_names': 'Bob Dylan',
#     'pyongs_count': 27,
#     'relationships_index_url': 'https://genius.com/Bob-dylan-tangled-up-in-blue-sample',
#     'release_date_components': {'year': 1975, 'month': 1, 'day': 17},
#     'release_date_for_display': 'January 17, 1975',
#     'release_date_with_abbreviated_month_for_display': 'Jan. 17, 1975',
#     'song_art_image_thumbnail_url': 'https://images.genius.com/9146ba54ed06288f10b296cd5d888781.300x300x1.jpg',
#     'song_art_image_url': 'https://images.genius.com/9146ba54ed06288f10b296cd5d888781.500x500x1.jpg',
#     'stats': {'unreviewed_annotations': 14, 'hot': False, 'pageviews': 328617},
#     'title': 'Tangled Up in Blue',
#     'title_with_featured': 'Tangled Up in Blue',
#     'url': 'https://genius.com/Bob-dylan-tangled-up-in-blue-lyrics',
#     'featured_artists': [],
#     'primary_artist': {'api_path': '/artists/181',
#      'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#      'id': 181,
#      'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#      'is_meme_verified': False,
#      'is_verified': False,
#      'name': 'Bob Dylan',
#      'url': 'https://genius.com/artists/Bob-dylan'},
#     'primary_artists': [{'api_path': '/artists/181',
#       'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#       'id': 181,
#       'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Bob Dylan',
#       'url': 'https://genius.com/artists/Bob-dylan'}]},
#    {'annotation_count': 14,
#     'api_path': '/songs/154239',
#     'artist_names': 'Darius Rucker',
#     'full_title': 'Wagon Wheel by\xa0Darius\xa0Rucker',
#     'header_image_thumbnail_url': 'https://images.genius.com/06957cdf4a75a96e581f0d2510105ebe.300x300x1.jpg',
#     'header_image_url': 'https://images.genius.com/06957cdf4a75a96e581f0d2510105ebe.640x640x1.jpg',
#     'id': 154239,
#     'lyrics_owner_id': 10380,
#     'lyrics_state': 'complete',
#     'path': '/Darius-rucker-wagon-wheel-lyrics',
#     'primary_artist_names': 'Darius Rucker',
#     'pyongs_count': 33,
#     'relationships_index_url': 'https://genius.com/Darius-rucker-wagon-wheel-sample',
#     'release_date_components': {'year': 2013, 'month': 1, 'day': 7},
#     'release_date_for_display': 'January 7, 2013',
#     'release_date_with_abbreviated_month_for_display': 'Jan. 7, 2013',
#     'song_art_image_thumbnail_url': 'https://images.genius.com/06957cdf4a75a96e581f0d2510105ebe.300x300x1.jpg',
#     'song_art_image_url': 'https://images.genius.com/06957cdf4a75a96e581f0d2510105ebe.640x640x1.jpg',
#     'stats': {'unreviewed_annotations': 0, 'hot': False, 'pageviews': 327873},
#     'title': 'Wagon Wheel',
#     'title_with_featured': 'Wagon Wheel',
#     'url': 'https://genius.com/Darius-rucker-wagon-wheel-lyrics',
#     'featured_artists': [],
#     'primary_artist': {'api_path': '/artists/21867',
#      'header_image_url': 'https://images.genius.com/6a629cf1a4b6fec5b21a8dd995cf928f.1000x519x1.jpg',
#      'id': 21867,
#      'image_url': 'https://images.genius.com/6009b412250fcc9da9092429cc266812.474x474x1.jpg',
#      'is_meme_verified': False,
#      'is_verified': False,
#      'name': 'Darius Rucker',
#      'url': 'https://genius.com/artists/Darius-rucker'},
#     'primary_artists': [{'api_path': '/artists/21867',
#       'header_image_url': 'https://images.genius.com/6a629cf1a4b6fec5b21a8dd995cf928f.1000x519x1.jpg',
#       'id': 21867,
#       'image_url': 'https://images.genius.com/6009b412250fcc9da9092429cc266812.474x474x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Darius Rucker',
#       'url': 'https://genius.com/artists/Darius-rucker'}]},
#    {'annotation_count': 6,
#     'api_path': '/songs/199531',
#     'artist_names': 'Bob Dylan',
#     'full_title': 'Knockin’ on Heaven’s Door by\xa0Bob\xa0Dylan',
#     'header_image_thumbnail_url': 'https://images.genius.com/e0a7ce8aae657ee022f141e82efa8891.300x299x1.jpg',
#     'header_image_url': 'https://images.genius.com/e0a7ce8aae657ee022f141e82efa8891.500x498x1.jpg',
#     'id': 199531,
#     'lyrics_owner_id': 225680,
#     'lyrics_state': 'complete',
#     'path': '/Bob-dylan-knockin-on-heavens-door-lyrics',
#     'primary_artist_names': 'Bob Dylan',
#     'pyongs_count': 16,
#     'relationships_index_url': 'https://genius.com/Bob-dylan-knockin-on-heavens-door-sample',
#     'release_date_components': {'year': 1973, 'month': 6, 'day': 13},
#     'release_date_for_display': 'June 13, 1973',
#     'release_date_with_abbreviated_month_for_display': 'Jun. 13, 1973',
#     'song_art_image_thumbnail_url': 'https://images.genius.com/e0a7ce8aae657ee022f141e82efa8891.300x299x1.jpg',
#     'song_art_image_url': 'https://images.genius.com/e0a7ce8aae657ee022f141e82efa8891.500x498x1.jpg',
#     'stats': {'unreviewed_annotations': 2, 'hot': False, 'pageviews': 298709},
#     'title': 'Knockin’ on Heaven’s Door',
#     'title_with_featured': 'Knockin’ on Heaven’s Door',
#     'url': 'https://genius.com/Bob-dylan-knockin-on-heavens-door-lyrics',
#     'featured_artists': [],
#     'primary_artist': {'api_path': '/artists/181',
#      'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#      'id': 181,
#      'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#      'is_meme_verified': False,
#      'is_verified': False,
#      'name': 'Bob Dylan',
#      'url': 'https://genius.com/artists/Bob-dylan'},
#     'primary_artists': [{'api_path': '/artists/181',
#       'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#       'id': 181,
#       'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Bob Dylan',
#       'url': 'https://genius.com/artists/Bob-dylan'}]},
#    {'annotation_count': 51,
#     'api_path': '/songs/75463',
#     'artist_names': 'Bob Dylan',
#     'full_title': "It's Alright, Ma (I'm Only Bleeding) by\xa0Bob\xa0Dylan",
#     'header_image_thumbnail_url': 'https://images.genius.com/e4013e376bc0912bdb9bddd9e9d53aef.300x300x1.png',
#     'header_image_url': 'https://images.genius.com/e4013e376bc0912bdb9bddd9e9d53aef.1000x1000x1.png',
#     'id': 75463,
#     'lyrics_owner_id': 74226,
#     'lyrics_state': 'complete',
#     'path': '/Bob-dylan-its-alright-ma-im-only-bleeding-lyrics',
#     'primary_artist_names': 'Bob Dylan',
#     'pyongs_count': 18,
#     'relationships_index_url': 'https://genius.com/Bob-dylan-its-alright-ma-im-only-bleeding-sample',
#     'release_date_components': {'year': 1965, 'month': 3, 'day': 22},
#     'release_date_for_display': 'March 22, 1965',
#     'release_date_with_abbreviated_month_for_display': 'Mar. 22, 1965',
#     'song_art_image_thumbnail_url': 'https://images.genius.com/e4013e376bc0912bdb9bddd9e9d53aef.300x300x1.png',
#     'song_art_image_url': 'https://images.genius.com/e4013e376bc0912bdb9bddd9e9d53aef.1000x1000x1.png',
#     'stats': {'unreviewed_annotations': 5, 'hot': False, 'pageviews': 258206},
#     'title': 'It’s Alright, Ma (I’m Only Bleeding)',
#     'title_with_featured': "It's Alright, Ma (I'm Only Bleeding)",
#     'url': 'https://genius.com/Bob-dylan-its-alright-ma-im-only-bleeding-lyrics',
#     'featured_artists': [],
#     'primary_artist': {'api_path': '/artists/181',
#      'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#      'id': 181,
#      'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#      'is_meme_verified': False,
#      'is_verified': False,
#      'name': 'Bob Dylan',
#      'url': 'https://genius.com/artists/Bob-dylan'},
#     'primary_artists': [{'api_path': '/artists/181',
#       'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#       'id': 181,
#       'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Bob Dylan',
#       'url': 'https://genius.com/artists/Bob-dylan'}]},
#    {'annotation_count': 82,
#     'api_path': '/songs/92350',
#     'artist_names': 'Bob Dylan',
#     'full_title': 'Desolation Row by\xa0Bob\xa0Dylan',
#     'header_image_thumbnail_url': 'https://images.genius.com/5f645b57452ff0d90afe6c138180db0a.300x300x1.jpg',
#     'header_image_url': 'https://images.genius.com/5f645b57452ff0d90afe6c138180db0a.1000x1000x1.jpg',
#     'id': 92350,
#     'lyrics_owner_id': 145715,
#     'lyrics_state': 'complete',
#     'path': '/Bob-dylan-desolation-row-lyrics',
#     'primary_artist_names': 'Bob Dylan',
#     'pyongs_count': 14,
#     'relationships_index_url': 'https://genius.com/Bob-dylan-desolation-row-sample',
#     'release_date_components': {'year': 1965, 'month': 8, 'day': 30},
#     'release_date_for_display': 'August 30, 1965',
#     'release_date_with_abbreviated_month_for_display': 'Aug. 30, 1965',
#     'song_art_image_thumbnail_url': 'https://images.genius.com/5f645b57452ff0d90afe6c138180db0a.300x300x1.jpg',
#     'song_art_image_url': 'https://images.genius.com/5f645b57452ff0d90afe6c138180db0a.1000x1000x1.jpg',
#     'stats': {'unreviewed_annotations': 20, 'hot': False, 'pageviews': 252967},
#     'title': 'Desolation Row',
#     'title_with_featured': 'Desolation Row',
#     'url': 'https://genius.com/Bob-dylan-desolation-row-lyrics',
#     'featured_artists': [],
#     'primary_artist': {'api_path': '/artists/181',
#      'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#      'id': 181,
#      'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#      'is_meme_verified': False,
#      'is_verified': False,
#      'name': 'Bob Dylan',
#      'url': 'https://genius.com/artists/Bob-dylan'},
#     'primary_artists': [{'api_path': '/artists/181',
#       'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#       'id': 181,
#       'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Bob Dylan',
#       'url': 'https://genius.com/artists/Bob-dylan'}]}],
#   'next_page': 2}}

# %%
songs = data["response"]["songs"]
songs
# Out:
# [{'annotation_count': 15,
#   'api_path': '/songs/96286',
#   'artist_names': 'USA For Africa',
#   'full_title': 'We Are the World by\xa0USA\xa0For Africa',
#   'header_image_thumbnail_url': 'https://images.genius.com/d328397b28953bd84465cd582e71271d.300x300x1.jpg',
#   'header_image_url': 'https://images.genius.com/d328397b28953bd84465cd582e71271d.1000x1000x1.jpg',
#   'id': 96286,
#   'lyrics_owner_id': 4733728,
#   'lyrics_state': 'complete',
#   'path': '/Usa-for-africa-we-are-the-world-lyrics',
#   'primary_artist_names': 'USA For Africa',
#   'pyongs_count': 35,
#   'relationships_index_url': 'https://genius.com/Usa-for-africa-we-are-the-world-sample',
#   'release_date_components': {'year': 1985, 'month': 3, 'day': 7},
#   'release_date_for_display': 'March 7, 1985',
#   'release_date_with_abbreviated_month_for_display': 'Mar. 7, 1985',
#   'song_art_image_thumbnail_url': 'https://images.genius.com/d328397b28953bd84465cd582e71271d.300x300x1.jpg',
#   'song_art_image_url': 'https://images.genius.com/d328397b28953bd84465cd582e71271d.1000x1000x1.jpg',
#   'stats': {'unreviewed_annotations': 0,
#    'concurrents': 2,
#    'hot': False,
#    'pageviews': 837056},
#   'title': 'We Are the World',
#   'title_with_featured': 'We Are the World',
#   'url': 'https://genius.com/Usa-for-africa-we-are-the-world-lyrics',
#   'featured_artists': [],
#   'primary_artist': {'api_path': '/artists/370890',
#    'header_image_url': 'https://images.genius.com/3fb2d9f68c911b5473399b97ef9427e6.768x768x1.jpg',
#    'id': 370890,
#    'image_url': 'https://images.genius.com/3fb2d9f68c911b5473399b97ef9427e6.768x768x1.jpg',
#    'is_meme_verified': False,
#    'is_verified': False,
#    'name': 'USA For Africa',
#    'url': 'https://genius.com/artists/Usa-for-africa'},
#   'primary_artists': [{'api_path': '/artists/370890',
#     'header_image_url': 'https://images.genius.com/3fb2d9f68c911b5473399b97ef9427e6.768x768x1.jpg',
#     'id': 370890,
#     'image_url': 'https://images.genius.com/3fb2d9f68c911b5473399b97ef9427e6.768x768x1.jpg',
#     'is_meme_verified': False,
#     'is_verified': False,
#     'name': 'USA For Africa',
#     'url': 'https://genius.com/artists/Usa-for-africa'}]},
#  {'annotation_count': 12,
#   'api_path': '/songs/79424',
#   'artist_names': 'Bob Dylan',
#   'full_title': "Blowin' in the Wind by\xa0Bob\xa0Dylan",
#   'header_image_thumbnail_url': 'https://images.genius.com/8ad4575fda9fd49e964c4b4ac541b4a4.300x300x1.png',
#   'header_image_url': 'https://images.genius.com/8ad4575fda9fd49e964c4b4ac541b4a4.1000x1000x1.png',
#   'id': 79424,
#   'lyrics_owner_id': 73267,
#   'lyrics_state': 'complete',
#   'path': '/Bob-dylan-blowin-in-the-wind-lyrics',
#   'primary_artist_names': 'Bob Dylan',
#   'pyongs_count': 49,
#   'relationships_index_url': 'https://genius.com/Bob-dylan-blowin-in-the-wind-sample',
#   'release_date_components': {'year': 1963, 'month': 5, 'day': 27},
#   'release_date_for_display': 'May 27, 1963',
#   'release_date_with_abbreviated_month_for_display': 'May 27, 1963',
#   'song_art_image_thumbnail_url': 'https://images.genius.com/8ad4575fda9fd49e964c4b4ac541b4a4.300x300x1.png',
#   'song_art_image_url': 'https://images.genius.com/8ad4575fda9fd49e964c4b4ac541b4a4.1000x1000x1.png',
#   'stats': {'unreviewed_annotations': 0,
#    'concurrents': 2,
#    'hot': False,
#    'pageviews': 706090},
#   'title': 'Blowin’ in the Wind',
#   'title_with_featured': "Blowin' in the Wind",
#   'url': 'https://genius.com/Bob-dylan-blowin-in-the-wind-lyrics',
#   'featured_artists': [],
#   'primary_artist': {'api_path': '/artists/181',
#    'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#    'id': 181,
#    'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#    'is_meme_verified': False,
#    'is_verified': False,
#    'name': 'Bob Dylan',
#    'url': 'https://genius.com/artists/Bob-dylan'},
#   'primary_artists': [{'api_path': '/artists/181',
#     'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#     'id': 181,
#     'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#     'is_meme_verified': False,
#     'is_verified': False,
#     'name': 'Bob Dylan',
#     'url': 'https://genius.com/artists/Bob-dylan'}]},
#  {'annotation_count': 3,
#   'api_path': '/songs/68146',
#   'artist_names': 'Adele',
#   'full_title': 'Make You Feel My Love by\xa0Adele',
#   'header_image_thumbnail_url': 'https://images.genius.com/f248cc85ccaab603ce88832109b21bb8.300x300x1.png',
#   'header_image_url': 'https://images.genius.com/f248cc85ccaab603ce88832109b21bb8.1000x1000x1.png',
#   'id': 68146,
#   'lyrics_owner_id': 82481,
#   'lyrics_state': 'complete',
#   'path': '/Adele-make-you-feel-my-love-lyrics',
#   'primary_artist_names': 'Adele',
#   'pyongs_count': 53,
#   'relationships_index_url': 'https://genius.com/Adele-make-you-feel-my-love-sample',
#   'release_date_components': {'year': 2008, 'month': 10, 'day': 27},
#   'release_date_for_display': 'October 27, 2008',
#   'release_date_with_abbreviated_month_for_display': 'Oct. 27, 2008',
#   'song_art_image_thumbnail_url': 'https://images.genius.com/f248cc85ccaab603ce88832109b21bb8.300x300x1.png',
#   'song_art_image_url': 'https://images.genius.com/f248cc85ccaab603ce88832109b21bb8.1000x1000x1.png',
#   'stats': {'unreviewed_annotations': 2,
#    'concurrents': 2,
#    'hot': False,
#    'pageviews': 689276},
#   'title': 'Make You Feel My Love',
#   'title_with_featured': 'Make You Feel My Love',
#   'url': 'https://genius.com/Adele-make-you-feel-my-love-lyrics',
#   'featured_artists': [],
#   'primary_artist': {'api_path': '/artists/2300',
#    'header_image_url': 'https://images.genius.com/87aa5d8c32965a10e0e7ad1acb54ba40.1000x287x6.gif',
#    'id': 2300,
#    'image_url': 'https://images.genius.com/8a23ab928ccfce13accfde72f1290702.1000x1000x1.jpg',
#    'is_meme_verified': False,
#    'is_verified': False,
#    'name': 'Adele',
#    'url': 'https://genius.com/artists/Adele'},
#   'primary_artists': [{'api_path': '/artists/2300',
#     'header_image_url': 'https://images.genius.com/87aa5d8c32965a10e0e7ad1acb54ba40.1000x287x6.gif',
#     'id': 2300,
#     'image_url': 'https://images.genius.com/8a23ab928ccfce13accfde72f1290702.1000x1000x1.jpg',
#     'is_meme_verified': False,
#     'is_verified': False,
#     'name': 'Adele',
#     'url': 'https://genius.com/artists/Adele'}]},
#  {'annotation_count': 19,
#   'api_path': '/songs/62605',
#   'artist_names': 'Bob Dylan',
#   'full_title': "The Times They Are A-Changin' by\xa0Bob\xa0Dylan",
#   'header_image_thumbnail_url': 'https://images.genius.com/3f8af2a0b75202890de67fbfe572fe94.300x300x1.jpg',
#   'header_image_url': 'https://images.genius.com/3f8af2a0b75202890de67fbfe572fe94.571x571x1.jpg',
#   'id': 62605,
#   'lyrics_owner_id': 49202,
#   'lyrics_state': 'complete',
#   'path': '/Bob-dylan-the-times-they-are-a-changin-lyrics',
#   'primary_artist_names': 'Bob Dylan',
#   'pyongs_count': 44,
#   'relationships_index_url': 'https://genius.com/Bob-dylan-the-times-they-are-a-changin-sample',
#   'release_date_components': {'year': 1964, 'month': 1, 'day': 13},
#   'release_date_for_display': 'January 13, 1964',
#   'release_date_with_abbreviated_month_for_display': 'Jan. 13, 1964',
#   'song_art_image_thumbnail_url': 'https://images.genius.com/3f8af2a0b75202890de67fbfe572fe94.300x300x1.jpg',
#   'song_art_image_url': 'https://images.genius.com/3f8af2a0b75202890de67fbfe572fe94.571x571x1.jpg',
#   'stats': {'unreviewed_annotations': 4, 'hot': False, 'pageviews': 600869},
#   'title': 'The Times They Are A-Changin’',
#   'title_with_featured': "The Times They Are A-Changin'",
#   'url': 'https://genius.com/Bob-dylan-the-times-they-are-a-changin-lyrics',
#   'featured_artists': [],
#   'primary_artist': {'api_path': '/artists/181',
#    'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#    'id': 181,
#    'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#    'is_meme_verified': False,
#    'is_verified': False,
#    'name': 'Bob Dylan',
#    'url': 'https://genius.com/artists/Bob-dylan'},
#   'primary_artists': [{'api_path': '/artists/181',
#     'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#     'id': 181,
#     'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#     'is_meme_verified': False,
#     'is_verified': False,
#     'name': 'Bob Dylan',
#     'url': 'https://genius.com/artists/Bob-dylan'}]},
#  {'annotation_count': 31,
#   'api_path': '/songs/54784',
#   'artist_names': 'Bob Dylan',
#   'full_title': 'Like a Rolling Stone by\xa0Bob\xa0Dylan',
#   'header_image_thumbnail_url': 'https://images.genius.com/51cae7d22b817fa25c88b8618ad91b40.300x300x1.jpg',
#   'header_image_url': 'https://images.genius.com/51cae7d22b817fa25c88b8618ad91b40.550x550x1.jpg',
#   'id': 54784,
#   'lyrics_owner_id': 7,
#   'lyrics_state': 'complete',
#   'path': '/Bob-dylan-like-a-rolling-stone-lyrics',
#   'primary_artist_names': 'Bob Dylan',
#   'pyongs_count': 66,
#   'relationships_index_url': 'https://genius.com/Bob-dylan-like-a-rolling-stone-sample',
#   'release_date_components': {'year': 1965, 'month': 7, 'day': 20},
#   'release_date_for_display': 'July 20, 1965',
#   'release_date_with_abbreviated_month_for_display': 'Jul. 20, 1965',
#   'song_art_image_thumbnail_url': 'https://images.genius.com/51cae7d22b817fa25c88b8618ad91b40.300x300x1.jpg',
#   'song_art_image_url': 'https://images.genius.com/51cae7d22b817fa25c88b8618ad91b40.550x550x1.jpg',
#   'stats': {'unreviewed_annotations': 15, 'hot': False, 'pageviews': 586233},
#   'title': 'Like a Rolling Stone',
#   'title_with_featured': 'Like a Rolling Stone',
#   'url': 'https://genius.com/Bob-dylan-like-a-rolling-stone-lyrics',
#   'featured_artists': [],
#   'primary_artist': {'api_path': '/artists/181',
#    'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#    'id': 181,
#    'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#    'is_meme_verified': False,
#    'is_verified': False,
#    'name': 'Bob Dylan',
#    'url': 'https://genius.com/artists/Bob-dylan'},
#   'primary_artists': [{'api_path': '/artists/181',
#     'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#     'id': 181,
#     'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#     'is_meme_verified': False,
#     'is_verified': False,
#     'name': 'Bob Dylan',
#     'url': 'https://genius.com/artists/Bob-dylan'}]},
#  {'annotation_count': 15,
#   'api_path': '/songs/98664',
#   'artist_names': 'Bob Dylan',
#   'full_title': 'All Along the Watchtower by\xa0Bob\xa0Dylan',
#   'header_image_thumbnail_url': 'https://images.genius.com/40169c4a86e479f32e7a44e3ae4d85d4.300x300x1.jpg',
#   'header_image_url': 'https://images.genius.com/40169c4a86e479f32e7a44e3ae4d85d4.320x320x1.jpg',
#   'id': 98664,
#   'lyrics_owner_id': 779,
#   'lyrics_state': 'complete',
#   'path': '/Bob-dylan-all-along-the-watchtower-lyrics',
#   'primary_artist_names': 'Bob Dylan',
#   'pyongs_count': 44,
#   'relationships_index_url': 'https://genius.com/Bob-dylan-all-along-the-watchtower-sample',
#   'release_date_components': {'year': 1967, 'month': 12, 'day': 27},
#   'release_date_for_display': 'December 27, 1967',
#   'release_date_with_abbreviated_month_for_display': 'Dec. 27, 1967',
#   'song_art_image_thumbnail_url': 'https://images.genius.com/40169c4a86e479f32e7a44e3ae4d85d4.300x300x1.jpg',
#   'song_art_image_url': 'https://images.genius.com/40169c4a86e479f32e7a44e3ae4d85d4.320x320x1.jpg',
#   'stats': {'unreviewed_annotations': 0,
#    'concurrents': 2,
#    'hot': False,
#    'pageviews': 550954},
#   'title': 'All Along the Watchtower',
#   'title_with_featured': 'All Along the Watchtower',
#   'url': 'https://genius.com/Bob-dylan-all-along-the-watchtower-lyrics',
#   'featured_artists': [],
#   'primary_artist': {'api_path': '/artists/181',
#    'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#    'id': 181,
#    'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#    'is_meme_verified': False,
#    'is_verified': False,
#    'name': 'Bob Dylan',
#    'url': 'https://genius.com/artists/Bob-dylan'},
#   'primary_artists': [{'api_path': '/artists/181',
#     'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#     'id': 181,
#     'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#     'is_meme_verified': False,
#     'is_verified': False,
#     'name': 'Bob Dylan',
#     'url': 'https://genius.com/artists/Bob-dylan'}]},
#  {'annotation_count': 7,
#   'api_path': '/songs/103982',
#   'artist_names': "Guns N' Roses",
#   'full_title': "Knockin’ on Heaven’s Door by\xa0Guns\xa0N' Roses",
#   'header_image_thumbnail_url': 'https://images.genius.com/cb2614550098bf753ab31c1f4a758686.300x300x1.jpg',
#   'header_image_url': 'https://images.genius.com/cb2614550098bf753ab31c1f4a758686.770x770x1.jpg',
#   'id': 103982,
#   'lyrics_owner_id': 168784,
#   'lyrics_state': 'complete',
#   'path': '/Guns-n-roses-knockin-on-heavens-door-lyrics',
#   'primary_artist_names': "Guns N' Roses",
#   'pyongs_count': 34,
#   'relationships_index_url': 'https://genius.com/Guns-n-roses-knockin-on-heavens-door-sample',
#   'release_date_components': {'year': 1991, 'month': 9, 'day': 17},
#   'release_date_for_display': 'September 17, 1991',
#   'release_date_with_abbreviated_month_for_display': 'Sep. 17, 1991',
#   'song_art_image_thumbnail_url': 'https://images.genius.com/cb2614550098bf753ab31c1f4a758686.300x300x1.jpg',
#   'song_art_image_url': 'https://images.genius.com/cb2614550098bf753ab31c1f4a758686.770x770x1.jpg',
#   'stats': {'unreviewed_annotations': 1, 'hot': False, 'pageviews': 549060},
#   'title': 'Knockin’ on Heaven’s Door',
#   'title_with_featured': 'Knockin’ on Heaven’s Door',
#   'url': 'https://genius.com/Guns-n-roses-knockin-on-heavens-door-lyrics',
#   'featured_artists': [],
#   'primary_artist': {'api_path': '/artists/637',
#    'header_image_url': 'https://images.genius.com/61cac9c5419a6d77387bb46ecda665fe.1000x488x1.jpg',
#    'id': 637,
#    'image_url': 'https://images.genius.com/f849831e1c03d02aa523459287b7ca51.1000x1000x1.png',
#    'is_meme_verified': False,
#    'is_verified': False,
#    'name': 'Guns N’ Roses',
#    'url': 'https://genius.com/artists/Guns-n-roses'},
#   'primary_artists': [{'api_path': '/artists/637',
#     'header_image_url': 'https://images.genius.com/61cac9c5419a6d77387bb46ecda665fe.1000x488x1.jpg',
#     'id': 637,
#     'image_url': 'https://images.genius.com/f849831e1c03d02aa523459287b7ca51.1000x1000x1.png',
#     'is_meme_verified': False,
#     'is_verified': False,
#     'name': 'Guns N’ Roses',
#     'url': 'https://genius.com/artists/Guns-n-roses'}]},
#  {'annotation_count': 128,
#   'api_path': '/songs/5393247',
#   'artist_names': 'Bob Dylan',
#   'full_title': 'Murder Most Foul by\xa0Bob\xa0Dylan',
#   'header_image_thumbnail_url': 'https://images.genius.com/7fbaf838ffdf99315408faa29cb566ac.300x300x1.jpg',
#   'header_image_url': 'https://images.genius.com/7fbaf838ffdf99315408faa29cb566ac.1000x1000x1.jpg',
#   'id': 5393247,
#   'lyrics_owner_id': 3360167,
#   'lyrics_state': 'complete',
#   'path': '/Bob-dylan-murder-most-foul-lyrics',
#   'primary_artist_names': 'Bob Dylan',
#   'pyongs_count': 37,
#   'relationships_index_url': 'https://genius.com/Bob-dylan-murder-most-foul-sample',
#   'release_date_components': {'year': 2020, 'month': 3, 'day': 27},
#   'release_date_for_display': 'March 27, 2020',
#   'release_date_with_abbreviated_month_for_display': 'Mar. 27, 2020',
#   'song_art_image_thumbnail_url': 'https://images.genius.com/7fbaf838ffdf99315408faa29cb566ac.300x300x1.jpg',
#   'song_art_image_url': 'https://images.genius.com/7fbaf838ffdf99315408faa29cb566ac.1000x1000x1.jpg',
#   'stats': {'unreviewed_annotations': 40, 'hot': False, 'pageviews': 519604},
#   'title': 'Murder Most Foul',
#   'title_with_featured': 'Murder Most Foul',
#   'url': 'https://genius.com/Bob-dylan-murder-most-foul-lyrics',
#   'featured_artists': [],
#   'primary_artist': {'api_path': '/artists/181',
#    'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#    'id': 181,
#    'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#    'is_meme_verified': False,
#    'is_verified': False,
#    'name': 'Bob Dylan',
#    'url': 'https://genius.com/artists/Bob-dylan'},
#   'primary_artists': [{'api_path': '/artists/181',
#     'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#     'id': 181,
#     'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#     'is_meme_verified': False,
#     'is_verified': False,
#     'name': 'Bob Dylan',
#     'url': 'https://genius.com/artists/Bob-dylan'}]},
#  {'annotation_count': 10,
#   'api_path': '/songs/84846',
#   'artist_names': 'Bob Dylan',
#   'full_title': "Don't Think Twice, It's All Right by\xa0Bob\xa0Dylan",
#   'header_image_thumbnail_url': 'https://images.genius.com/8ad4575fda9fd49e964c4b4ac541b4a4.300x300x1.png',
#   'header_image_url': 'https://images.genius.com/8ad4575fda9fd49e964c4b4ac541b4a4.1000x1000x1.png',
#   'id': 84846,
#   'lyrics_owner_id': 125524,
#   'lyrics_state': 'complete',
#   'path': '/Bob-dylan-dont-think-twice-its-all-right-lyrics',
#   'primary_artist_names': 'Bob Dylan',
#   'pyongs_count': 31,
#   'relationships_index_url': 'https://genius.com/Bob-dylan-dont-think-twice-its-all-right-sample',
#   'release_date_components': {'year': 1963, 'month': 5, 'day': 27},
#   'release_date_for_display': 'May 27, 1963',
#   'release_date_with_abbreviated_month_for_display': 'May 27, 1963',
#   'song_art_image_thumbnail_url': 'https://images.genius.com/8ad4575fda9fd49e964c4b4ac541b4a4.300x300x1.png',
#   'song_art_image_url': 'https://images.genius.com/8ad4575fda9fd49e964c4b4ac541b4a4.1000x1000x1.png',
#   'stats': {'unreviewed_annotations': 5, 'hot': False, 'pageviews': 488074},
#   'title': 'Don’t Think Twice, It’s All Right',
#   'title_with_featured': "Don't Think Twice, It's All Right",
#   'url': 'https://genius.com/Bob-dylan-dont-think-twice-its-all-right-lyrics',
#   'featured_artists': [],
#   'primary_artist': {'api_path': '/artists/181',
#    'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#    'id': 181,
#    'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#    'is_meme_verified': False,
#    'is_verified': False,
#    'name': 'Bob Dylan',
#    'url': 'https://genius.com/artists/Bob-dylan'},
#   'primary_artists': [{'api_path': '/artists/181',
#     'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#     'id': 181,
#     'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#     'is_meme_verified': False,
#     'is_verified': False,
#     'name': 'Bob Dylan',
#     'url': 'https://genius.com/artists/Bob-dylan'}]},
#  {'annotation_count': 32,
#   'api_path': '/songs/87402',
#   'artist_names': 'Bob Dylan',
#   'full_title': 'Hurricane by\xa0Bob\xa0Dylan',
#   'header_image_thumbnail_url': 'https://images.genius.com/2df91ca57456e44cf67e1d30d25bb701.300x299x1.jpg',
#   'header_image_url': 'https://images.genius.com/2df91ca57456e44cf67e1d30d25bb701.567x566x1.jpg',
#   'id': 87402,
#   'lyrics_owner_id': 132320,
#   'lyrics_state': 'complete',
#   'path': '/Bob-dylan-hurricane-lyrics',
#   'primary_artist_names': 'Bob Dylan',
#   'pyongs_count': 27,
#   'relationships_index_url': 'https://genius.com/Bob-dylan-hurricane-sample',
#   'release_date_components': {'year': 1976, 'month': 1, 'day': 5},
#   'release_date_for_display': 'January 5, 1976',
#   'release_date_with_abbreviated_month_for_display': 'Jan. 5, 1976',
#   'song_art_image_thumbnail_url': 'https://images.genius.com/2df91ca57456e44cf67e1d30d25bb701.300x299x1.jpg',
#   'song_art_image_url': 'https://images.genius.com/2df91ca57456e44cf67e1d30d25bb701.567x566x1.jpg',
#   'stats': {'unreviewed_annotations': 7, 'hot': False, 'pageviews': 441456},
#   'title': 'Hurricane',
#   'title_with_featured': 'Hurricane',
#   'url': 'https://genius.com/Bob-dylan-hurricane-lyrics',
#   'featured_artists': [],
#   'primary_artist': {'api_path': '/artists/181',
#    'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#    'id': 181,
#    'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#    'is_meme_verified': False,
#    'is_verified': False,
#    'name': 'Bob Dylan',
#    'url': 'https://genius.com/artists/Bob-dylan'},
#   'primary_artists': [{'api_path': '/artists/181',
#     'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#     'id': 181,
#     'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#     'is_meme_verified': False,
#     'is_verified': False,
#     'name': 'Bob Dylan',
#     'url': 'https://genius.com/artists/Bob-dylan'}]},
#  {'annotation_count': 10,
#   'api_path': '/songs/63341',
#   'artist_names': 'The Jimi Hendrix Experience',
#   'full_title': 'All Along the Watchtower by\xa0The\xa0Jimi Hendrix Experience',
#   'header_image_thumbnail_url': 'https://images.genius.com/ff55dd642026ce236b2488bb316bd98a.300x300x1.jpg',
#   'header_image_url': 'https://images.genius.com/ff55dd642026ce236b2488bb316bd98a.1000x1000x1.jpg',
#   'id': 63341,
#   'lyrics_owner_id': 31298,
#   'lyrics_state': 'complete',
#   'path': '/The-jimi-hendrix-experience-all-along-the-watchtower-lyrics',
#   'primary_artist_names': 'The Jimi Hendrix Experience',
#   'pyongs_count': 73,
#   'relationships_index_url': 'https://genius.com/The-jimi-hendrix-experience-all-along-the-watchtower-sample',
#   'release_date_components': {'year': 1968, 'month': 9, 'day': 21},
#   'release_date_for_display': 'September 21, 1968',
#   'release_date_with_abbreviated_month_for_display': 'Sep. 21, 1968',
#   'song_art_image_thumbnail_url': 'https://images.genius.com/ff55dd642026ce236b2488bb316bd98a.300x300x1.jpg',
#   'song_art_image_url': 'https://images.genius.com/ff55dd642026ce236b2488bb316bd98a.1000x1000x1.jpg',
#   'stats': {'unreviewed_annotations': 0, 'hot': False, 'pageviews': 413430},
#   'title': 'All Along the Watchtower',
#   'title_with_featured': 'All Along the Watchtower',
#   'url': 'https://genius.com/The-jimi-hendrix-experience-all-along-the-watchtower-lyrics',
#   'featured_artists': [],
#   'primary_artist': {'api_path': '/artists/634985',
#    'header_image_url': 'https://images.genius.com/2631895179875ea7541bbb43d0a83481.1000x250x1.png',
#    'id': 634985,
#    'image_url': 'https://images.genius.com/ca64447350d06d6dc144070174575951.840x840x1.jpg',
#    'is_meme_verified': False,
#    'is_verified': False,
#    'name': 'The Jimi Hendrix Experience',
#    'url': 'https://genius.com/artists/The-jimi-hendrix-experience'},
#   'primary_artists': [{'api_path': '/artists/634985',
#     'header_image_url': 'https://images.genius.com/2631895179875ea7541bbb43d0a83481.1000x250x1.png',
#     'id': 634985,
#     'image_url': 'https://images.genius.com/ca64447350d06d6dc144070174575951.840x840x1.jpg',
#     'is_meme_verified': False,
#     'is_verified': False,
#     'name': 'The Jimi Hendrix Experience',
#     'url': 'https://genius.com/artists/The-jimi-hendrix-experience'}]},
#  {'annotation_count': 21,
#   'api_path': '/songs/224',
#   'artist_names': 'Bob Dylan',
#   'full_title': 'Subterranean Homesick Blues by\xa0Bob\xa0Dylan',
#   'header_image_thumbnail_url': 'https://images.genius.com/fccb3cb2608c837461ddab5ddd8cd31e.300x300x1.jpg',
#   'header_image_url': 'https://images.genius.com/fccb3cb2608c837461ddab5ddd8cd31e.1000x1000x1.jpg',
#   'id': 224,
#   'lyrics_owner_id': 4,
#   'lyrics_state': 'complete',
#   'path': '/Bob-dylan-subterranean-homesick-blues-lyrics',
#   'primary_artist_names': 'Bob Dylan',
#   'pyongs_count': 37,
#   'relationships_index_url': 'https://genius.com/Bob-dylan-subterranean-homesick-blues-sample',
#   'release_date_components': {'year': 1965, 'month': 3, 'day': 8},
#   'release_date_for_display': 'March 8, 1965',
#   'release_date_with_abbreviated_month_for_display': 'Mar. 8, 1965',
#   'song_art_image_thumbnail_url': 'https://images.genius.com/fccb3cb2608c837461ddab5ddd8cd31e.300x300x1.jpg',
#   'song_art_image_url': 'https://images.genius.com/fccb3cb2608c837461ddab5ddd8cd31e.1000x1000x1.jpg',
#   'stats': {'unreviewed_annotations': 2, 'hot': False, 'pageviews': 404743},
#   'title': 'Subterranean Homesick Blues',
#   'title_with_featured': 'Subterranean Homesick Blues',
#   'url': 'https://genius.com/Bob-dylan-subterranean-homesick-blues-lyrics',
#   'featured_artists': [],
#   'primary_artist': {'api_path': '/artists/181',
#    'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#    'id': 181,
#    'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#    'is_meme_verified': False,
#    'is_verified': False,
#    'name': 'Bob Dylan',
#    'url': 'https://genius.com/artists/Bob-dylan'},
#   'primary_artists': [{'api_path': '/artists/181',
#     'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#     'id': 181,
#     'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#     'is_meme_verified': False,
#     'is_verified': False,
#     'name': 'Bob Dylan',
#     'url': 'https://genius.com/artists/Bob-dylan'}]},
#  {'annotation_count': 10,
#   'api_path': '/songs/79749',
#   'artist_names': 'Bob Dylan',
#   'full_title': 'Make You Feel My Love by\xa0Bob\xa0Dylan',
#   'header_image_thumbnail_url': 'https://images.genius.com/cd0a26733cc459710d0986b7b64de8f0.300x300x1.jpg',
#   'header_image_url': 'https://images.genius.com/cd0a26733cc459710d0986b7b64de8f0.1000x1000x1.jpg',
#   'id': 79749,
#   'lyrics_owner_id': 5307,
#   'lyrics_state': 'complete',
#   'path': '/Bob-dylan-make-you-feel-my-love-lyrics',
#   'primary_artist_names': 'Bob Dylan',
#   'pyongs_count': 10,
#   'relationships_index_url': 'https://genius.com/Bob-dylan-make-you-feel-my-love-sample',
#   'release_date_components': {'year': 1997, 'month': 9, 'day': 30},
#   'release_date_for_display': 'September 30, 1997',
#   'release_date_with_abbreviated_month_for_display': 'Sep. 30, 1997',
#   'song_art_image_thumbnail_url': 'https://images.genius.com/cd0a26733cc459710d0986b7b64de8f0.300x300x1.jpg',
#   'song_art_image_url': 'https://images.genius.com/cd0a26733cc459710d0986b7b64de8f0.1000x1000x1.jpg',
#   'stats': {'unreviewed_annotations': 3, 'hot': False, 'pageviews': 391598},
#   'title': 'Make You Feel My Love',
#   'title_with_featured': 'Make You Feel My Love',
#   'url': 'https://genius.com/Bob-dylan-make-you-feel-my-love-lyrics',
#   'featured_artists': [],
#   'primary_artist': {'api_path': '/artists/181',
#    'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#    'id': 181,
#    'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#    'is_meme_verified': False,
#    'is_verified': False,
#    'name': 'Bob Dylan',
#    'url': 'https://genius.com/artists/Bob-dylan'},
#   'primary_artists': [{'api_path': '/artists/181',
#     'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#     'id': 181,
#     'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#     'is_meme_verified': False,
#     'is_verified': False,
#     'name': 'Bob Dylan',
#     'url': 'https://genius.com/artists/Bob-dylan'}]},
#  {'annotation_count': 41,
#   'api_path': '/songs/105186',
#   'artist_names': 'Bob Dylan',
#   'full_title': "A Hard Rain's A-Gonna Fall by\xa0Bob\xa0Dylan",
#   'header_image_thumbnail_url': 'https://images.genius.com/8ad4575fda9fd49e964c4b4ac541b4a4.300x300x1.png',
#   'header_image_url': 'https://images.genius.com/8ad4575fda9fd49e964c4b4ac541b4a4.1000x1000x1.png',
#   'id': 105186,
#   'lyrics_owner_id': 16,
#   'lyrics_state': 'complete',
#   'path': '/Bob-dylan-a-hard-rains-a-gonna-fall-lyrics',
#   'primary_artist_names': 'Bob Dylan',
#   'pyongs_count': 24,
#   'relationships_index_url': 'https://genius.com/Bob-dylan-a-hard-rains-a-gonna-fall-sample',
#   'release_date_components': {'year': 1963, 'month': 5, 'day': 27},
#   'release_date_for_display': 'May 27, 1963',
#   'release_date_with_abbreviated_month_for_display': 'May 27, 1963',
#   'song_art_image_thumbnail_url': 'https://images.genius.com/8ad4575fda9fd49e964c4b4ac541b4a4.300x300x1.png',
#   'song_art_image_url': 'https://images.genius.com/8ad4575fda9fd49e964c4b4ac541b4a4.1000x1000x1.png',
#   'stats': {'unreviewed_annotations': 5, 'hot': False, 'pageviews': 390351},
#   'title': 'A Hard Rain’s A-Gonna Fall',
#   'title_with_featured': "A Hard Rain's A-Gonna Fall",
#   'url': 'https://genius.com/Bob-dylan-a-hard-rains-a-gonna-fall-lyrics',
#   'featured_artists': [],
#   'primary_artist': {'api_path': '/artists/181',
#    'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#    'id': 181,
#    'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#    'is_meme_verified': False,
#    'is_verified': False,
#    'name': 'Bob Dylan',
#    'url': 'https://genius.com/artists/Bob-dylan'},
#   'primary_artists': [{'api_path': '/artists/181',
#     'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#     'id': 181,
#     'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#     'is_meme_verified': False,
#     'is_verified': False,
#     'name': 'Bob Dylan',
#     'url': 'https://genius.com/artists/Bob-dylan'}]},
#  {'annotation_count': 23,
#   'api_path': '/songs/75446',
#   'artist_names': 'Bob Dylan',
#   'full_title': 'Mr. Tambourine Man by\xa0Bob\xa0Dylan',
#   'header_image_thumbnail_url': 'https://images.genius.com/051afc779ad250f5a1f770d5a5baaa72.300x303x1.jpg',
#   'header_image_url': 'https://images.genius.com/051afc779ad250f5a1f770d5a5baaa72.593x599x1.jpg',
#   'id': 75446,
#   'lyrics_owner_id': 74226,
#   'lyrics_state': 'complete',
#   'path': '/Bob-dylan-mr-tambourine-man-lyrics',
#   'primary_artist_names': 'Bob Dylan',
#   'pyongs_count': 25,
#   'relationships_index_url': 'https://genius.com/Bob-dylan-mr-tambourine-man-sample',
#   'release_date_components': {'year': 1965, 'month': 3, 'day': 22},
#   'release_date_for_display': 'March 22, 1965',
#   'release_date_with_abbreviated_month_for_display': 'Mar. 22, 1965',
#   'song_art_image_thumbnail_url': 'https://images.genius.com/051afc779ad250f5a1f770d5a5baaa72.300x303x1.jpg',
#   'song_art_image_url': 'https://images.genius.com/051afc779ad250f5a1f770d5a5baaa72.593x599x1.jpg',
#   'stats': {'unreviewed_annotations': 5, 'hot': False, 'pageviews': 340001},
#   'title': 'Mr. Tambourine Man',
#   'title_with_featured': 'Mr. Tambourine Man',
#   'url': 'https://genius.com/Bob-dylan-mr-tambourine-man-lyrics',
#   'featured_artists': [],
#   'primary_artist': {'api_path': '/artists/181',
#    'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#    'id': 181,
#    'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#    'is_meme_verified': False,
#    'is_verified': False,
#    'name': 'Bob Dylan',
#    'url': 'https://genius.com/artists/Bob-dylan'},
#   'primary_artists': [{'api_path': '/artists/181',
#     'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#     'id': 181,
#     'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#     'is_meme_verified': False,
#     'is_verified': False,
#     'name': 'Bob Dylan',
#     'url': 'https://genius.com/artists/Bob-dylan'}]},
#  {'annotation_count': 35,
#   'api_path': '/songs/118799',
#   'artist_names': 'Bob Dylan',
#   'full_title': 'Tangled Up in Blue by\xa0Bob\xa0Dylan',
#   'header_image_thumbnail_url': 'https://images.genius.com/9146ba54ed06288f10b296cd5d888781.300x300x1.jpg',
#   'header_image_url': 'https://images.genius.com/9146ba54ed06288f10b296cd5d888781.500x500x1.jpg',
#   'id': 118799,
#   'lyrics_owner_id': 1850,
#   'lyrics_state': 'complete',
#   'path': '/Bob-dylan-tangled-up-in-blue-lyrics',
#   'primary_artist_names': 'Bob Dylan',
#   'pyongs_count': 27,
#   'relationships_index_url': 'https://genius.com/Bob-dylan-tangled-up-in-blue-sample',
#   'release_date_components': {'year': 1975, 'month': 1, 'day': 17},
#   'release_date_for_display': 'January 17, 1975',
#   'release_date_with_abbreviated_month_for_display': 'Jan. 17, 1975',
#   'song_art_image_thumbnail_url': 'https://images.genius.com/9146ba54ed06288f10b296cd5d888781.300x300x1.jpg',
#   'song_art_image_url': 'https://images.genius.com/9146ba54ed06288f10b296cd5d888781.500x500x1.jpg',
#   'stats': {'unreviewed_annotations': 14, 'hot': False, 'pageviews': 328617},
#   'title': 'Tangled Up in Blue',
#   'title_with_featured': 'Tangled Up in Blue',
#   'url': 'https://genius.com/Bob-dylan-tangled-up-in-blue-lyrics',
#   'featured_artists': [],
#   'primary_artist': {'api_path': '/artists/181',
#    'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#    'id': 181,
#    'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#    'is_meme_verified': False,
#    'is_verified': False,
#    'name': 'Bob Dylan',
#    'url': 'https://genius.com/artists/Bob-dylan'},
#   'primary_artists': [{'api_path': '/artists/181',
#     'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#     'id': 181,
#     'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#     'is_meme_verified': False,
#     'is_verified': False,
#     'name': 'Bob Dylan',
#     'url': 'https://genius.com/artists/Bob-dylan'}]},
#  {'annotation_count': 14,
#   'api_path': '/songs/154239',
#   'artist_names': 'Darius Rucker',
#   'full_title': 'Wagon Wheel by\xa0Darius\xa0Rucker',
#   'header_image_thumbnail_url': 'https://images.genius.com/06957cdf4a75a96e581f0d2510105ebe.300x300x1.jpg',
#   'header_image_url': 'https://images.genius.com/06957cdf4a75a96e581f0d2510105ebe.640x640x1.jpg',
#   'id': 154239,
#   'lyrics_owner_id': 10380,
#   'lyrics_state': 'complete',
#   'path': '/Darius-rucker-wagon-wheel-lyrics',
#   'primary_artist_names': 'Darius Rucker',
#   'pyongs_count': 33,
#   'relationships_index_url': 'https://genius.com/Darius-rucker-wagon-wheel-sample',
#   'release_date_components': {'year': 2013, 'month': 1, 'day': 7},
#   'release_date_for_display': 'January 7, 2013',
#   'release_date_with_abbreviated_month_for_display': 'Jan. 7, 2013',
#   'song_art_image_thumbnail_url': 'https://images.genius.com/06957cdf4a75a96e581f0d2510105ebe.300x300x1.jpg',
#   'song_art_image_url': 'https://images.genius.com/06957cdf4a75a96e581f0d2510105ebe.640x640x1.jpg',
#   'stats': {'unreviewed_annotations': 0, 'hot': False, 'pageviews': 327873},
#   'title': 'Wagon Wheel',
#   'title_with_featured': 'Wagon Wheel',
#   'url': 'https://genius.com/Darius-rucker-wagon-wheel-lyrics',
#   'featured_artists': [],
#   'primary_artist': {'api_path': '/artists/21867',
#    'header_image_url': 'https://images.genius.com/6a629cf1a4b6fec5b21a8dd995cf928f.1000x519x1.jpg',
#    'id': 21867,
#    'image_url': 'https://images.genius.com/6009b412250fcc9da9092429cc266812.474x474x1.jpg',
#    'is_meme_verified': False,
#    'is_verified': False,
#    'name': 'Darius Rucker',
#    'url': 'https://genius.com/artists/Darius-rucker'},
#   'primary_artists': [{'api_path': '/artists/21867',
#     'header_image_url': 'https://images.genius.com/6a629cf1a4b6fec5b21a8dd995cf928f.1000x519x1.jpg',
#     'id': 21867,
#     'image_url': 'https://images.genius.com/6009b412250fcc9da9092429cc266812.474x474x1.jpg',
#     'is_meme_verified': False,
#     'is_verified': False,
#     'name': 'Darius Rucker',
#     'url': 'https://genius.com/artists/Darius-rucker'}]},
#  {'annotation_count': 6,
#   'api_path': '/songs/199531',
#   'artist_names': 'Bob Dylan',
#   'full_title': 'Knockin’ on Heaven’s Door by\xa0Bob\xa0Dylan',
#   'header_image_thumbnail_url': 'https://images.genius.com/e0a7ce8aae657ee022f141e82efa8891.300x299x1.jpg',
#   'header_image_url': 'https://images.genius.com/e0a7ce8aae657ee022f141e82efa8891.500x498x1.jpg',
#   'id': 199531,
#   'lyrics_owner_id': 225680,
#   'lyrics_state': 'complete',
#   'path': '/Bob-dylan-knockin-on-heavens-door-lyrics',
#   'primary_artist_names': 'Bob Dylan',
#   'pyongs_count': 16,
#   'relationships_index_url': 'https://genius.com/Bob-dylan-knockin-on-heavens-door-sample',
#   'release_date_components': {'year': 1973, 'month': 6, 'day': 13},
#   'release_date_for_display': 'June 13, 1973',
#   'release_date_with_abbreviated_month_for_display': 'Jun. 13, 1973',
#   'song_art_image_thumbnail_url': 'https://images.genius.com/e0a7ce8aae657ee022f141e82efa8891.300x299x1.jpg',
#   'song_art_image_url': 'https://images.genius.com/e0a7ce8aae657ee022f141e82efa8891.500x498x1.jpg',
#   'stats': {'unreviewed_annotations': 2, 'hot': False, 'pageviews': 298709},
#   'title': 'Knockin’ on Heaven’s Door',
#   'title_with_featured': 'Knockin’ on Heaven’s Door',
#   'url': 'https://genius.com/Bob-dylan-knockin-on-heavens-door-lyrics',
#   'featured_artists': [],
#   'primary_artist': {'api_path': '/artists/181',
#    'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#    'id': 181,
#    'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#    'is_meme_verified': False,
#    'is_verified': False,
#    'name': 'Bob Dylan',
#    'url': 'https://genius.com/artists/Bob-dylan'},
#   'primary_artists': [{'api_path': '/artists/181',
#     'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#     'id': 181,
#     'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#     'is_meme_verified': False,
#     'is_verified': False,
#     'name': 'Bob Dylan',
#     'url': 'https://genius.com/artists/Bob-dylan'}]},
#  {'annotation_count': 51,
#   'api_path': '/songs/75463',
#   'artist_names': 'Bob Dylan',
#   'full_title': "It's Alright, Ma (I'm Only Bleeding) by\xa0Bob\xa0Dylan",
#   'header_image_thumbnail_url': 'https://images.genius.com/e4013e376bc0912bdb9bddd9e9d53aef.300x300x1.png',
#   'header_image_url': 'https://images.genius.com/e4013e376bc0912bdb9bddd9e9d53aef.1000x1000x1.png',
#   'id': 75463,
#   'lyrics_owner_id': 74226,
#   'lyrics_state': 'complete',
#   'path': '/Bob-dylan-its-alright-ma-im-only-bleeding-lyrics',
#   'primary_artist_names': 'Bob Dylan',
#   'pyongs_count': 18,
#   'relationships_index_url': 'https://genius.com/Bob-dylan-its-alright-ma-im-only-bleeding-sample',
#   'release_date_components': {'year': 1965, 'month': 3, 'day': 22},
#   'release_date_for_display': 'March 22, 1965',
#   'release_date_with_abbreviated_month_for_display': 'Mar. 22, 1965',
#   'song_art_image_thumbnail_url': 'https://images.genius.com/e4013e376bc0912bdb9bddd9e9d53aef.300x300x1.png',
#   'song_art_image_url': 'https://images.genius.com/e4013e376bc0912bdb9bddd9e9d53aef.1000x1000x1.png',
#   'stats': {'unreviewed_annotations': 5, 'hot': False, 'pageviews': 258206},
#   'title': 'It’s Alright, Ma (I’m Only Bleeding)',
#   'title_with_featured': "It's Alright, Ma (I'm Only Bleeding)",
#   'url': 'https://genius.com/Bob-dylan-its-alright-ma-im-only-bleeding-lyrics',
#   'featured_artists': [],
#   'primary_artist': {'api_path': '/artists/181',
#    'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#    'id': 181,
#    'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#    'is_meme_verified': False,
#    'is_verified': False,
#    'name': 'Bob Dylan',
#    'url': 'https://genius.com/artists/Bob-dylan'},
#   'primary_artists': [{'api_path': '/artists/181',
#     'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#     'id': 181,
#     'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#     'is_meme_verified': False,
#     'is_verified': False,
#     'name': 'Bob Dylan',
#     'url': 'https://genius.com/artists/Bob-dylan'}]},
#  {'annotation_count': 82,
#   'api_path': '/songs/92350',
#   'artist_names': 'Bob Dylan',
#   'full_title': 'Desolation Row by\xa0Bob\xa0Dylan',
#   'header_image_thumbnail_url': 'https://images.genius.com/5f645b57452ff0d90afe6c138180db0a.300x300x1.jpg',
#   'header_image_url': 'https://images.genius.com/5f645b57452ff0d90afe6c138180db0a.1000x1000x1.jpg',
#   'id': 92350,
#   'lyrics_owner_id': 145715,
#   'lyrics_state': 'complete',
#   'path': '/Bob-dylan-desolation-row-lyrics',
#   'primary_artist_names': 'Bob Dylan',
#   'pyongs_count': 14,
#   'relationships_index_url': 'https://genius.com/Bob-dylan-desolation-row-sample',
#   'release_date_components': {'year': 1965, 'month': 8, 'day': 30},
#   'release_date_for_display': 'August 30, 1965',
#   'release_date_with_abbreviated_month_for_display': 'Aug. 30, 1965',
#   'song_art_image_thumbnail_url': 'https://images.genius.com/5f645b57452ff0d90afe6c138180db0a.300x300x1.jpg',
#   'song_art_image_url': 'https://images.genius.com/5f645b57452ff0d90afe6c138180db0a.1000x1000x1.jpg',
#   'stats': {'unreviewed_annotations': 20, 'hot': False, 'pageviews': 252967},
#   'title': 'Desolation Row',
#   'title_with_featured': 'Desolation Row',
#   'url': 'https://genius.com/Bob-dylan-desolation-row-lyrics',
#   'featured_artists': [],
#   'primary_artist': {'api_path': '/artists/181',
#    'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#    'id': 181,
#    'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#    'is_meme_verified': False,
#    'is_verified': False,
#    'name': 'Bob Dylan',
#    'url': 'https://genius.com/artists/Bob-dylan'},
#   'primary_artists': [{'api_path': '/artists/181',
#     'header_image_url': 'https://images.genius.com/f854c714833541117358e2097cfd597f.1000x563x2.gif',
#     'id': 181,
#     'image_url': 'https://images.genius.com/f3c6518f8979ef5e0ee44ea51c4ba462.610x610x1.jpg',
#     'is_meme_verified': False,
#     'is_verified': False,
#     'name': 'Bob Dylan',
#     'url': 'https://genius.com/artists/Bob-dylan'}]}]

# %%
# Build DataFrame

df = pd.DataFrame([{
    "Title": song["title"],
    "Performer": song["primary_artist"]["name"],
    "Song URL": song["url"]
} for song in songs])

df
# Out:
#                                    Title                    Performer  \
# 0                       We Are the World               USA For Africa
# 1                    Blowin’ in the Wind                    Bob Dylan
# 2                  Make You Feel My Love                        Adele
# 3          The Times They Are A-Changin’                    Bob Dylan
# 4                   Like a Rolling Stone                    Bob Dylan
# 5               All Along the Watchtower                    Bob Dylan
# 6              Knockin’ on Heaven’s Door                Guns N’ Roses
# 7                       Murder Most Foul                    Bob Dylan
# 8      Don’t Think Twice, It’s All Right                    Bob Dylan
# 9                              Hurricane                    Bob Dylan
# 10              All Along the Watchtower  The Jimi Hendrix Experience
# 11           Subterranean Homesick Blues                    Bob Dylan
# 12                 Make You Feel My Love                    Bob Dylan
# 13            A Hard Rain’s A-Gonna Fall                    Bob Dylan
# 14                    Mr. Tambourine Man                    Bob Dylan
# 15                    Tangled Up in Blue                    Bob Dylan
# 16                           Wagon Wheel                Darius Rucker
# 17             Knockin’ on Heaven’s Door                    Bob Dylan
# 18  It’s Alright, Ma (I’m Only Bleeding)                    Bob Dylan
# 19                        Desolation Row                    Bob Dylan
#
#                                              Song URL
# 0   https://genius.com/Usa-for-africa-we-are-the-w...
# 1   https://genius.com/Bob-dylan-blowin-in-the-win...
# 2   https://genius.com/Adele-make-you-feel-my-love...
# 3   https://genius.com/Bob-dylan-the-times-they-ar...
# 4   https://genius.com/Bob-dylan-like-a-rolling-st...
# 5   https://genius.com/Bob-dylan-all-along-the-wat...
# 6   https://genius.com/Guns-n-roses-knockin-on-hea...
# 7   https://genius.com/Bob-dylan-murder-most-foul-...
# 8   https://genius.com/Bob-dylan-dont-think-twice-...
# 9       https://genius.com/Bob-dylan-hurricane-lyrics
# 10  https://genius.com/The-jimi-hendrix-experience...
# 11  https://genius.com/Bob-dylan-subterranean-home...
# 12  https://genius.com/Bob-dylan-make-you-feel-my-...
# 13  https://genius.com/Bob-dylan-a-hard-rains-a-go...
# 14  https://genius.com/Bob-dylan-mr-tambourine-man...
# 15  https://genius.com/Bob-dylan-tangled-up-in-blu...
# 16  https://genius.com/Darius-rucker-wagon-wheel-l...
# 17  https://genius.com/Bob-dylan-knockin-on-heaven...
# 18  https://genius.com/Bob-dylan-its-alright-ma-im...
# 19  https://genius.com/Bob-dylan-desolation-row-ly...

# %% [markdown]
# ## Problem 3
# One drawback of the Genius API is that is currently has no endpoint that returns song lyrics.
#
# The `lyricsgenius` package is a wrapper around `requests` and `BeautifulSoup`, the Python package for web-scraping data off of the raw HTML of a webpage. We will cover web-scraping in module 5. But for now, follow the guide on the GitHub repository for this package (https://github.com/johnwmillr/LyricsGenius) for instructions on using it. Then use `lyricsgenius` to download and display the lyrics to "Tangled Up in Blue" by Bob Dylan.
#
# Optional but recommended: call a loved one on the phone and sing "Tangled Up in Blue" to them. [12 points]

# %%
pip install lyricsgenius
# Out:
# Requirement already satisfied: lyricsgenius in /Users/khansaamaa/miniconda3/envs/ds6001/lib/python3.13/site-packages (3.7.2)
# Requirement already satisfied: beautifulsoup4>=4.12.3 in /Users/khansaamaa/miniconda3/envs/ds6001/lib/python3.13/site-packages (from lyricsgenius) (4.13.5)
# Requirement already satisfied: requests>=2.27.1 in /Users/khansaamaa/miniconda3/envs/ds6001/lib/python3.13/site-packages (from lyricsgenius) (2.32.5)
# Requirement already satisfied: soupsieve>1.2 in /Users/khansaamaa/miniconda3/envs/ds6001/lib/python3.13/site-packages (from beautifulsoup4>=4.12.3->lyricsgenius) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in /Users/khansaamaa/miniconda3/envs/ds6001/lib/python3.13/site-packages (from beautifulsoup4>=4.12.3->lyricsgenius) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/khansaamaa/miniconda3/envs/ds6001/lib/python3.13/site-packages (from requests>=2.27.1->lyricsgenius) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /Users/khansaamaa/miniconda3/envs/ds6001/lib/python3.13/site-packages (from requests>=2.27.1->lyricsgenius) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/khansaamaa/miniconda3/envs/ds6001/lib/python3.13/site-packages (from requests>=2.27.1->lyricsgenius) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/khansaamaa/miniconda3/envs/ds6001/lib/python3.13/site-packages (from requests>=2.27.1->lyricsgenius) (2025.8.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
import lyricsgenius

# Replace with your actual Genius API token
genius = lyricsgenius.Genius("8znOF5jl48PfBcwy9DJkVx1nrzxRqBIGfLlLaIABcDHnhCLFl1gfOn2Ynioo7mbQ")

# %%
# Optional: limit verbosity and remove section headers
genius.verbose = False
genius.remove_section_headers = True

# %%
# Search for the song
song = genius.search_song("Tangled Up in Blue", "Bob Dylan")

song
# Out:
# Song(title=Tangled Up in Blue, artist=Bob Dylan)

# %%
# Display lyrics (truncated for copyright compliance)
if song:
    print("🎶 Song Title:", song.title)
    print("🎤 Artist:", song.artist)
    print("📜 Lyrics Preview:")
    print("\n".join(song.lyrics.split("\n")[:10]))  # Show first 10 lines only
else:
    print("Song not found.")
# Out:
# 🎶 Song Title: Tangled Up in Blue
# 🎤 Artist: Bob Dylan
# 📜 Lyrics Preview:
# Early one morning the sun was shining
# I was laying in bed
# Wondering if she'd changed at all
# If her hair was still red
# Her folks they said our lives together
# Sure was going to be rough
# They never did like Mama's homemade dress
# Papa's bankbook wasn't big enough
# And I was standing on the side of the road
# Rain falling on my shoes
